# %%
pip install apyori

# %%
from apyori import apriori

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Market_Basket_Optimisation.csv", header=None)
df
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# 0     green grapes  whole weat flour  yams  cottage cheese  energy drink
# 1              NaN               NaN   NaN             NaN           NaN
# 2              NaN               NaN   NaN             NaN           NaN
# 3              NaN               NaN   NaN             NaN           NaN
# 4        green tea               NaN   NaN             NaN           NaN
# ...            ...               ...   ...             ...           ...
# 7496           NaN               NaN   NaN             NaN           NaN
# 7497     magazines         green tea   NaN             NaN           NaN
# 7498           NaN               NaN   NaN             NaN           NaN
# 7499           NaN               NaN   NaN             NaN           NaN
# 7500           NaN               NaN   NaN             NaN           NaN
#
#                 9               10         11     12     13             14  \
# 0     tomato juice  low fat yogurt  green tea  honey  salad  mineral water
# 1              NaN             NaN        NaN    NaN    NaN            NaN
# 2              NaN             NaN        NaN    NaN    NaN            NaN
# 3              NaN             NaN        NaN    NaN    NaN            NaN
# 4              NaN             NaN        NaN    NaN    NaN            NaN
# ...            ...             ...        ...    ...    ...            ...
# 7496           NaN             NaN        NaN    NaN    NaN            NaN
# 7497           NaN             NaN        NaN    NaN    NaN            NaN
# 7498           NaN             NaN        NaN    NaN    NaN            NaN
# 7499           NaN             NaN        NaN    NaN    NaN            NaN
# 7500           NaN             NaN        NaN    NaN    NaN            NaN
#
#           15                 16               17       18         19
# 0     salmon  antioxydant juice  frozen smoothie  spinach  olive oil
# 1        NaN                NaN              NaN      NaN        NaN
# 2        NaN                NaN              NaN      NaN        NaN
# 3        NaN                NaN              NaN      NaN        NaN
# 4        NaN                NaN              NaN      NaN        NaN
# ...      ...                ...              ...      ...        ...
# 7496     NaN                NaN              NaN      NaN        NaN
# 7497     NaN                NaN              NaN      NaN        NaN
# 7498     NaN                NaN              NaN      NaN        NaN
# 7499     NaN                NaN              NaN      NaN        NaN
# 7500     NaN                NaN              NaN      NaN        NaN
#
# [7501 rows x 20 columns]

# %%
df.isnull().sum()
# Out:
# 0        0
# 1     1754
# 2     3112
# 3     4156
# 4     4972
# 5     5637
# 6     6132
# 7     6520
# 8     6847
# 9     7106
# 10    7245
# 11    7347
# 12    7414
# 13    7454
# 14    7476
# 15    7493
# 16    7497
# 17    7497
# 18    7498
# 19    7500
# dtype: int64

# %%
df.values.tolist()
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers',
#   'meatballs',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['chutney',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'avocado',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mineral water',
#   'milk',
#   'energy bar',
#   'whole wheat rice',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['whole wheat pasta',
#   'french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['soup',
#   'light cream',
#   'shallot',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen vegetables',
#   'spaghetti',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['eggs',
#   'pet food',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'burgers',
#   'mineral water',
#   'eggs',
#   'cooking oil',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['spaghetti',
#   'champagne',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mineral water',
#   'salmon',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mineral water',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['shrimp',
#   'chocolate',
#   'chicken',
#   'honey',
#   'oil',
#   'cooking oil',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'fresh tuna',
#   'tomatoes',
#   'spaghetti',
#   'mineral water',
#   'black tea',
#   'salmon',
#   'eggs',
#   'chicken',
#   'extra dark chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['meatballs',
#   'milk',
#   'honey',
#   'french fries',
#   'protein bar',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['red wine',
#   'shrimp',
#   'pasta',
#   'pepper',
#   'eggs',
#   'chocolate',
#   'shampoo',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['rice',
#   'sparkling water',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['spaghetti',
#   'mineral water',
#   'ham',
#   'body spray',
#   'pancakes',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'grated cheese',
#   'shrimp',
#   'pasta',
#   'avocado',
#   'honey',
#   'white wine',
#   'toothpaste',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['parmesan cheese',
#   'spaghetti',
#   'soup',
#   'avocado',
#   'milk',
#   'fresh bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['ground beef',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'energy bar',
#   'black tea',
#   'salmon',
#   'frozen smoothie',
#   'escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['sparkling water',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mineral water',
#   'eggs',
#   'chicken',
#   'chocolate',
#   'french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen vegetables',
#   'spaghetti',
#   'yams',
#   'mineral water',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['herb & pepper',
#   'tomato sauce',
#   'light cream',
#   'magazines',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mineral water',
#   'chocolate',
#   'avocado',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'french fries',
#   'strawberries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen vegetables',
#   'strong cheese',
#   'chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['pickles',
#   'spaghetti',
#   'salmon',
#   'escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['energy bar',
#   'french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['red wine',
#   'ground beef',
#   'mineral water',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mineral water',
#   'cake',
#   'cottage cheese',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['pickles',
#   'champagne',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['spaghetti',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['fresh tuna',
#   'frozen vegetables',
#   'spaghetti',
#   'mineral water',
#   'honey',
#   'whole wheat rice',
#   'frozen smoothie',
#   'escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['spaghetti',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['soup',
#   'meatballs',
#   'hot dogs',
#   'sparkling water',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['soup',
#   'avocado',
#   'french fries',
#   'hot dogs',
#   'brownies',
#   'body spray',
#   'pancakes',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mineral water',
#   'chicken',
#   'cereals',
#   'clothes accessories',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mineral water',
#   'bug spray',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['avocado',
#   'muffins',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'black tea',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['spaghetti',
#   'chocolate',
#   'brownies',
#   'white wine',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['fresh tuna',
#   'mineral water',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['spaghetti',
#   'muffins',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['spaghetti',
#   'chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['french fries',
#   'escalope',
#   'champagne',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['tomato sauce',
#   'light mayo',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'fresh tuna',
#   'frozen vegetables',
#   'tomatoes',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'chocolate',
#   'soup',
#   'milk',
#   'olive oil',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['eggs',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['soup',
#   'chicken',
#   'gums',
#   'soda',
#   'body spray',
#   'energy drink',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'frozen vegetables',
#   'mineral water',
#   'cider',
#   'cooking oil',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['spaghetti',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['clothes accessories',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['energy drink',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['soup',
#   'bug spray',
#   'shallot',
#   'protein bar',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['chocolate',
#   'milk',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['herb & pepper',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'avocado',
#   'cider',
#   'whole wheat rice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['shrimp',
#   'pasta',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['grated cheese',
#   'herb & pepper',
#   'tomatoes',
#   'tomato sauce',
#   'corn',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'escalope',
#   'shallot',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['yogurt cake',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['soup',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mineral water',
#   'chocolate',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['eggs',
#   'strawberries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['grated cheese',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'white wine',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mint',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['eggs',
#   'cake',
#   'french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'spaghetti',
#   'milk',
#   'french fries',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mineral water',
#   'energy bar',
#   'butter',
#   'french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'grated cheese',
#   'herb & pepper',
#   'mineral water',
#   'eggs',
#   'cooking oil',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['energy bar',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['energy bar',
#   'energy drink',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['chocolate',
#   'frozen smoothie',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['asparagus',
#   'salad',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'french fries',
#   'low fat yogurt',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'herb & pepper',
#   'shrimp',
#   'pasta',
#   'spaghetti',
#   'mineral water',
#   'meatballs',
#   'olive oil',
#   'energy bar',
#   'french wine',
#   'eggs',
#   'salt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['champagne',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['champagne',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'almonds',
#   'eggs',
#   'french fries',
#   'cookies',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['ham',
#   'soup',
#   'escalope',
#   'body spray',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'ham',
#   'frozen vegetables',
#   'pepper',
#   'oil',
#   'extra dark chocolate',
#   'tea',
#   'magazines',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['muffins',
#   'eggs',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen vegetables',
#   'whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'chocolate',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mineral water',
#   'barbecue sauce',
#   'chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'herb & pepper',
#   'energy bar',
#   'almonds',
#   'eggs',
#   'corn',
#   'mayonnaise',
#   'zucchini',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'burgers',
#   'ground beef',
#   'chocolate',
#   'soup',
#   'almonds',
#   'eggs',
#   'hot dogs',
#   'cottage cheese',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['ham',
#   'spaghetti',
#   'chocolate',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['ground beef',
#   'energy bar',
#   'pet food',
#   'carrots',
#   'protein bar',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['ground beef',
#   'tomato sauce',
#   'spaghetti',
#   'mineral water',
#   'almonds',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mineral water',
#   'olive oil',
#   'gums',
#   'cooking oil',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['shrimp',
#   'pasta',
#   'mineral water',
#   'soup',
#   'avocado',
#   'milk',
#   'olive oil',
#   'green grapes',
#   'eggs',
#   'bug spray',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['shrimp',
#   'pasta',
#   'soup',
#   'cake',
#   'cooking oil',
#   'chicken',
#   'light mayo',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['spaghetti',
#   'mineral water',
#   'chocolate',
#   'french fries',
#   'champagne',
#   'escalope',
#   'mushroom cream sauce',
#   'fresh bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['shrimp',
#   'pasta',
#   'mineral water',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'oil',
#   'tomato juice',
#   'fresh bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['french wine',
#   'eggs',
#   'chocolate',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['chicken',
#   'eggs',
#   'french fries',
#   'pancakes',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'herb & pepper',
#   'salmon',
#   'white wine',
#   'candy bars',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['grated cheese',
#   'spaghetti',
#   'olive oil',
#   'eggs',
#   'french fries',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mineral water',
#   'energy bar',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['eggs',
#   'french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'tomatoes',
#   'mineral water',
#   'soup',
#   'milk',
#   'almonds',
#   'eggs',
#   'chocolate',
#   'tomato juice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['muffins',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['pasta',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['tomatoes',
#   'spaghetti',
#   'frozen smoothie',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['ground beef',
#   'spaghetti',
#   'milk',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['chocolate',
#   'milk',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'shrimp',
#   'pasta',
#   'frozen vegetables',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'eggs',
#   'chocolate',
#   'french fries',
#   'pancakes',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['ground beef',
#   'mineral water',
#   'antioxydant juice',
#   'protein bar',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['grated cheese',
#   'whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'cake',
#   'energy drink',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['grated cheese',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['pancakes',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen smoothie',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['carrots',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'burgers',
#   'chocolate',
#   'olive oil',
#   'eggs',
#   'cooking oil',
#   'corn',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen vegetables',
#   'tomatoes',
#   'pepper',
#   'spaghetti',
#   'mineral water',
#   'pancakes',
#   'chicken',
#   'chili',
#   'tea',
#   'french fries',
#   'tomato juice',
#   'fresh bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['ground beef',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'eggs',
#   'chocolate',
#   'frozen smoothie',
#   'tomato juice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen vegetables',
#   'cooking oil',
#   'mashed potato',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen vegetables',
#   'ground beef',
#   'tomato sauce',
#   'mineral water',
#   'meatballs',
#   'olive oil',
#   'light cream',
#   'tomato juice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['red wine',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'milk',
#   'eggs',
#   'cake',
#   'gums',
#   'cooking oil',
#   'chocolate',
#   'frozen smoothie',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['chocolate',
#   'tomatoes',
#   'spaghetti',
#   'mineral water',
#   'avocado',
#   'milk',
#   'olive oil',
#   'eggs',
#   'rice',
#   'french fries',
#   'brownies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['chocolate',
#   'shrimp',
#   'pasta',
#   'frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'nonfat milk',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'shrimp',
#   'pasta',
#   'pepper',
#   'spaghetti',
#   'mineral water',
#   'eggs',
#   'chicken',
#   'french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'tomatoes',
#   'cake',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['yams',
#   'mineral water',
#   'soup',
#   'milk',
#   'pancakes',
#   'whole wheat rice',
#   'barbecue sauce',
#   'carrots',
#   'chocolate',
#   'champagne',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['rice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['chocolate',
#   'milk',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['shrimp',
#   'pasta',
#   'frozen vegetables',
#   'water spray',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'mineral water',
#   'milk',
#   'eggs',
#   'whole wheat rice',
#   'mint',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mineral water',
#   'vegetables mix',
#   'cake',
#   'frozen smoothie',
#   'brownies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['shrimp',
#   'pasta',
#   'chicken',
#   'chocolate bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['shallot',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['shrimp',
#   'pasta',
#   'spaghetti',
#   'eggs',
#   'hot dogs',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['red wine',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'olive oil',
#   'strong cheese',
#   'light cream',
#   'cooking oil',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'grated cheese',
#   'spaghetti',
#   'avocado',
#   'milk',
#   'oil',
#   'french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['herb & pepper',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'olive oil',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['shrimp',
#   'pasta',
#   'yams',
#   'milk',
#   'chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['butter',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['light mayo',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['herb & pepper',
#   'shrimp',
#   'pasta',
#   'spaghetti',
#   'milk',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'herb & pepper',
#   'ground beef',
#   'soup',
#   'avocado',
#   'milk',
#   'black tea',
#   'eggs',
#   'barbecue sauce',
#   'carrots',
#   'cookies',
#   'tomato juice',
#   'fresh bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['pepper',
#   'french fries',
#   'strawberries',
#   'pancakes',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen vegetables',
#   'yams',
#   'chicken',
#   'honey',
#   'light mayo',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['chocolate',
#   'champagne',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['herb & pepper',
#   'honey',
#   'cake',
#   'rice',
#   'protein bar',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'chocolate',
#   'frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'milk',
#   'light mayo',
#   'asparagus',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['chocolate',
#   'mineral water',
#   'corn',
#   'cottage cheese',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['muffins',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['ham',
#   'french wine',
#   'escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['spaghetti',
#   'milk',
#   'whole wheat rice',
#   'mint green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['chocolate',
#   'body spray',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen vegetables',
#   'french fries',
#   'hot dogs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['candy bars',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'shrimp',
#   'pasta',
#   'milk',
#   'green tea',
#   'french fries',
#   'cookies',
#   'white wine',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['parmesan cheese',
#   'ground beef',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['pancakes',
#   'whole wheat rice',
#   'candy bars',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['eggs',
#   'eggplant',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen vegetables',
#   'mineral water',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'spaghetti',
#   'milk',
#   'whole wheat rice',
#   'chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'soup',
#   'meatballs',
#   'chicken',
#   'blueberries',
#   'cooking oil',
#   'champagne',
#   'yogurt cake',
#   'protein bar',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cooking oil',
#   'tomato juice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen vegetables',
#   'milk',
#   'eggs',
#   'french fries',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['fresh tuna',
#   'spaghetti',
#   'olive oil',
#   'french wine',
#   'eggs',
#   'french fries',
#   'champagne',
#   'pancakes',
#   'light mayo',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['red wine',
#   'honey',
#   'hot dogs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['milk',
#   'bacon',
#   'eggs',
#   'french fries',
#   'fresh bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['french fries',
#   'yogurt cake',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['milk',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'ham',
#   'red wine',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['shrimp',
#   'pasta',
#   'tomatoes',
#   'energy bar',
#   'french wine',
#   'antioxydant juice',
#   'french fries',
#   'frozen smoothie',
#   'brownies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'spinach',
#   'soda',
#   'energy drink',
#   'salt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['bug spray',
#   'hot dogs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['oil',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['soup',
#   'energy bar',
#   'chicken',
#   'eggs',
#   'cake',
#   'french fries',
#   'body spray',
#   'strawberries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['spaghetti',
#   'chocolate',
#   'yogurt cake',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'mineral water',
#   'meatballs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['ground beef',
#   'mineral water',
#   'chocolate',
#   'fromage blanc',
#   'bacon',
#   'hot dogs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen vegetables',
#   'mineral water',
#   'vegetables mix',
#   'escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['herb & pepper',
#   'red wine',
#   'tomatoes',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['whole wheat pasta',
#   'olive oil',
#   'cereals',
#   'brownies',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['olive oil',
#   'cookies',
#   'mushroom cream sauce',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['ground beef',
#   'pancakes',
#   'cooking oil',
#   'gluten free bar',
#   'light mayo',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mineral water',
#   'french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['herb & pepper',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['salmon',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['eggs',
#   'escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mineral water',
#   'tomato juice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mineral water',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['shrimp',
#   'mineral water',
#   'soup',
#   'black tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cake',
#   'frozen smoothie',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'burgers',
#   'grated cheese',
#   'tomatoes',
#   'chocolate',
#   'fromage blanc',
#   'honey',
#   'whole wheat rice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'olive oil',
#   'pancakes',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'burgers',
#   'ground beef',
#   'milk',
#   'olive oil',
#   'cake',
#   'fresh bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'yams',
#   'mineral water',
#   'soup',
#   'chutney',
#   'cereals',
#   'energy drink',
#   'protein bar',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['eggs',
#   'whole wheat rice',
#   'cake',
#   'green tea',
#   'escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['ground beef',
#   'yams',
#   'soup',
#   'avocado',
#   'salmon',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['milk',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['spaghetti',
#   'chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['whole wheat pasta',
#   'honey',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['whole wheat pasta',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['spaghetti',
#   'meatballs',
#   'vegetables mix',
#   'chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['eggs',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['fresh tuna',
#   'shrimp',
#   'pasta',
#   'mineral water',
#   'olive oil',
#   'eggs',
#   'cake',
#   'brownies',
#   'tomato juice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mineral water',
#   'green grapes',
#   'hot dogs',
#   'fresh bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen vegetables',
#   'meatballs',
#   'eggs',
#   'chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['meatballs',
#   'milk',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['escalope',
#   'pasta',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['pepper',
#   'chocolate',
#   'olive oil',
#   'french wine',
#   'salmon',
#   'rice',
#   'light mayo',
#   'fresh bread',
#   'magazines',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['red wine',
#   'french wine',
#   'vegetables mix',
#   'rice',
#   'clothes accessories',
#   'hot dogs',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'dessert wine',
#   'spaghetti',
#   'chicken',
#   'cake',
#   'protein bar',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['french wine',
#   'cake',
#   'fresh bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'frozen vegetables',
#   'flax seed',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['red wine',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['pepper',
#   'mineral water',
#   'energy bar',
#   'green grapes',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['milk',
#   'eggs',
#   'cake',
#   'chocolate',
#   'french fries',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['almonds',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'mineral water',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['milk',
#   'pancakes',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['pancakes',
#   'eggs',
#   'salt',
#   'tomato juice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mineral water',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['ham',
#   'spaghetti',
#   'mineral water',
#   'olive oil',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['salt',
#   'tomato juice',
#   'fresh bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['spaghetti',
#   'mushroom cream sauce',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['spaghetti',
#   'mineral water',
#   'eggs',
#   'pet food',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen vegetables',
#   'spaghetti',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['energy drink',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['muffins',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'milk',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['spaghetti',
#   'mineral water',
#   'eggs',
#   'cooking oil',
#   'chocolate',
#   'escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['shrimp',
#   'frozen vegetables',
#   'pepper',
#   'spaghetti',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'fresh tuna',
#   'red wine',
#   'mineral water',
#   'french fries',
#   'hand protein bar',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['pancakes',
#   'eggs',
#   'energy drink',
#   'fresh bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['strong cheese',
#   'salmon',
#   'green tea',
#   'french fries',
#   'frozen smoothie',
#   'hot dogs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['grated cheese',
#   'shrimp',
#   'pasta',
#   'tomatoes',
#   'milk',
#   'frozen smoothie',
#   'sandwich',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['herb & pepper',
#   'whole wheat pasta',
#   'olive oil',
#   'pancakes',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['spaghetti',
#   'antioxydant juice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['chocolate',
#   'milk',
#   'almonds',
#   'eggs',
#   'strawberries',
#   'white wine',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['french fries',
#   'strawberries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mineral water',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
# ...
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mushroom cream sauce',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['butter',
#   'mint green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['whole wheat rice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['gums',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mineral water',
#   'french fries',
#   'champagne',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cereals',
#   'salt',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['shrimp',
#   'spaghetti',
#   'chocolate',
#   'french fries',
#   'escalope',
#   'cookies',
#   'brownies',
#   'pancakes',
#   'melons',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['ham',
#   'spaghetti',
#   'yams',
#   'chicken',
#   'cooking oil',
#   'chocolate',
#   'hot dogs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['ground beef',
#   'olive oil',
#   'bug spray',
#   'frozen smoothie',
#   'hot dogs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen vegetables',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'olive oil',
#   'escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['whole wheat rice',
#   'oil',
#   'chicken',
#   'french fries',
#   'escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['parmesan cheese',
#   'whole wheat rice',
#   'escalope',
#   'champagne',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['fresh tuna',
#   'frozen vegetables',
#   'chicken',
#   'fromage blanc',
#   'honey',
#   'light mayo',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['ground beef',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['muffins',
#   'champagne',
#   'cookies',
#   'fresh bread',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen vegetables',
#   'spaghetti',
#   'chocolate',
#   'escalope',
#   'fresh bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['pickles',
#   'spaghetti',
#   'french fries',
#   'frozen smoothie',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['avocado',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['sandwich',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['spaghetti',
#   'milk',
#   'oil',
#   'shampoo',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['champagne',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['spaghetti',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['champagne',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['avocado',
#   'milk',
#   'butter',
#   'french fries',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'frozen vegetables',
#   'chicken',
#   'eggs',
#   'frozen smoothie',
#   'cauliflower',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'shrimp',
#   'tomatoes',
#   'milk',
#   'energy bar',
#   'almonds',
#   'chicken',
#   'chocolate',
#   'french fries',
#   'body spray',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'milk',
#   'cake',
#   'cooking oil',
#   'french fries',
#   'escalope',
#   'zucchini',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['tomatoes',
#   'spaghetti',
#   'chocolate',
#   'milk',
#   'olive oil',
#   'whole wheat rice',
#   'cake',
#   'frozen smoothie',
#   'protein bar',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['fresh tuna',
#   'red wine',
#   'pepper',
#   'spaghetti',
#   'fromage blanc',
#   'salmon',
#   'pancakes',
#   'eggs',
#   'honey',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['milk',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['shrimp',
#   'parmesan cheese',
#   'soup',
#   'chocolate',
#   'brownies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['spaghetti',
#   'chicken',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['grated cheese',
#   'vegetables mix',
#   'nonfat milk',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['fresh tuna',
#   'parmesan cheese',
#   'cider',
#   'muffins',
#   'spinach',
#   'honey',
#   'oil',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cake',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['shrimp',
#   'chocolate',
#   'mushroom cream sauce',
#   'candy bars',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['candy bars',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['avocado',
#   'honey',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['shrimp',
#   'frozen vegetables',
#   'tomatoes',
#   'cottage cheese',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['strawberries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['ground beef',
#   'almonds',
#   'french fries',
#   'escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['grated cheese',
#   'spaghetti',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'mineral water',
#   'butter',
#   'frozen smoothie',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen vegetables',
#   'spaghetti',
#   'french fries',
#   'light mayo',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'ham',
#   'spaghetti',
#   'whole wheat rice',
#   'eggplant',
#   'chocolate',
#   'cookies',
#   'shallot',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['grated cheese',
#   'frozen vegetables',
#   'spaghetti',
#   'avocado',
#   'milk',
#   'blueberries',
#   'light cream',
#   'rice',
#   'green tea',
#   'chocolate',
#   'french fries',
#   'frozen smoothie',
#   'cookies',
#   'hot dogs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'shrimp',
#   'tomatoes',
#   'bacon',
#   'whole wheat rice',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['parmesan cheese',
#   'pancakes',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['parmesan cheese',
#   'cake',
#   'hot dogs',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['spaghetti',
#   'milk',
#   'fromage blanc',
#   'ketchup',
#   'chocolate',
#   'babies food',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mint',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['chocolate',
#   'mint',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['butter',
#   'french fries',
#   'salt',
#   'fresh bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['chocolate',
#   'french fries',
#   'strawberries',
#   'yogurt cake',
#   'light mayo',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['eggs',
#   'eggplant',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['yogurt cake',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['herb & pepper',
#   'spaghetti',
#   'meatballs',
#   'milk',
#   'olive oil',
#   'chicken',
#   'honey',
#   'frozen smoothie',
#   'escalope',
#   'pancakes',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen vegetables',
#   'rice',
#   'chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['herb & pepper',
#   'ground beef',
#   'spaghetti',
#   'chocolate',
#   'milk',
#   'eggs',
#   'light cream',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['eggs',
#   'champagne',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['whole wheat pasta',
#   'ground beef',
#   'olive oil',
#   'blueberries',
#   'escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'red wine',
#   'mineral water',
#   'eggs',
#   'oil',
#   'carrots',
#   'hand protein bar',
#   'tomato juice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['chocolate',
#   'grated cheese',
#   'herb & pepper',
#   'mineral water',
#   'soup',
#   'olive oil',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'shrimp',
#   'mineral water',
#   'chicken',
#   'fromage blanc',
#   'salmon',
#   'eggs',
#   'cake',
#   'frozen smoothie',
#   'strawberries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['french fries',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['milk',
#   'butter',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['eggs',
#   'mushroom cream sauce',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['eggs',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mineral water',
#   'whole wheat rice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['shrimp',
#   'frozen vegetables',
#   'parmesan cheese',
#   'mineral water',
#   'whole wheat rice',
#   'cake',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['whole wheat rice',
#   'pancakes',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen vegetables',
#   'spaghetti',
#   'olive oil',
#   'butter',
#   'salmon',
#   'oil',
#   'cooking oil',
#   'frozen smoothie',
#   'cauliflower',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['fresh tuna',
#   'eggs',
#   'escalope',
#   'strawberries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['spaghetti',
#   'soup',
#   'milk',
#   'carrots',
#   'chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burgers',
#   'mineral water',
#   'soup',
#   'meatballs',
#   'olive oil',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['grated cheese',
#   'mineral water',
#   'cooking oil',
#   'french fries',
#   'cookies',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['shrimp',
#   'milk',
#   'olive oil',
#   'french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen vegetables',
#   'mineral water',
#   'pancakes',
#   'cake',
#   'tomato juice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['spaghetti',
#   'milk',
#   'chicken',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['grated cheese',
#   'mineral water',
#   'chicken',
#   'french fries',
#   'cottage cheese',
#   'pancakes',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['ground beef',
#   'mineral water',
#   'milk',
#   'eggs',
#   'mint',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['shrimp',
#   'body spray',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen smoothie',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['herb & pepper',
#   'frozen vegetables',
#   'mineral water',
#   'muffins',
#   'cereals',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'tomatoes',
#   'spaghetti',
#   'milk',
#   'cider',
#   'eggs',
#   'honey',
#   'cake',
#   'green tea',
#   'french fries',
#   'brownies',
#   'tomato juice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ...]

# %%
T = []
for i in range(len(df)):
    T.append([str(df.values[i,j]) for j in range(0,20)])

# %%
T
# Out:
# [['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['burgers', 'meatballs', 'eggs', 'nan'],
#  ['chutney', 'nan', 'nan', 'nan'],
#  ['turkey', 'avocado', 'nan', 'nan'],
#  ['mineral water', 'milk', 'energy bar', 'whole wheat rice'],
#  ['low fat yogurt', 'nan', 'nan', 'nan'],
#  ['whole wheat pasta', 'french fries', 'nan', 'nan'],
#  ['soup', 'light cream', 'shallot', 'nan'],
#  ['frozen vegetables', 'spaghetti', 'green tea', 'nan'],
#  ['french fries', 'nan', 'nan', 'nan'],
#  ['eggs', 'pet food', 'nan', 'nan'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['turkey', 'burgers', 'mineral water', 'eggs'],
#  ['spaghetti', 'champagne', 'cookies', 'nan'],
#  ['mineral water', 'salmon', 'nan', 'nan'],
#  ['mineral water', 'nan', 'nan', 'nan'],
#  ['shrimp', 'chocolate', 'chicken', 'honey'],
#  ['turkey', 'eggs', 'nan', 'nan'],
#  ['turkey', 'fresh tuna', 'tomatoes', 'spaghetti'],
#  ['meatballs', 'milk', 'honey', 'french fries'],
#  ['red wine', 'shrimp', 'pasta', 'pepper'],
#  ['rice', 'sparkling water', 'nan', 'nan'],
#  ['spaghetti', 'mineral water', 'ham', 'body spray'],
#  ['burgers', 'grated cheese', 'shrimp', 'pasta'],
#  ['eggs', 'nan', 'nan', 'nan'],
#  ['parmesan cheese', 'spaghetti', 'soup', 'avocado'],
#  ['ground beef', 'spaghetti', 'mineral water', 'milk'],
#  ['sparkling water', 'nan', 'nan', 'nan'],
#  ['mineral water', 'eggs', 'chicken', 'chocolate'],
#  ['frozen vegetables', 'spaghetti', 'yams', 'mineral water'],
#  ['herb & pepper', 'tomato sauce', 'light cream', 'magazines'],
#  ['mineral water', 'chocolate', 'avocado', 'eggs'],
#  ['turkey', 'french fries', 'strawberries', 'nan'],
#  ['frozen vegetables', 'strong cheese', 'chocolate', 'nan'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['pickles', 'spaghetti', 'salmon', 'escalope'],
#  ['energy bar', 'french fries', 'nan', 'nan'],
#  ['red wine', 'ground beef', 'mineral water', 'nan'],
#  ['mineral water', 'cake', 'cottage cheese', 'nan'],
#  ['pickles', 'champagne', 'green tea', 'nan'],
#  ['spaghetti', 'nan', 'nan', 'nan'],
#  ['fresh tuna', 'frozen vegetables', 'spaghetti', 'mineral water'],
#  ['spaghetti', 'nan', 'nan', 'nan'],
#  ['soup', 'meatballs', 'hot dogs', 'sparkling water'],
#  ['escalope', 'nan', 'nan', 'nan'],
#  ['soup', 'avocado', 'french fries', 'hot dogs'],
#  ['mineral water', 'chicken', 'cereals', 'clothes accessories'],
#  ['mineral water', 'bug spray', 'nan', 'nan'],
#  ['avocado', 'muffins', 'nan', 'nan'],
#  ['burgers', 'black tea', 'green tea', 'nan'],
#  ['spaghetti', 'chocolate', 'brownies', 'white wine'],
#  ['fresh tuna', 'mineral water', 'eggs', 'nan'],
#  ['spaghetti', 'muffins', 'nan', 'nan'],
#  ['spaghetti', 'chocolate', 'nan', 'nan'],
#  ['french fries', 'escalope', 'champagne', 'nan'],
#  ['tomato sauce', 'light mayo', 'nan', 'nan'],
#  ['turkey', 'fresh tuna', 'frozen vegetables', 'tomatoes'],
#  ['eggs', 'cookies', 'nan', 'nan'],
#  ['soup', 'chicken', 'gums', 'soda'],
#  ['turkey', 'frozen vegetables', 'mineral water', 'cider'],
#  ['spaghetti', 'nan', 'nan', 'nan'],
#  ['clothes accessories', 'nan', 'nan', 'nan'],
#  ['energy drink', 'nan', 'nan', 'nan'],
#  ['soup', 'bug spray', 'shallot', 'protein bar'],
#  ['turkey', 'eggs', 'nan', 'nan'],
#  ['french fries', 'nan', 'nan', 'nan'],
#  ['chocolate', 'milk', 'nan', 'nan'],
#  ['herb & pepper', 'whole wheat pasta', 'ground beef', 'mineral water'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['shrimp', 'pasta', 'nan', 'nan'],
#  ['grated cheese', 'herb & pepper', 'tomatoes', 'tomato sauce'],
#  ['burgers', 'escalope', 'shallot', 'nan'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['yogurt cake', 'nan', 'nan', 'nan'],
#  ['soup', 'eggs', 'nan', 'nan'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['mineral water', 'chocolate', 'low fat yogurt', 'nan'],
#  ['eggs', 'strawberries', 'nan', 'nan'],
#  ['grated cheese', 'ground beef', 'spaghetti', 'mineral water'],
#  ['mint', 'nan', 'nan', 'nan'],
#  ['eggs', 'cake', 'french fries', 'nan'],
#  ['burgers', 'spaghetti', 'milk', 'french fries'],
#  ['mineral water', 'energy bar', 'butter', 'french fries'],
#  ['burgers', 'grated cheese', 'herb & pepper', 'mineral water'],
#  ['energy bar', 'nan', 'nan', 'nan'],
#  ['energy bar', 'energy drink', 'nan', 'nan'],
#  ['chocolate', 'frozen smoothie', 'nan', 'nan'],
#  ['low fat yogurt', 'nan', 'nan', 'nan'],
#  ['asparagus', 'salad', 'nan', 'nan'],
#  ['burgers', 'french fries', 'low fat yogurt', 'green tea'],
#  ['low fat yogurt', 'nan', 'nan', 'nan'],
#  ['burgers', 'herb & pepper', 'shrimp', 'pasta'],
#  ['champagne', 'low fat yogurt', 'nan', 'nan'],
#  ['champagne', 'nan', 'nan', 'nan'],
#  ['burgers', 'almonds', 'eggs', 'french fries'],
#  ['ham', 'soup', 'escalope', 'body spray'],
#  ['turkey', 'ham', 'frozen vegetables', 'pepper'],
#  ['muffins', 'eggs', 'cookies', 'nan'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['frozen vegetables', 'whole wheat pasta', 'ground beef', 'spaghetti'],
#  ['mineral water', 'barbecue sauce', 'chocolate', 'nan'],
#  ['burgers', 'herb & pepper', 'energy bar', 'almonds'],
#  ['turkey', 'burgers', 'ground beef', 'chocolate'],
#  ['ham', 'spaghetti', 'chocolate', 'eggs'],
#  ['ground beef', 'energy bar', 'pet food', 'carrots'],
#  ['ground beef', 'tomato sauce', 'spaghetti', 'mineral water'],
#  ['mineral water', 'olive oil', 'gums', 'cooking oil'],
#  ['shrimp', 'pasta', 'mineral water', 'soup'],
#  ['shrimp', 'pasta', 'soup', 'cake'],
#  ['spaghetti', 'mineral water', 'chocolate', 'french fries'],
#  ['shrimp', 'pasta', 'mineral water', 'eggs'],
#  ['burgers', 'oil', 'tomato juice', 'fresh bread'],
#  ['french wine', 'eggs', 'chocolate', 'low fat yogurt'],
#  ['chicken', 'eggs', 'french fries', 'pancakes'],
#  ['turkey', 'herb & pepper', 'salmon', 'white wine'],
#  ['grated cheese', 'spaghetti', 'olive oil', 'eggs'],
#  ['mineral water', 'energy bar', 'nan', 'nan'],
#  ['eggs', 'french fries', 'nan', 'nan'],
#  ['burgers', 'tomatoes', 'mineral water', 'soup'],
#  ['muffins', 'nan', 'nan', 'nan'],
#  ['pasta', 'nan', 'nan', 'nan'],
#  ['tomatoes', 'spaghetti', 'frozen smoothie', 'nan'],
#  ['ground beef', 'spaghetti', 'milk', 'nan'],
#  ['french fries', 'nan', 'nan', 'nan'],
#  ['chocolate', 'milk', 'nan', 'nan'],
#  ['burgers', 'shrimp', 'pasta', 'frozen vegetables'],
#  ['ground beef', 'mineral water', 'antioxydant juice', 'protein bar'],
#  ['grated cheese', 'whole wheat pasta', 'ground beef', 'spaghetti'],
#  ['grated cheese', 'nan', 'nan', 'nan'],
#  ['pancakes', 'nan', 'nan', 'nan'],
#  ['frozen smoothie', 'nan', 'nan', 'nan'],
#  ['carrots', 'green tea', 'nan', 'nan'],
#  ['chocolate', 'nan', 'nan', 'nan'],
#  ['turkey', 'burgers', 'chocolate', 'olive oil'],
#  ['frozen vegetables', 'tomatoes', 'pepper', 'spaghetti'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['ground beef', 'nan', 'nan', 'nan'],
#  ['turkey', 'eggs', 'chocolate', 'frozen smoothie'],
#  ['frozen vegetables', 'cooking oil', 'mashed potato', 'nan'],
#  ['frozen vegetables', 'ground beef', 'tomato sauce', 'mineral water'],
#  ['red wine', 'spaghetti', 'mineral water', 'soup'],
#  ['chocolate', 'tomatoes', 'spaghetti', 'mineral water'],
#  ['chocolate', 'shrimp', 'pasta', 'frozen vegetables'],
#  ['turkey', 'shrimp', 'pasta', 'pepper'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['turkey', 'tomatoes', 'cake', 'nan'],
#  ['yams', 'mineral water', 'soup', 'milk'],
#  ['rice', 'nan', 'nan', 'nan'],
#  ['chocolate', 'milk', 'nan', 'nan'],
#  ['shrimp', 'pasta', 'frozen vegetables', 'water spray'],
#  ['burgers', 'mineral water', 'milk', 'eggs'],
#  ['mineral water', 'vegetables mix', 'cake', 'frozen smoothie'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['shrimp', 'pasta', 'chicken', 'chocolate bread'],
#  ['shallot', 'nan', 'nan', 'nan'],
#  ['shrimp', 'pasta', 'spaghetti', 'eggs'],
#  ['burgers', 'nan', 'nan', 'nan'],
#  ['red wine', 'ground beef', 'spaghetti', 'mineral water'],
#  ['burgers', 'grated cheese', 'spaghetti', 'avocado'],
#  ['herb & pepper', 'whole wheat pasta', 'ground beef', 'mineral water'],
#  ['shrimp', 'pasta', 'yams', 'milk'],
#  ['butter', 'green tea', 'nan', 'nan'],
#  ['light mayo', 'nan', 'nan', 'nan'],
#  ['low fat yogurt', 'nan', 'nan', 'nan'],
#  ['herb & pepper', 'shrimp', 'pasta', 'spaghetti'],
#  ['burgers', 'eggs', 'nan', 'nan'],
#  ['turkey', 'herb & pepper', 'ground beef', 'soup'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['escalope', 'nan', 'nan', 'nan'],
#  ['pepper', 'french fries', 'strawberries', 'pancakes'],
#  ['frozen vegetables', 'yams', 'chicken', 'honey'],
#  ['chocolate', 'champagne', 'nan', 'nan'],
#  ['herb & pepper', 'honey', 'cake', 'rice'],
#  ['burgers', 'chocolate', 'frozen vegetables', 'ground beef'],
#  ['chocolate', 'mineral water', 'corn', 'cottage cheese'],
#  ['muffins', 'nan', 'nan', 'nan'],
#  ['ham', 'french wine', 'escalope', 'nan'],
#  ['spaghetti', 'milk', 'whole wheat rice', 'mint green tea'],
#  ['chocolate', 'body spray', 'nan', 'nan'],
#  ['frozen vegetables', 'french fries', 'hot dogs', 'nan'],
#  ['candy bars', 'nan', 'nan', 'nan'],
#  ['burgers', 'shrimp', 'pasta', 'milk'],
#  ['parmesan cheese', 'ground beef', 'nan', 'nan'],
#  ['pancakes', 'whole wheat rice', 'candy bars', 'nan'],
#  ['eggs', 'eggplant', 'cookies', 'nan'],
#  ['frozen vegetables', 'mineral water', 'nan', 'nan'],
#  ['chocolate', 'nan', 'nan', 'nan'],
#  ['turkey', 'spaghetti', 'milk', 'whole wheat rice'],
#  ['whole wheat pasta', 'ground beef', 'spaghetti', 'soup'],
#  ['cooking oil', 'tomato juice', 'nan', 'nan'],
#  ['frozen vegetables', 'milk', 'eggs', 'french fries'],
#  ['fresh tuna', 'spaghetti', 'olive oil', 'french wine'],
#  ['red wine', 'honey', 'hot dogs', 'nan'],
#  ['milk', 'bacon', 'eggs', 'french fries'],
#  ['french fries', 'yogurt cake', 'nan', 'nan'],
#  ['milk', 'nan', 'nan', 'nan'],
#  ['french fries', 'nan', 'nan', 'nan'],
#  ['chocolate', 'nan', 'nan', 'nan'],
#  ['burgers', 'ham', 'red wine', 'nan'],
#  ['shrimp', 'pasta', 'tomatoes', 'energy bar'],
#  ['green tea', 'nan', 'nan', 'nan'],
#  ['low fat yogurt', 'nan', 'nan', 'nan'],
#  ['turkey', 'spaghetti', 'mineral water', 'soup'],
#  ['turkey', 'eggs', 'nan', 'nan'],
#  ['bug spray', 'hot dogs', 'nan', 'nan'],
#  ['oil', 'nan', 'nan', 'nan'],
#  ['soup', 'energy bar', 'chicken', 'eggs'],
#  ['spaghetti', 'chocolate', 'yogurt cake', 'nan'],
#  ['turkey', 'mineral water', 'meatballs', 'nan'],
#  ['ground beef', 'mineral water', 'chocolate', 'fromage blanc'],
#  ['frozen vegetables', 'mineral water', 'vegetables mix', 'escalope'],
#  ['herb & pepper', 'red wine', 'tomatoes', 'nan'],
#  ['whole wheat pasta', 'olive oil', 'cereals', 'brownies'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['olive oil', 'cookies', 'mushroom cream sauce', 'nan'],
#  ['ground beef', 'pancakes', 'cooking oil', 'gluten free bar'],
#  ['mineral water', 'french fries', 'nan', 'nan'],
#  ['herb & pepper', 'nan', 'nan', 'nan'],
#  ['salmon', 'nan', 'nan', 'nan'],
#  ['eggs', 'escalope', 'nan', 'nan'],
#  ['mineral water', 'tomato juice', 'nan', 'nan'],
#  ['mineral water', 'nan', 'nan', 'nan'],
#  ['shrimp', 'mineral water', 'soup', 'black tea'],
#  ['cake', 'frozen smoothie', 'nan', 'nan'],
#  ['turkey', 'burgers', 'grated cheese', 'tomatoes'],
#  ['frozen vegetables', 'ground beef', 'mineral water', 'olive oil'],
#  ['turkey', 'burgers', 'ground beef', 'milk'],
#  ['whole wheat pasta', 'ground beef', 'spaghetti', 'yams'],
#  ['eggs', 'whole wheat rice', 'cake', 'green tea'],
#  ['ground beef', 'yams', 'soup', 'avocado'],
#  ['milk', 'nan', 'nan', 'nan'],
#  ['spaghetti', 'chocolate', 'nan', 'nan'],
#  ['whole wheat pasta', 'honey', 'nan', 'nan'],
#  ['whole wheat pasta', 'green tea', 'nan', 'nan'],
#  ['spaghetti', 'meatballs', 'vegetables mix', 'chocolate'],
#  ['eggs', 'low fat yogurt', 'nan', 'nan'],
#  ['fresh tuna', 'shrimp', 'pasta', 'mineral water'],
#  ['mineral water', 'green grapes', 'hot dogs', 'fresh bread'],
#  ['frozen vegetables', 'meatballs', 'eggs', 'chocolate'],
#  ['chocolate', 'nan', 'nan', 'nan'],
#  ['meatballs', 'milk', 'nan', 'nan'],
#  ['low fat yogurt', 'nan', 'nan', 'nan'],
#  ['green tea', 'nan', 'nan', 'nan'],
#  ['escalope', 'pasta', 'nan', 'nan'],
#  ['pepper', 'chocolate', 'olive oil', 'french wine'],
#  ['red wine', 'french wine', 'vegetables mix', 'rice'],
#  ['burgers', 'dessert wine', 'spaghetti', 'chicken'],
#  ['french wine', 'cake', 'fresh bread', 'nan'],
#  ['burgers', 'frozen vegetables', 'flax seed', 'eggs'],
#  ['red wine', 'nan', 'nan', 'nan'],
#  ['pepper', 'mineral water', 'energy bar', 'green grapes'],
#  ['milk', 'eggs', 'cake', 'chocolate'],
#  ['french fries', 'nan', 'nan', 'nan'],
#  ['almonds', 'nan', 'nan', 'nan'],
#  ['burgers', 'mineral water', 'green tea', 'nan'],
#  ['milk', 'pancakes', 'nan', 'nan'],
#  ['pancakes', 'eggs', 'salt', 'tomato juice'],
#  ['mineral water', 'nan', 'nan', 'nan'],
#  ['ham', 'spaghetti', 'mineral water', 'olive oil'],
#  ['salt', 'tomato juice', 'fresh bread', 'nan'],
#  ['spaghetti', 'mushroom cream sauce', 'nan', 'nan'],
#  ['spaghetti', 'mineral water', 'eggs', 'pet food'],
#  ['frozen vegetables', 'spaghetti', 'nan', 'nan'],
#  ['energy drink', 'nan', 'nan', 'nan'],
#  ['muffins', 'nan', 'nan', 'nan'],
#  ['turkey', 'milk', 'nan', 'nan'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['chocolate', 'nan', 'nan', 'nan'],
#  ['spaghetti', 'mineral water', 'eggs', 'cooking oil'],
#  ['shrimp', 'frozen vegetables', 'pepper', 'spaghetti'],
#  ['burgers', 'fresh tuna', 'red wine', 'mineral water'],
#  ['pancakes', 'eggs', 'energy drink', 'fresh bread'],
#  ['strong cheese', 'salmon', 'green tea', 'french fries'],
#  ['grated cheese', 'shrimp', 'pasta', 'tomatoes'],
#  ['herb & pepper', 'whole wheat pasta', 'olive oil', 'pancakes'],
#  ['spaghetti', 'antioxydant juice', 'nan', 'nan'],
#  ['chocolate', 'milk', 'almonds', 'eggs'],
#  ['french fries', 'strawberries', 'nan', 'nan'],
#  ['mineral water', 'nan', 'nan', 'nan'],
#  ['eggs', 'nan', 'nan', 'nan'],
#  ['escalope', 'nan', 'nan', 'nan'],
#  ['cake', 'nan', 'nan', 'nan'],
#  ['whole wheat pasta', 'antioxydant juice', 'body spray', 'green tea'],
#  ['mineral water', 'oil', 'frozen smoothie', 'nan'],
#  ['french fries', 'champagne', 'nan', 'nan'],
#  ['chocolate', 'french fries', 'nan', 'nan'],
#  ['frozen vegetables', 'spaghetti', 'eggs', 'nan'],
#  ['hot dogs', 'nan', 'nan', 'nan'],
#  ['chocolate', 'cookies', 'nan', 'nan'],
#  ['pancakes', 'nan', 'nan', 'nan'],
#  ['shrimp', 'butter', 'chicken', 'salmon'],
#  ['chocolate', 'cookies', 'babies food', 'nan'],
#  ['pepper', 'spaghetti', 'cake', 'chocolate'],
#  ['avocado', 'oil', 'cereals', 'french fries'],
#  ['herb & pepper', 'spaghetti', 'mineral water', 'spinach'],
#  ['herb & pepper', 'frozen vegetables', 'ground beef', 'pepper'],
#  ['french fries', 'nan', 'nan', 'nan'],
#  ['green tea', 'tomato juice', 'nan', 'nan'],
#  ['eggs', 'whole wheat rice', 'chocolate', 'nan'],
#  ['grated cheese', 'herb & pepper', 'red wine', 'spaghetti'],
#  ['french fries', 'cookies', 'shallot', 'tomato juice'],
#  ['burgers', 'fresh tuna', 'spaghetti', 'muffins'],
#  ['herb & pepper', 'ground beef', 'spaghetti', 'eggs'],
#  ['grated cheese', 'muffins', 'tomato juice', 'mayonnaise'],
#  ['whole wheat pasta', 'yams', 'mineral water', 'muffins'],
#  ['burgers', 'spaghetti', 'soup', 'milk'],
#  ['chocolate', 'champagne', 'magazines', 'nan'],
#  ['frozen vegetables', 'spaghetti', 'yams', 'mineral water'],
#  ['tomato sauce', 'chocolate', 'nan', 'nan'],
#  ['milk', 'eggs', 'nan', 'nan'],
#  ['pet food', 'nan', 'nan', 'nan'],
#  ['yogurt cake', 'nan', 'nan', 'nan'],
#  ['green tea', 'nan', 'nan', 'nan'],
#  ['escalope', 'pasta', 'nan', 'nan'],
#  ['herb & pepper', 'ground beef', 'nan', 'nan'],
#  ['mineral water', 'honey', 'brownies', 'nan'],
#  ['turkey', 'eggs', 'cake', 'energy drink'],
#  ['turkey', 'burgers', 'dessert wine', 'ground beef'],
#  ['spaghetti', 'mineral water', 'chicken', 'nan'],
#  ['turkey', 'ground beef', 'carrots', 'french fries'],
#  ['mineral water', 'eggs', 'low fat yogurt', 'nan'],
#  ['turkey', 'cooking oil', 'shampoo', 'nan'],
#  ['spaghetti', 'hot dogs', 'nan', 'nan'],
#  ['chocolate', 'green tea', 'nan', 'nan'],
#  ['grated cheese', 'pepper', 'mineral water', 'chocolate'],
#  ['chocolate', 'nan', 'nan', 'nan'],
#  ['spaghetti', 'olive oil', 'strong cheese', 'pancakes'],
#  ['red wine', 'mineral water', 'soup', 'rice'],
#  ['red wine', 'shrimp', 'spaghetti', 'nan'],
#  ['green tea', 'nan', 'nan', 'nan'],
#  ['mineral water', 'chicken', 'french fries', 'frozen smoothie'],
#  ['muffins', 'nan', 'nan', 'nan'],
#  ['cake', 'chocolate', 'nan', 'nan'],
#  ['fresh tuna', 'tomatoes', 'mineral water', 'soup'],
#  ['turkey', 'french fries', 'nan', 'nan'],
#  ['burgers', 'turkey', 'herb & pepper', 'ground beef'],
#  ['escalope', 'nan', 'nan', 'nan'],
#  ['chocolate', 'escalope', 'fresh bread', 'nan'],
#  ['ham', 'spaghetti', 'french wine', 'vegetables mix'],
#  ['avocado', 'light mayo', 'nan', 'nan'],
#  ['spaghetti', 'yams', 'butter', 'chocolate'],
#  ['energy bar', 'eggs', 'french fries', 'nan'],
#  ['fresh tuna', 'barbecue sauce', 'eggplant', 'nan'],
#  ['energy drink', 'nan', 'nan', 'nan'],
#  ['whole wheat rice', 'french fries', 'hot dogs', 'green tea'],
#  ['mineral water', 'chicken', 'green tea', 'nan'],
#  ['eggs', 'cake', 'mushroom cream sauce', 'nan'],
#  ['escalope', 'nan', 'nan', 'nan'],
#  ['antioxydant juice', 'escalope', 'nan', 'nan'],
#  ['shrimp', 'spaghetti', 'french fries', 'nan'],
#  ['grated cheese', 'spaghetti', 'salmon', 'tomato juice'],
#  ['spaghetti', 'green tea', 'nan', 'nan'],
#  ['champagne', 'protein bar', 'nan', 'nan'],
#  ['mineral water', 'avocado', 'chocolate', 'nan'],
#  ['tomatoes', 'champagne', 'green tea', 'nan'],
#  ['chicken', 'french fries', 'escalope', 'nan'],
#  ['frozen vegetables', 'tomatoes', 'eggs', 'green tea'],
#  ['ground beef', 'chicken', 'cider', 'green grapes'],
#  ['french fries', 'champagne', 'nan', 'nan'],
#  ['mineral water', 'soup', 'nan', 'nan'],
#  ['frozen vegetables', 'spaghetti', 'milk', 'chocolate'],
#  ['honey', 'whole wheat rice', 'nan', 'nan'],
#  ['whole wheat rice', 'chicken', 'tomato juice', 'nan'],
#  ['pancakes', 'nan', 'nan', 'nan'],
#  ['green tea', 'protein bar', 'tomato juice', 'candy bars'],
#  ['french fries', 'nan', 'nan', 'nan'],
#  ['mineral water', 'nan', 'nan', 'nan'],
#  ['escalope', 'nan', 'nan', 'nan'],
#  ['grated cheese', 'herb & pepper', 'whole wheat pasta', 'yams'],
#  ['spaghetti', 'milk', 'nan', 'nan'],
#  ['milk', 'chocolate', 'white wine', 'nan'],
#  ['sandwich', 'nan', 'nan', 'nan'],
#  ['chocolate', 'light mayo', 'nan', 'nan'],
#  ['shrimp', 'whole wheat pasta', 'spaghetti', 'meatballs'],
#  ['red wine', 'ground beef', 'spaghetti', 'mineral water'],
#  ['yams', 'melons', 'nan', 'nan'],
#  ['spaghetti', 'cooking oil', 'nan', 'nan'],
#  ['french fries', 'nan', 'nan', 'nan'],
#  ['mineral water', 'milk', 'spinach', 'cooking oil'],
#  ['tomato sauce', 'milk', 'nan', 'nan'],
#  ['shrimp', 'cider', 'eggs', 'french fries'],
#  ['champagne', 'nan', 'nan', 'nan'],
#  ['salad', 'nan', 'nan', 'nan'],
#  ['french fries', 'nan', 'nan', 'nan'],
#  ['frozen vegetables', 'mineral water', 'energy bar', 'honey'],
#  ['french fries', 'salad', 'nan', 'nan'],
#  ['honey', 'chocolate', 'french fries', 'brownies'],
#  ['green tea', 'strawberries', 'gluten free bar', 'nan'],
#  ['frozen vegetables', 'ground beef', 'mineral water', 'salmon'],
#  ['grated cheese', 'tomatoes', 'mineral water', 'meatballs'],
#  ['shrimp', 'chocolate', 'water spray', 'nan'],
#  ['turkey', 'nan', 'nan', 'nan'],
#  ['turkey', 'eggs', 'nan', 'nan'],
#  ['turkey', 'frozen vegetables', 'tomatoes', 'soup'],
#  ['spaghetti', 'nan', 'nan', 'nan'],
#  ['milk', 'frozen smoothie', 'low fat yogurt', 'nan'],
#  ['burgers', 'mineral water', 'milk', 'whole wheat rice'],
#  ['mineral water', 'nan', 'nan', 'nan'],
#  ['tomatoes', 'mineral water', 'soup', 'cake'],
#  ['mineral water', 'nan', 'nan', 'nan'],
#  ['ground beef', 'spaghetti', 'nan', 'nan'],
#  ['pepper', 'frozen smoothie', 'nan', 'nan'],
#  ['yogurt cake', 'nan', 'nan', 'nan'],
#  ['red wine', 'pancakes', 'nan', 'nan'],
#  ['candy bars', 'nan', 'nan', 'nan'],
#  ['eggs', 'french fries', 'low fat yogurt', 'nan'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['spaghetti', 'soup', 'vegetables mix', 'spinach'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['soup', 'olive oil', 'eggs', 'soda'],
#  ['chocolate', 'frozen smoothie', 'low fat yogurt', 'nan'],
#  ['spaghetti', 'mineral water', 'milk', 'pancakes'],
#  ['mineral water', 'nan', 'nan', 'nan'],
#  ['herb & pepper', 'frozen vegetables', 'tomato sauce', 'mineral water'],
#  ['burgers', 'eggs', 'nan', 'nan'],
#  ['french fries', 'nan', 'nan', 'nan'],
#  ['frozen smoothie', 'cottage cheese', 'nan', 'nan'],
#  ['tomatoes', 'mineral water', 'chocolate', 'light mayo'],
#  ['salmon', 'escalope', 'shallot', 'strawberries'],
#  ['energy bar', 'nan', 'nan', 'nan'],
#  ['red wine', 'ground beef', 'spaghetti', 'pancakes'],
#  ['ground beef', 'spaghetti', 'mineral water', 'milk'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['salmon', 'escalope', 'nan', 'nan'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['low fat yogurt', 'nan', 'nan', 'nan'],
#  ['eggs', 'nan', 'nan', 'nan'],
#  ['red wine', 'butter', 'hot dogs', 'nan'],
#  ['tomatoes', 'mineral water', 'soup', 'mashed potato'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['parmesan cheese', 'ground beef', 'salmon', 'pancakes'],
#  ['ground beef', 'yams', 'chocolate', 'olive oil'],
#  ['shrimp', 'salmon', 'eggs', 'cookies'],
#  ['magazines', 'mint', 'nan', 'nan'],
#  ['turkey', 'mineral water', 'eggs', 'cooking oil'],
#  ['mineral water', 'mushroom cream sauce', 'nan', 'nan'],
#  ['grated cheese', 'frozen vegetables', 'mineral water', 'soup'],
#  ['chocolate', 'cake', 'nan', 'nan'],
#  ['burgers', 'salt', 'white wine', 'nan'],
#  ['energy drink', 'nan', 'nan', 'nan'],
#  ['olive oil', 'cake', 'energy drink', 'nan'],
#  ['ground beef', 'whole wheat rice', 'nan', 'nan'],
#  ['eggs', 'french fries', 'nan', 'nan'],
#  ['spaghetti', 'escalope', 'mushroom cream sauce', 'nan'],
#  ['mineral water', 'fromage blanc', 'whole wheat rice', 'cake'],
#  ['turkey', 'burgers', 'frozen vegetables', 'ground beef'],
#  ['green tea', 'cottage cheese', 'nan', 'nan'],
#  ['fresh tuna', 'eggs', 'champagne', 'nan'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['tomatoes', 'mineral water', 'eggplant', 'nan'],
#  ['grated cheese', 'tomatoes', 'spaghetti', 'mineral water'],
#  ['protein bar', 'nan', 'nan', 'nan'],
#  ['herb & pepper', 'red wine', 'shrimp', 'mineral water'],
#  ['burgers', 'ham', 'spaghetti', 'mineral water'],
#  ['french fries', 'nan', 'nan', 'nan'],
#  ['frozen vegetables', 'soup', 'milk', 'eggs'],
#  ['spaghetti', 'nan', 'nan', 'nan'],
#  ['herb & pepper', 'shrimp', 'soup', 'eggs'],
#  ['ham', 'grated cheese', 'herb & pepper', 'shrimp'],
#  ['ham', 'red wine', 'ground beef', 'yams'],
#  ['chocolate', 'french fries', 'mushroom cream sauce', 'cottage cheese'],
#  ['eggs', 'nan', 'nan', 'nan'],
#  ['cake', 'cookies', 'nan', 'nan'],
#  ['grated cheese', 'mineral water', 'cake', 'chocolate bread'],
#  ['tomatoes', 'almonds', 'cake', 'champagne'],
#  ['herb & pepper', 'shrimp', 'frozen vegetables', 'milk'],
#  ['herb & pepper', 'shrimp', 'whole wheat pasta', 'whole wheat rice'],
#  ['eggs', 'corn', 'nan', 'nan'],
#  ['shrimp', 'frozen vegetables', 'tomato sauce', 'mineral water'],
#  ['ham', 'herb & pepper', 'tomato sauce', 'mineral water'],
#  ['energy bar', 'cake', 'chocolate', 'nan'],
#  ['herb & pepper', 'shrimp', 'spaghetti', 'eggs'],
#  ['fresh tuna', 'mineral water', 'honey', 'cooking oil'],
#  ['red wine', 'mineral water', 'oil', 'ketchup'],
#  ['herb & pepper', 'shrimp', 'mineral water', 'pancakes'],
#  ['ground beef', 'mineral water', 'protein bar', 'nan'],
#  ['shrimp', 'frozen vegetables', 'parmesan cheese', 'spaghetti'],
#  ['milk', 'chocolate', 'nan', 'nan'],
#  ['frozen vegetables', 'ground beef', 'spaghetti', 'olive oil'],
#  ['turkey', 'ground beef', 'low fat yogurt', 'nan'],
#  ['herb & pepper', 'spaghetti', 'mineral water', 'whole wheat rice'],
#  ['green tea', 'nan', 'nan', 'nan'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['eggs', 'cookies', 'nan', 'nan'],
#  ['spaghetti', 'eggs', 'ham', 'chocolate'],
#  ['red wine', 'spaghetti', 'milk', 'eggs'],
#  ['turkey', 'burgers', 'pancakes', 'french fries'],
#  ['escalope', 'nan', 'nan', 'nan'],
#  ['frozen vegetables', 'pancakes', 'eggs', 'cake'],
#  ['french fries', 'nan', 'nan', 'nan'],
#  ['turkey', 'ground beef', 'pepper', 'spaghetti'],
#  ['chocolate', 'red wine', 'tomato sauce', 'olive oil'],
#  ['green tea', 'french fries', 'nan', 'nan'],
#  ['mineral water', 'nan', 'nan', 'nan'],
#  ['cooking oil', 'nan', 'nan', 'nan'],
#  ['frozen vegetables', 'spaghetti', 'nan', 'nan'],
#  ['ham', 'spaghetti', 'nan', 'nan'],
#  ['chicken', 'chocolate', 'cookies', 'nan'],
#  ['low fat yogurt', 'nan', 'nan', 'nan'],
#  ['eggs', 'cake', 'low fat yogurt', 'nan'],
#  ['shrimp', 'spaghetti', 'mineral water', 'soup'],
#  ['mineral water', 'eggs', 'protein bar', 'nan'],
#  ['turkey', 'shrimp', 'meatballs', 'butter'],
#  ['fresh tuna', 'spaghetti', 'chocolate', 'olive oil'],
#  ['turkey', 'shrimp', 'escalope', 'hot dogs'],
#  ['burgers', 'pepper', 'soup', 'milk'],
#  ['pancakes', 'nan', 'nan', 'nan'],
#  ['mineral water', 'pancakes', 'eggs', 'french fries'],
#  ['eggs', 'escalope', 'low fat yogurt', 'nan'],
#  ['mineral water', 'french wine', 'gluten free bar', 'nan'],
#  ['burgers', 'ground beef', 'spaghetti', 'eggs'],
#  ['soup', 'meatballs', 'milk', 'energy bar'],
#  ['chocolate', 'nan', 'nan', 'nan'],
#  ['herb & pepper', 'nan', 'nan', 'nan'],
#  ['turkey', 'red wine', 'mineral water', 'eggs'],
#  ['burgers', 'ham', 'frozen vegetables', 'tomatoes'],
#  ['grated cheese', 'mineral water', 'olive oil', 'energy bar'],
#  ['milk', 'cake', 'green tea', 'nan'],
#  ['mineral water', 'almonds', 'cooking oil', 'cereals'],
#  ['turkey', 'fresh tuna', 'mineral water', 'milk'],
#  ['herb & pepper', 'mineral water', 'whole wheat rice', 'yogurt cake'],
#  ['tomatoes', 'spaghetti', 'meatballs', 'chicken'],
#  ['burgers', 'mineral water', 'eggs', 'green tea'],
#  ['cake', 'green tea', 'nan', 'nan'],
#  ['chocolate', 'herb & pepper', 'yogurt cake', 'nan'],
#  ['ground beef', 'spaghetti', 'mineral water', 'almonds'],
#  ['mineral water', 'vegetables mix', 'eggs', 'nan'],
#  ['protein bar', 'nan', 'nan', 'nan'],
#  ['eggs', 'eggplant', 'nan', 'nan'],
#  ['mayonnaise', 'nan', 'nan', 'nan'],
#  ['milk', 'bug spray', 'oatmeal', 'sandwich'],
#  ['frozen vegetables', 'soup', 'almonds', 'eggs'],
#  ['frozen vegetables', 'nan', 'nan', 'nan'],
#  ['soup', 'butter', 'shampoo', 'nan'],
#  ['herb & pepper', 'whole wheat pasta', 'pepper', 'eggs'],
#  ['mineral water', 'whole wheat rice', 'rice', 'cooking oil'],
#  ['grated cheese', 'butter', 'chocolate', 'french fries'],
#  ['spaghetti', 'soup', 'milk', 'chutney'],
#  ['eggs', 'french fries', 'frozen smoothie', 'cookies'],
#  ['turkey', 'tomatoes', 'mineral water', 'eggs'],
#  ['milk', 'tomato juice', 'low fat yogurt', 'green tea'],
#  ['mineral water', 'soup', 'almonds', 'cereals'],
#  ['chocolate', 'light mayo', 'nan', 'nan'],
#  ['turkey', 'herb & pepper', 'chocolate', 'nan'],
#  ['eggs', 'french fries', 'green tea', 'nan'],
#  ['mineral water', 'cake', 'chocolate', 'tomato juice'],
#  ['eggs', 'nan', 'nan', 'nan'],
#  ['chocolate', 'pepper', 'spaghetti', 'mineral water'],
#  ['frozen vegetables', 'pepper', 'mineral water', 'chocolate'],
#  ['burgers', 'turkey', 'spaghetti', 'milk'],
#  ['burgers', 'spaghetti', 'mineral water', 'soup'],
#  ['butter', 'green grapes', 'frozen smoothie', 'low fat yogurt'],
#  ['eggs', 'low fat yogurt', 'nan', 'nan'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['milk', 'energy drink', 'nan', 'nan'],
#  ['olive oil', 'energy drink', 'nan', 'nan'],
#  ['eggs', 'cookies', 'nan', 'nan'],
#  ['eggs', 'nan', 'nan', 'nan'],
#  ['energy bar', 'eggs', 'nan', 'nan'],
#  ['eggs', 'nan', 'nan', 'nan'],
#  ['eggs', 'green tea', 'nan', 'nan'],
#  ['escalope', 'nan', 'nan', 'nan'],
#  ['shrimp', 'soup', 'milk', 'almonds'],
#  ['chocolate', 'french fries', 'nan', 'nan'],
#  ['cake', 'nan', 'nan', 'nan'],
#  ['pancakes', 'eggs', 'cake', 'green tea'],
#  ['herb & pepper', 'tomatoes', 'ground beef', 'eggs'],
#  ['cider', 'eggs', 'chocolate', 'low fat yogurt'],
#  ['frozen vegetables', 'cider', 'eggs', 'french fries'],
#  ['yams', 'cookies', 'toothpaste', 'nan'],
#  ['mineral water', 'milk', 'escalope', 'champagne'],
#  ['ham', 'herb & pepper', 'spaghetti', 'mineral water'],
#  ['pepper', 'mineral water', 'escalope', 'shallot'],
#  ['turkey', 'parmesan cheese', 'spaghetti', 'meatballs'],
#  ['herb & pepper', 'eggs', 'escalope', 'nan'],
#  ['herb & pepper', 'nan', 'nan', 'nan'],
#  ['burgers', 'escalope', 'shallot', 'nan'],
#  ['chocolate', 'pepper', 'tomato sauce', 'tomato juice'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['burgers', 'ground beef', 'spaghetti', 'mineral water'],
#  ['frozen vegetables', 'mineral water', 'soup', 'milk'],
#  ['turkey', 'eggs', 'french fries', 'asparagus'],
#  ['burgers', 'frozen vegetables', 'gums', 'nan'],
#  ['herb & pepper', 'frozen vegetables', 'ground beef', 'milk'],
#  ['frozen vegetables', 'cake', 'light cream', 'mashed potato'],
#  ['milk', 'nan', 'nan', 'nan'],
#  ['turkey', 'eggs', 'barbecue sauce', 'nan'],
#  ['escalope', 'nan', 'nan', 'nan'],
#  ['parmesan cheese', 'french fries', 'nan', 'nan'],
#  ['energy bar', 'eggs', 'nan', 'nan'],
#  ['soup', 'escalope', 'mint', 'nan'],
#  ['muffins', 'chicken', 'zucchini', 'nan'],
#  ['burgers', 'eggs', 'french fries', 'cookies'],
#  ['spaghetti', 'nan', 'nan', 'nan'],
#  ['avocado', 'energy bar', 'chocolate', 'nan'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['green tea', 'nan', 'nan', 'nan'],
#  ['whole wheat pasta', 'spaghetti', 'mineral water', 'olive oil'],
#  ['grated cheese', 'frozen vegetables', 'eggs', 'gums'],
#  ['grated cheese', 'herb & pepper', 'mineral water', 'pancakes'],
#  ['chocolate', 'spaghetti', 'yams', 'flax seed'],
#  ['burger sauce', 'oil', 'nan', 'nan'],
#  ['eggs', 'french fries', 'energy drink', 'nan'],
#  ['mineral water', 'nan', 'nan', 'nan'],
#  ['grated cheese', 'ground beef', 'mineral water', 'olive oil'],
#  ['eggs', 'low fat yogurt', 'nan', 'nan'],
#  ['parmesan cheese', 'spaghetti', 'soda', 'pet food'],
#  ['turkey', 'shrimp', 'olive oil', 'chicken'],
#  ['pickles', 'ground beef', 'yams', 'milk'],
#  ['pepper', 'spaghetti', 'light cream', 'nan'],
#  ['frozen vegetables', 'mineral water', 'eggs', 'nan'],
#  ['spaghetti', 'chicken', 'tea', 'pancakes'],
#  ['fresh tuna', 'turkey', 'herb & pepper', 'spaghetti'],
#  ['spaghetti', 'mineral water', 'cooking oil', 'escalope'],
#  ['soup', 'nan', 'nan', 'nan'],
#  ['burgers', 'herb & pepper', 'spaghetti', 'nan'],
#  ['cookies', 'shallot', 'strawberries', 'nan'],
#  ['fresh tuna', 'chocolate', 'shrimp', 'whole wheat pasta'],
#  ['yams', 'mineral water', 'avocado', 'milk'],
#  ['ham', 'eggs', 'french fries', 'energy drink'],
#  ['mineral water', 'avocado', 'nan', 'nan'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['chocolate', 'butter', 'eggs', 'green tea'],
#  ['eggs', 'mushroom cream sauce', 'low fat yogurt', 'nan'],
#  ['antioxydant juice', 'chocolate', 'nan', 'nan'],
#  ['ground beef', 'spaghetti', 'french fries', 'green tea'],
#  ['cake', 'nan', 'nan', 'nan'],
#  ['turkey', 'red wine', 'mineral water', 'pancakes'],
#  ['chocolate', 'parmesan cheese', 'mineral water', 'olive oil'],
#  ['green grapes', 'gums', 'nan', 'nan'],
#  ['shrimp', 'frozen vegetables', 'parmesan cheese', 'milk'],
#  ['ground beef', 'mineral water', 'milk', 'eggs'],
#  ['escalope', 'nan', 'nan', 'nan'],
#  ['turkey', 'cookies', 'nan', 'nan'],
#  ['ground beef', 'mineral water', 'chocolate', 'green tea'],
#  ['whole wheat pasta', 'spaghetti', 'olive oil', 'butter'],
#  ['red wine', 'nan', 'nan', 'nan'],
#  ['frozen vegetables', 'mineral water', 'eggs', 'gums'],
#  ['turkey', 'grated cheese', 'energy bar', 'vegetables mix'],
#  ['turkey', 'burgers', 'nonfat milk', 'cooking oil'],
#  ['french fries', 'low fat yogurt', 'nan', 'nan'],
#  ['muffins', 'nan', 'nan', 'nan'],
#  ['herb & pepper', 'mineral water', 'salmon', 'whole wheat rice'],
#  ['mineral water', 'cake', 'chocolate', 'low fat yogurt'],
#  ['grated cheese', 'mineral water', 'chocolate', 'soup'],
#  ['mineral water', 'strawberries', 'nan', 'nan'],
#  ['escalope', 'nan', 'nan', 'nan'],
#  ['grated cheese', 'parmesan cheese', 'butter', 'whole wheat rice'],
#  ['ground beef', 'mint', 'nan', 'nan'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['ground beef', 'avocado', 'milk', 'chicken'],
#  ['frozen vegetables', 'soup', 'eggs', 'low fat yogurt'],
#  ['herb & pepper', 'ground beef', 'spaghetti', 'mineral water'],
#  ['shrimp', 'parmesan cheese', 'mineral water', 'eggs'],
#  ['ham', 'herb & pepper', 'frozen vegetables', 'tomatoes'],
#  ['chicken', 'cider', 'eggs', 'nan'],
#  ['shrimp', 'tomato sauce', 'mineral water', 'chocolate'],
#  ['energy drink', 'nan', 'nan', 'nan'],
#  ['ham', 'spaghetti', 'mineral water', 'energy bar'],
#  ['shrimp', 'frozen vegetables', 'tomatoes', 'nan'],
#  ['turkey', 'herb & pepper', 'frozen vegetables', 'ground beef'],
#  ['shrimp', 'mineral water', 'nan', 'nan'],
#  ['turkey', 'ground beef', 'spaghetti', 'soup'],
#  ['shrimp', 'pepper', 'mineral water', 'soup'],
#  ['burgers', 'pancakes', 'nan', 'nan'],
#  ['low fat yogurt', 'nan', 'nan', 'nan'],
#  ['mineral water', 'milk', 'nan', 'nan'],
#  ['milk', 'nan', 'nan', 'nan'],
#  ['chocolate', 'nan', 'nan', 'nan'],
#  ['whole wheat pasta', 'mineral water', 'olive oil', 'pancakes'],
#  ['yams', 'mineral water', 'eggs', 'cake'],
#  ['turkey', 'french fries', 'nan', 'nan'],
#  ['shrimp', 'spaghetti', 'yams', 'mineral water'],
#  ['mineral water', 'milk', 'salmon', 'green tea'],
#  ['spaghetti', 'olive oil', 'nan', 'nan'],
#  ['herb & pepper', 'spaghetti', 'nan', 'nan'],
#  ['spaghetti', 'mineral water', 'soup', 'salmon'],
#  ['frozen vegetables', 'whole wheat pasta', 'ground beef', 'mineral water'],
#  ['green tea', 'nan', 'nan', 'nan'],
#  ['burgers', 'grated cheese', 'spaghetti', 'nonfat milk'],
#  ['ham', 'ground beef', 'olive oil', 'energy bar'],
#  ['whole wheat pasta', 'mineral water', 'olive oil', 'cooking oil'],
#  ['vegetables mix', 'champagne', 'nan', 'nan'],
#  ['olive oil', 'nan', 'nan', 'nan'],
#  ['herb & pepper', 'ground beef', 'escalope', 'pancakes'],
#  ['herb & pepper', 'frozen vegetables', 'ground beef', 'tomato sauce'],
#  ['yams', 'carrots', 'nan', 'nan'],
#  ['chicken', 'nan', 'nan', 'nan'],
#  ['turkey', 'burgers', 'herb & pepper', 'ground beef'],
#  ['whole wheat pasta', 'salmon', 'antioxydant juice', 'mint green tea'],
#  ['chocolate', 'french fries', 'strawberries', 'fresh bread'],
#  ['burgers', 'chocolate', 'shrimp', 'whole wheat pasta'],
#  ['mineral water', 'butter', 'pancakes', 'french fries'],
#  ['muffins', 'eggs', 'nan', 'nan'],
#  ['turkey', 'shrimp', 'frozen vegetables', 'eggs'],
#  ['burgers', 'eggs', 'yogurt cake', 'nan'],
#  ['burgers', 'fresh tuna', 'shrimp', 'frozen vegetables'],
#  ['herb & pepper', 'ground beef', 'mineral water', 'chicken'],
#  ['frozen smoothie', 'nan', 'nan', 'nan'],
#  ['chicken', 'tomato juice', 'nan', 'nan'],
#  ['whole wheat pasta', 'olive oil', 'nan', 'nan'],
#  ['milk', 'energy bar', 'green tea', 'nan'],
#  ['grated cheese', 'herb & pepper', 'nan', 'nan'],
#  ['escalope', 'green tea', 'nan', 'nan'],
#  ['soup', 'meatballs', 'milk', 'almonds'],
#  ['herb & pepper', 'pet food', 'cookies', 'nan'],
#  ['grated cheese', 'whole wheat pasta', 'olive oil', 'energy bar'],
#  ['honey', 'nan', 'nan', 'nan'],
#  ['parmesan cheese', 'mineral water', 'fromage blanc', 'eggs'],
#  ['bramble', 'zucchini', 'nan', 'nan'],
#  ['ground beef', 'pepper', 'milk', 'eggs'],
#  ['chocolate', 'red wine', 'butter', 'french fries'],
#  ['chocolate', 'spaghetti', 'bug spray', 'nan'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['spaghetti', 'mineral water', 'vegetables mix', 'eggs'],
#  ['chocolate', 'grated cheese', 'mineral water', 'salmon'],
#  ['spaghetti', 'champagne', 'nan', 'nan'],
#  ['frozen vegetables', 'mineral water', 'nan', 'nan'],
#  ['mineral water', 'body spray', 'low fat yogurt', 'nan'],
#  ['herb & pepper', 'red wine', 'whole wheat pasta', 'cake'],
#  ['burgers', 'parmesan cheese', 'eggs', 'french fries'],
#  ['mineral water', 'eggs', 'pancakes', 'nan'],
#  ['eggs', 'french fries', 'nan', 'nan'],
#  ['shrimp', 'frozen vegetables', 'tomatoes', 'spaghetti'],
#  ['mineral water', 'almonds', 'pancakes', 'chocolate'],
#  ['cake', 'french fries', 'escalope', 'nan'],
#  ['frozen vegetables', 'spaghetti', 'mineral water', 'milk'],
#  ['almonds', 'cake', 'low fat yogurt', 'nan'],
#  ['french fries', 'nan', 'nan', 'nan'],
#  ['hot dogs', 'nan', 'nan', 'nan'],
#  ['mineral water', 'soup', 'chicken', 'light cream'],
#  ['ground beef', 'olive oil', 'nan', 'nan'],
#  ['french fries', 'cookies', 'green tea', 'nan'],
#  ['soup', 'blueberries', 'cooking oil', 'chocolate'],
#  ['chocolate', 'french fries', 'frozen smoothie', 'escalope'],
#  ['yams', 'mint', 'nan', 'nan'],
#  ['frozen vegetables', 'ground beef', 'salmon', 'muffins'],
#  ['fresh tuna', 'herb & pepper', 'parmesan cheese', 'milk'],
#  ['grated cheese', 'shrimp', 'butter', 'whole wheat rice'],
#  ['energy bar', 'eggs', 'french fries', 'champagne'],
#  ['burgers', 'eggs', 'french fries', 'nan'],
#  ['burgers', 'shrimp', 'mineral water', 'milk'],
#  ['ground beef', 'mineral water', 'chocolate', 'milk'],
#  ['mineral water', 'chicken', 'nan', 'nan'],
#  ['turkey', 'ground beef', 'spaghetti', 'milk'],
#  ['french fries', 'green tea', 'nan', 'nan'],
#  ['french fries', 'escalope', 'nan', 'nan'],
#  ['turkey', 'sparkling water', 'nan', 'nan'],
#  ['whole wheat pasta', 'mineral water', 'olive oil', 'carrots'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['turkey', 'grated cheese', 'honey', 'green beans'],
#  ['turkey', 'red wine', 'mineral water', 'chocolate'],
#  ['turkey', 'eggs', 'nan', 'nan'],
#  ['low fat yogurt', 'nan', 'nan', 'nan'],
#  ['nonfat milk', 'low fat yogurt', 'nan', 'nan'],
#  ['frozen vegetables', 'low fat yogurt', 'nan', 'nan'],
#  ['herb & pepper', 'parmesan cheese', 'whole wheat pasta', 'mineral water'],
#  ['yogurt cake', 'mint', 'nan', 'nan'],
#  ['sandwich', 'salt', 'nan', 'nan'],
#  ['shrimp', 'fresh bread', 'green tea', 'nan'],
#  ['pepper', 'tomato sauce', 'escalope', 'nan'],
#  ['mineral water', 'cake', 'protein bar', 'toothpaste'],
#  ['candy bars', 'nan', 'nan', 'nan'],
#  ['red wine', 'nan', 'nan', 'nan'],
#  ['spaghetti', 'mineral water', 'honey', 'strawberries'],
#  ['mineral water', 'eggs', 'green tea', 'nan'],
#  ['grated cheese', 'frozen vegetables', 'parmesan cheese', 'french wine'],
#  ['frozen vegetables', 'parmesan cheese', 'whole wheat pasta', 'spaghetti'],
#  ['chocolate', 'grated cheese', 'shrimp', 'spaghetti'],
#  ['spaghetti', 'strawberries', 'nan', 'nan'],
#  ['burgers', 'chocolate', 'mushroom cream sauce', 'nan'],
#  ['mineral water', 'olive oil', 'extra dark chocolate', 'nan'],
#  ['eggs', 'green tea', 'nan', 'nan'],
#  ['tomato juice', 'nan', 'nan', 'nan'],
#  ['muffins', 'low fat yogurt', 'nan', 'nan'],
#  ['soup', 'olive oil', 'pancakes', 'light cream'],
#  ['mineral water', 'vegetables mix', 'low fat yogurt', 'nan'],
#  ['pepper', 'mineral water', 'avocado', 'pancakes'],
#  ['pickles', 'burgers', 'almonds', 'honey'],
#  ['bug spray', 'clothes accessories', 'cottage cheese', 'nan'],
#  ['frozen vegetables', 'ground beef', 'spaghetti', 'pancakes'],
#  ['spaghetti', 'mineral water', 'milk', 'nan'],
#  ['pancakes', 'nan', 'nan', 'nan'],
#  ['muffins', 'nan', 'nan', 'nan'],
#  ['frozen vegetables', 'oil', 'cereals', 'nan'],
#  ['turkey', 'shrimp', 'mineral water', 'milk'],
#  ['chocolate', 'rice', 'eggplant', 'hand protein bar'],
#  ['spaghetti', 'meatballs', 'nonfat milk', 'hot dogs'],
#  ['frozen vegetables', 'cake', 'cookies', 'pancakes'],
#  ['butter', 'bug spray', 'french fries', 'yogurt cake'],
#  ['herb & pepper', 'nan', 'nan', 'nan'],
#  ['soup', 'milk', 'cider', 'chicken'],
#  ['shrimp', 'spaghetti', 'mineral water', 'avocado'],
#  ['milk', 'whole wheat rice', 'escalope', 'champagne'],
#  ['escalope', 'pasta', 'mushroom cream sauce', 'nan'],
#  ['parmesan cheese', 'nan', 'nan', 'nan'],
#  ['grated cheese', 'spaghetti', 'french fries', 'nan'],
#  ['burgers', 'shrimp', 'whole wheat pasta', 'spaghetti'],
#  ['turkey', 'chocolate', 'grated cheese', 'frozen vegetables'],
#  ['turkey', 'pepper', 'chocolate', 'fromage blanc'],
#  ['tomatoes', 'ground beef', 'avocado', 'milk'],
#  ['turkey', 'mineral water', 'green tea', 'protein bar'],
#  ['mineral water', 'low fat yogurt', 'nan', 'nan'],
#  ['pancakes', 'tomato juice', 'candy bars', 'nan'],
#  ['yams', 'avocado', 'bacon', 'oil'],
#  ['shrimp', 'spaghetti', 'mineral water', 'soup'],
#  ['chicken', 'cooking oil', 'tea', 'nan'],
#  ['burgers', 'soup', 'vegetables mix', 'pancakes'],
#  ['shrimp', 'pepper', 'nan', 'nan'],
#  ['spaghetti', 'olive oil', 'blueberries', 'nan'],
#  ['muffins', 'nan', 'nan', 'nan'],
#  ['grated cheese', 'herb & pepper', 'muffins', 'eggs'],
#  ['grated cheese', 'frozen vegetables', 'spaghetti', 'milk'],
#  ['pepper', 'pancakes', 'french fries', 'tomato juice'],
#  ['frozen vegetables', 'tomatoes', 'parmesan cheese', 'ground beef'],
#  ['olive oil', 'chicken', 'chocolate', 'cookies'],
#  ['whole wheat pasta', 'ground beef', 'spaghetti', 'chocolate'],
#  ['eggs', 'cottage cheese', 'nan', 'nan'],
#  ['muffins', 'cottage cheese', 'nan', 'nan'],
#  ['green tea', 'frozen smoothie', 'white wine', 'nan'],
#  ['mineral water', 'chocolate', 'rice', 'champagne'],
#  ['mineral water', 'nan', 'nan', 'nan'],
#  ['shrimp', 'whole wheat pasta', 'meatballs', 'milk'],
#  ['herb & pepper', 'parmesan cheese', 'ground beef', 'pepper'],
#  ['grated cheese', 'shrimp', 'parmesan cheese', 'ground beef'],
#  ['mineral water', 'rice', 'nan', 'nan'],
#  ['pancakes', 'nan', 'nan', 'nan'],
#  ['mineral water', 'honey', 'nan', 'nan'],
#  ['burgers', 'ground beef', 'pancakes', 'salt'],
#  ['parmesan cheese', 'soda', 'french fries', 'brownies'],
#  ['whole wheat rice', 'nan', 'nan', 'nan'],
#  ['ground beef', 'spaghetti', 'chicken', 'rice'],
#  ['butter', 'chocolate', 'nan', 'nan'],
#  ['pepper', 'nan', 'nan', 'nan'],
#  ['herb & pepper', 'chocolate', 'champagne', 'yogurt cake'],
#  ['grated cheese', 'mineral water', 'eggs', 'escalope'],
#  ['cookies', 'yogurt cake', 'light mayo', 'green tea'],
#  ['milk', 'cooking oil', 'nan', 'nan'],
#  ['milk', 'olive oil', 'light cream', 'cooking oil'],
#  ['tomatoes', 'soup', 'avocado', 'milk'],
#  ['ham', 'chocolate', 'ground beef', 'mineral water'],
#  ['green tea', 'champagne', 'escalope', 'nan'],
#  ['chocolate', 'nan', 'nan', 'nan'],
#  ['escalope', 'pasta', 'nan', 'nan'],
#  ['burgers', 'mineral water', 'olive oil', 'rice'],
#  ['green tea', 'nan', 'nan', 'nan'],
#  ['grated cheese', 'tomato sauce', 'spaghetti', 'milk'],
#  ['turkey', 'spaghetti', 'strong cheese', 'strawberries'],
#  ['muffins', 'nan', 'nan', 'nan'],
#  ['ground beef', 'spaghetti', 'cider', 'cooking oil'],
#  ['burgers', 'frozen vegetables', 'parmesan cheese', 'spaghetti'],
#  ['ground beef', 'nan', 'nan', 'nan'],
#  ['green beans', 'nan', 'nan', 'nan'],
#  ['frozen vegetables', 'mineral water', 'honey', 'whole wheat rice'],
#  ['parmesan cheese', 'milk', 'butter', 'black tea'],
#  ['mineral water', 'cake', 'nan', 'nan'],
#  ['turkey', 'mineral water', 'milk', 'pancakes'],
#  ['avocado', 'chocolate', 'french fries', 'nan'],
#  ['green tea', 'nan', 'nan', 'nan'],
#  ['chocolate', 'eggs', 'bug spray', 'nan'],
#  ['grated cheese', 'muffins', 'french fries', 'body spray'],
#  ['mineral water', 'eggs', 'blueberries', 'soda'],
#  ['whole wheat rice', 'nan', 'nan', 'nan'],
#  ['nonfat milk', 'cookies', 'mushroom cream sauce', 'nan'],
#  ['french fries', 'champagne', 'nan', 'nan'],
#  ['mineral water', 'salmon', 'nan', 'nan'],
#  ['olive oil', 'nan', 'nan', 'nan'],
#  ['turkey', 'tomatoes', 'ground beef', 'soup'],
#  ['parmesan cheese', 'spaghetti', 'mineral water', 'chocolate'],
#  ['burgers', 'parmesan cheese', 'chocolate', 'soup'],
#  ['shrimp', 'honey', 'pasta', 'energy drink'],
#  ['fresh tuna', 'chocolate', 'milk', 'french wine'],
#  ['strawberries', 'nan', 'nan', 'nan'],
#  ['herb & pepper', 'nan', 'nan', 'nan'],
#  ['herb & pepper', 'frozen vegetables', 'tomatoes', 'parmesan cheese'],
#  ['spaghetti', 'mineral water', 'milk', 'strong cheese'],
#  ['turkey', 'burgers', 'fresh tuna', 'spaghetti'],
#  ['eggplant', 'nan', 'nan', 'nan'],
#  ['burgers', 'spaghetti', 'mineral water', 'almonds'],
#  ['chocolate', 'french fries', 'frozen smoothie', 'cottage cheese'],
#  ['strong cheese', 'nan', 'nan', 'nan'],
#  ['chocolate', 'french fries', 'nan', 'nan'],
#  ['chocolate', 'french fries', 'strawberries', 'nan'],
#  ['turkey', 'frozen vegetables', 'avocado', 'cake'],
#  ['olive oil', 'energy bar', 'shallot', 'nan'],
#  ['turkey', 'shrimp', 'nan', 'nan'],
#  ['chocolate', 'spaghetti', 'champagne', 'yogurt cake'],
#  ['shrimp', 'mineral water', 'chocolate', 'avocado'],
#  ['muffins', 'green tea', 'brownies', 'nan'],
#  ['yogurt cake', 'nan', 'nan', 'nan'],
#  ['turkey', 'tomato sauce', 'milk', 'butter'],
#  ['grated cheese', 'nan', 'nan', 'nan'],
#  ['butter', 'burger sauce', 'brownies', 'pancakes'],
#  ['butter', 'pancakes', 'whole wheat rice', 'green tea'],
#  ['shrimp', 'chocolate', 'butter', 'cooking oil'],
#  ['burgers', 'red wine', 'frozen vegetables', 'pepper'],
#  ['turkey', 'ground beef', 'spaghetti', 'pancakes'],
#  ['shrimp', 'milk', 'butter', 'chicken'],
#  ['fresh tuna', 'mineral water', 'fromage blanc', 'honey'],
#  ['chocolate', 'cookies', 'nan', 'nan'],
#  ['sparkling water', 'light mayo', 'nan', 'nan'],
#  ['frozen vegetables', 'tomatoes', 'spaghetti', 'chicken'],
#  ['turkey', 'burgers', 'butter', 'vegetables mix'],
#  ['red wine', 'shrimp', 'yams', 'eggs'],
#  ['french fries', 'light mayo', 'nan', 'nan'],
#  ['burgers', 'ground beef', 'eggs', 'chocolate'],
#  ['mushroom cream sauce', 'nan', 'nan', 'nan'],
#  ['butter', 'mint green tea', 'nan', 'nan'],
#  ['whole wheat rice', 'nan', 'nan', 'nan'],
#  ['gums', 'nan', 'nan', 'nan'],
#  ['mineral water', 'french fries', 'champagne', 'green tea'],
#  ['cereals', 'salt', 'green tea', 'nan'],
#  ['shrimp', 'spaghetti', 'chocolate', 'french fries'],
#  ['ham', 'spaghetti', 'yams', 'chicken'],
#  ['eggs', 'nan', 'nan', 'nan'],
#  ['ground beef', 'olive oil', 'bug spray', 'frozen smoothie'],
#  ['frozen vegetables', 'spaghetti', 'mineral water', 'soup'],
#  ['whole wheat rice', 'oil', 'chicken', 'french fries'],
#  ['green tea', 'nan', 'nan', 'nan'],
#  ['parmesan cheese', 'whole wheat rice', 'escalope', 'champagne'],
#  ['fresh tuna', 'frozen vegetables', 'chicken', 'fromage blanc'],
#  ['ground beef', 'nan', 'nan', 'nan'],
#  ['muffins', 'champagne', 'cookies', 'fresh bread'],
#  ['frozen vegetables', 'spaghetti', 'chocolate', 'escalope'],
#  ['pickles', 'spaghetti', 'french fries', 'frozen smoothie'],
#  ['avocado', 'nan', 'nan', 'nan'],
#  ['sandwich', 'nan', 'nan', 'nan'],
#  ['spaghetti', 'milk', 'oil', 'shampoo'],
#  ['champagne', 'nan', 'nan', 'nan'],
#  ['spaghetti', 'nan', 'nan', 'nan'],
#  ['champagne', 'nan', 'nan', 'nan'],
#  ['avocado', 'milk', 'butter', 'french fries'],
#  ['turkey', 'frozen vegetables', 'chicken', 'eggs'],
#  ['burgers', 'shrimp', 'tomatoes', 'milk'],
#  ['burgers', 'milk', 'cake', 'cooking oil'],
#  ['tomatoes', 'spaghetti', 'chocolate', 'milk'],
#  ['fresh tuna', 'red wine', 'pepper', 'spaghetti'],
#  ['milk', 'low fat yogurt', 'nan', 'nan'],
#  ['shrimp', 'parmesan cheese', 'soup', 'chocolate'],
#  ['spaghetti', 'chicken', 'nan', 'nan'],
#  ['grated cheese', 'vegetables mix', 'nonfat milk', 'green tea'],
#  ['fresh tuna', 'parmesan cheese', 'cider', 'muffins'],
#  ['cake', 'nan', 'nan', 'nan'],
#  ['shrimp', 'chocolate', 'mushroom cream sauce', 'candy bars'],
#  ['candy bars', 'nan', 'nan', 'nan'],
#  ['avocado', 'honey', 'nan', 'nan'],
#  ['shrimp', 'frozen vegetables', 'tomatoes', 'cottage cheese'],
#  ['french fries', 'nan', 'nan', 'nan'],
#  ['strawberries', 'nan', 'nan', 'nan'],
#  ['ground beef', 'almonds', 'french fries', 'escalope'],
#  ['grated cheese', 'spaghetti', 'nan', 'nan'],
#  ['turkey', 'mineral water', 'butter', 'frozen smoothie'],
#  ['frozen vegetables', 'spaghetti', 'french fries', 'light mayo'],
#  ['burgers', 'ham', 'spaghetti', 'whole wheat rice'],
#  ['grated cheese', 'frozen vegetables', 'spaghetti', 'avocado'],
#  ['burgers', 'shrimp', 'tomatoes', 'bacon'],
#  ['parmesan cheese', 'pancakes', 'nan', 'nan'],
#  ['parmesan cheese', 'cake', 'hot dogs', 'green tea'],
#  ['spaghetti', 'milk', 'fromage blanc', 'ketchup'],
#  ['mint', 'nan', 'nan', 'nan'],
#  ['chocolate', 'mint', 'nan', 'nan'],
#  ['butter', 'french fries', 'salt', 'fresh bread'],
#  ['chocolate', 'french fries', 'strawberries', 'yogurt cake'],
#  ['eggs', 'eggplant', 'cookies', 'nan'],
#  ['yogurt cake', 'nan', 'nan', 'nan'],
#  ['herb & pepper', 'spaghetti', 'meatballs', 'milk'],
#  ['frozen vegetables', 'rice', 'chocolate', 'nan'],
#  ['herb & pepper', 'ground beef', 'spaghetti', 'chocolate'],
#  ['eggs', 'champagne', 'nan', 'nan'],
#  ['whole wheat pasta', 'ground beef', 'olive oil', 'blueberries'],
#  ['burgers', 'red wine', 'mineral water', 'eggs'],
#  ['chocolate', 'grated cheese', 'herb & pepper', 'mineral water'],
#  ['burgers', 'shrimp', 'mineral water', 'chicken'],
#  ['green tea', 'nan', 'nan', 'nan'],
#  ['cookies', 'nan', 'nan', 'nan'],
#  ['french fries', 'cookies', 'nan', 'nan'],
#  ['milk', 'butter', 'eggs', 'nan'],
#  ['eggs', 'mushroom cream sauce', 'low fat yogurt', 'nan'],
#  ['eggs', 'green tea', 'nan', 'nan'],
#  ['mineral water', 'whole wheat rice', 'nan', 'nan'],
#  ['shrimp', 'frozen vegetables', 'parmesan cheese', 'mineral water'],
#  ['whole wheat rice', 'pancakes', 'nan', 'nan'],
#  ['frozen vegetables', 'spaghetti', 'olive oil', 'butter'],
#  ['green tea', 'nan', 'nan', 'nan'],
#  ['fresh tuna', 'eggs', 'escalope', 'strawberries'],
#  ['spaghetti', 'soup', 'milk', 'carrots'],
#  ['burgers', 'mineral water', 'soup', 'meatballs'],
#  ['grated cheese', 'mineral water', 'cooking oil', 'french fries'],
#  ['shrimp', 'milk', 'olive oil', 'french fries'],
#  ['frozen vegetables', 'mineral water', 'pancakes', 'cake'],
#  ['spaghetti', 'milk', 'chicken', 'nan'],
#  ['grated cheese', 'mineral water', 'chicken', 'french fries'],
#  ['ground beef', 'mineral water', 'milk', 'eggs'],
#  ['shrimp', 'body spray', 'green tea', 'nan'],
#  ['frozen smoothie', 'nan', 'nan', 'nan'],
#  ['herb & pepper', 'frozen vegetables', 'mineral water', 'muffins'],
#  ['turkey', 'tomatoes', 'spaghetti', 'milk'],
#  ...]

# %%
T = []
for i in range(len(df)):
    T.append([str(df.values[i,j]) for j in range(0,20) if str(df.values[i,j]) !='nan'])
T
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers', 'meatballs', 'eggs'],
#  ['chutney'],
#  ['turkey', 'avocado'],
#  ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea'],
#  ['low fat yogurt'],
#  ['whole wheat pasta', 'french fries'],
#  ['soup', 'light cream', 'shallot'],
#  ['frozen vegetables', 'spaghetti', 'green tea'],
#  ['french fries'],
#  ['eggs', 'pet food'],
#  ['cookies'],
#  ['turkey', 'burgers', 'mineral water', 'eggs', 'cooking oil'],
#  ['spaghetti', 'champagne', 'cookies'],
#  ['mineral water', 'salmon'],
#  ['mineral water'],
#  ['shrimp',
#   'chocolate',
#   'chicken',
#   'honey',
#   'oil',
#   'cooking oil',
#   'low fat yogurt'],
#  ['turkey', 'eggs'],
#  ['turkey',
#   'fresh tuna',
#   'tomatoes',
#   'spaghetti',
#   'mineral water',
#   'black tea',
#   'salmon',
#   'eggs',
#   'chicken',
#   'extra dark chocolate'],
#  ['meatballs', 'milk', 'honey', 'french fries', 'protein bar'],
#  ['red wine', 'shrimp', 'pasta', 'pepper', 'eggs', 'chocolate', 'shampoo'],
#  ['rice', 'sparkling water'],
#  ['spaghetti', 'mineral water', 'ham', 'body spray', 'pancakes', 'green tea'],
#  ['burgers',
#   'grated cheese',
#   'shrimp',
#   'pasta',
#   'avocado',
#   'honey',
#   'white wine',
#   'toothpaste'],
#  ['eggs'],
#  ['parmesan cheese', 'spaghetti', 'soup', 'avocado', 'milk', 'fresh bread'],
#  ['ground beef',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'energy bar',
#   'black tea',
#   'salmon',
#   'frozen smoothie',
#   'escalope'],
#  ['sparkling water'],
#  ['mineral water', 'eggs', 'chicken', 'chocolate', 'french fries'],
#  ['frozen vegetables', 'spaghetti', 'yams', 'mineral water'],
#  ['herb & pepper', 'tomato sauce', 'light cream', 'magazines'],
#  ['mineral water', 'chocolate', 'avocado', 'eggs'],
#  ['turkey', 'french fries', 'strawberries'],
#  ['frozen vegetables', 'strong cheese', 'chocolate'],
#  ['cookies'],
#  ['pickles', 'spaghetti', 'salmon', 'escalope'],
#  ['energy bar', 'french fries'],
#  ['red wine', 'ground beef', 'mineral water'],
#  ['mineral water', 'cake', 'cottage cheese'],
#  ['pickles', 'champagne', 'green tea'],
#  ['spaghetti'],
#  ['fresh tuna',
#   'frozen vegetables',
#   'spaghetti',
#   'mineral water',
#   'honey',
#   'whole wheat rice',
#   'frozen smoothie',
#   'escalope'],
#  ['spaghetti'],
#  ['soup', 'meatballs', 'hot dogs', 'sparkling water'],
#  ['escalope'],
#  ['soup',
#   'avocado',
#   'french fries',
#   'hot dogs',
#   'brownies',
#   'body spray',
#   'pancakes',
#   'green tea'],
#  ['mineral water', 'chicken', 'cereals', 'clothes accessories'],
#  ['mineral water', 'bug spray'],
#  ['avocado', 'muffins'],
#  ['burgers', 'black tea', 'green tea'],
#  ['spaghetti', 'chocolate', 'brownies', 'white wine', 'green tea'],
#  ['fresh tuna', 'mineral water', 'eggs'],
#  ['spaghetti', 'muffins'],
#  ['spaghetti', 'chocolate'],
#  ['french fries', 'escalope', 'champagne'],
#  ['tomato sauce', 'light mayo'],
#  ['turkey',
#   'fresh tuna',
#   'frozen vegetables',
#   'tomatoes',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'chocolate',
#   'soup',
#   'milk',
#   'olive oil'],
#  ['eggs', 'cookies'],
#  ['soup',
#   'chicken',
#   'gums',
#   'soda',
#   'body spray',
#   'energy drink',
#   'green tea'],
#  ['turkey',
#   'frozen vegetables',
#   'mineral water',
#   'cider',
#   'cooking oil',
#   'green tea'],
#  ['spaghetti'],
#  ['clothes accessories'],
#  ['energy drink'],
#  ['soup', 'bug spray', 'shallot', 'protein bar', 'green tea'],
#  ['turkey', 'eggs'],
#  ['french fries'],
#  ['chocolate', 'milk'],
#  ['herb & pepper',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'avocado',
#   'cider',
#   'whole wheat rice'],
#  ['cookies'],
#  ['shrimp', 'pasta'],
#  ['grated cheese', 'herb & pepper', 'tomatoes', 'tomato sauce', 'corn'],
#  ['burgers', 'escalope', 'shallot'],
#  ['cookies'],
#  ['yogurt cake'],
#  ['soup', 'eggs'],
#  ['cookies'],
#  ['mineral water', 'chocolate', 'low fat yogurt'],
#  ['eggs', 'strawberries'],
#  ['grated cheese', 'ground beef', 'spaghetti', 'mineral water', 'white wine'],
#  ['mint'],
#  ['eggs', 'cake', 'french fries'],
#  ['burgers', 'spaghetti', 'milk', 'french fries', 'green tea'],
#  ['mineral water', 'energy bar', 'butter', 'french fries'],
#  ['burgers',
#   'grated cheese',
#   'herb & pepper',
#   'mineral water',
#   'eggs',
#   'cooking oil'],
#  ['energy bar'],
#  ['energy bar', 'energy drink'],
#  ['chocolate', 'frozen smoothie'],
#  ['low fat yogurt'],
#  ['asparagus', 'salad'],
#  ['burgers', 'french fries', 'low fat yogurt', 'green tea'],
#  ['low fat yogurt'],
#  ['burgers',
#   'herb & pepper',
#   'shrimp',
#   'pasta',
#   'spaghetti',
#   'mineral water',
#   'meatballs',
#   'olive oil',
#   'energy bar',
#   'french wine',
#   'eggs',
#   'salt'],
#  ['champagne', 'low fat yogurt'],
#  ['champagne'],
#  ['burgers', 'almonds', 'eggs', 'french fries', 'cookies', 'green tea'],
#  ['ham', 'soup', 'escalope', 'body spray'],
#  ['turkey',
#   'ham',
#   'frozen vegetables',
#   'pepper',
#   'oil',
#   'extra dark chocolate',
#   'tea',
#   'magazines'],
#  ['muffins', 'eggs', 'cookies'],
#  ['cookies'],
#  ['frozen vegetables',
#   'whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'chocolate',
#   'green tea'],
#  ['mineral water', 'barbecue sauce', 'chocolate'],
#  ['burgers',
#   'herb & pepper',
#   'energy bar',
#   'almonds',
#   'eggs',
#   'corn',
#   'mayonnaise',
#   'zucchini'],
#  ['turkey',
#   'burgers',
#   'ground beef',
#   'chocolate',
#   'soup',
#   'almonds',
#   'eggs',
#   'hot dogs',
#   'cottage cheese'],
#  ['ham', 'spaghetti', 'chocolate', 'eggs'],
#  ['ground beef', 'energy bar', 'pet food', 'carrots', 'protein bar'],
#  ['ground beef',
#   'tomato sauce',
#   'spaghetti',
#   'mineral water',
#   'almonds',
#   'eggs'],
#  ['mineral water', 'olive oil', 'gums', 'cooking oil'],
#  ['shrimp',
#   'pasta',
#   'mineral water',
#   'soup',
#   'avocado',
#   'milk',
#   'olive oil',
#   'green grapes',
#   'eggs',
#   'bug spray'],
#  ['shrimp',
#   'pasta',
#   'soup',
#   'cake',
#   'cooking oil',
#   'chicken',
#   'light mayo',
#   'low fat yogurt'],
#  ['spaghetti',
#   'mineral water',
#   'chocolate',
#   'french fries',
#   'champagne',
#   'escalope',
#   'mushroom cream sauce',
#   'fresh bread'],
#  ['shrimp', 'pasta', 'mineral water', 'eggs'],
#  ['burgers', 'oil', 'tomato juice', 'fresh bread'],
#  ['french wine', 'eggs', 'chocolate', 'low fat yogurt'],
#  ['chicken', 'eggs', 'french fries', 'pancakes'],
#  ['turkey', 'herb & pepper', 'salmon', 'white wine', 'candy bars'],
#  ['grated cheese',
#   'spaghetti',
#   'olive oil',
#   'eggs',
#   'french fries',
#   'green tea'],
#  ['mineral water', 'energy bar'],
#  ['eggs', 'french fries'],
#  ['burgers',
#   'tomatoes',
#   'mineral water',
#   'soup',
#   'milk',
#   'almonds',
#   'eggs',
#   'chocolate',
#   'tomato juice'],
#  ['muffins'],
#  ['pasta'],
#  ['tomatoes', 'spaghetti', 'frozen smoothie'],
#  ['ground beef', 'spaghetti', 'milk'],
#  ['french fries'],
#  ['chocolate', 'milk'],
#  ['burgers',
#   'shrimp',
#   'pasta',
#   'frozen vegetables',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'eggs',
#   'chocolate',
#   'french fries',
#   'pancakes',
#   'low fat yogurt'],
#  ['ground beef', 'mineral water', 'antioxydant juice', 'protein bar'],
#  ['grated cheese',
#   'whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'cake',
#   'energy drink'],
#  ['grated cheese'],
#  ['pancakes'],
#  ['frozen smoothie'],
#  ['carrots', 'green tea'],
#  ['chocolate'],
#  ['turkey',
#   'burgers',
#   'chocolate',
#   'olive oil',
#   'eggs',
#   'cooking oil',
#   'corn'],
#  ['frozen vegetables',
#   'tomatoes',
#   'pepper',
#   'spaghetti',
#   'mineral water',
#   'pancakes',
#   'chicken',
#   'chili',
#   'tea',
#   'french fries',
#   'tomato juice',
#   'fresh bread'],
#  ['cookies'],
#  ['ground beef'],
#  ['turkey', 'eggs', 'chocolate', 'frozen smoothie', 'tomato juice'],
#  ['frozen vegetables', 'cooking oil', 'mashed potato'],
#  ['frozen vegetables',
#   'ground beef',
#   'tomato sauce',
#   'mineral water',
#   'meatballs',
#   'olive oil',
#   'light cream',
#   'tomato juice'],
#  ['red wine',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'milk',
#   'eggs',
#   'cake',
#   'gums',
#   'cooking oil',
#   'chocolate',
#   'frozen smoothie'],
#  ['chocolate',
#   'tomatoes',
#   'spaghetti',
#   'mineral water',
#   'avocado',
#   'milk',
#   'olive oil',
#   'eggs',
#   'rice',
#   'french fries',
#   'brownies'],
#  ['chocolate',
#   'shrimp',
#   'pasta',
#   'frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'nonfat milk',
#   'eggs'],
#  ['turkey',
#   'shrimp',
#   'pasta',
#   'pepper',
#   'spaghetti',
#   'mineral water',
#   'eggs',
#   'chicken',
#   'french fries'],
#  ['cookies'],
#  ['turkey', 'tomatoes', 'cake'],
#  ['yams',
#   'mineral water',
#   'soup',
#   'milk',
#   'pancakes',
#   'whole wheat rice',
#   'barbecue sauce',
#   'carrots',
#   'chocolate',
#   'champagne'],
#  ['rice'],
#  ['chocolate', 'milk'],
#  ['shrimp', 'pasta', 'frozen vegetables', 'water spray'],
#  ['burgers', 'mineral water', 'milk', 'eggs', 'whole wheat rice', 'mint'],
#  ['mineral water', 'vegetables mix', 'cake', 'frozen smoothie', 'brownies'],
#  ['cookies'],
#  ['shrimp', 'pasta', 'chicken', 'chocolate bread'],
#  ['shallot'],
#  ['shrimp', 'pasta', 'spaghetti', 'eggs', 'hot dogs', 'green tea'],
#  ['burgers'],
#  ['red wine',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'olive oil',
#   'strong cheese',
#   'light cream',
#   'cooking oil'],
#  ['burgers',
#   'grated cheese',
#   'spaghetti',
#   'avocado',
#   'milk',
#   'oil',
#   'french fries'],
#  ['herb & pepper',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'olive oil'],
#  ['shrimp', 'pasta', 'yams', 'milk', 'chocolate'],
#  ['butter', 'green tea'],
#  ['light mayo'],
#  ['low fat yogurt'],
#  ['herb & pepper', 'shrimp', 'pasta', 'spaghetti', 'milk'],
#  ['burgers', 'eggs'],
#  ['turkey',
#   'herb & pepper',
#   'ground beef',
#   'soup',
#   'avocado',
#   'milk',
#   'black tea',
#   'eggs',
#   'barbecue sauce',
#   'carrots',
#   'cookies',
#   'tomato juice',
#   'fresh bread'],
#  ['cookies'],
#  ['escalope'],
#  ['pepper', 'french fries', 'strawberries', 'pancakes', 'low fat yogurt'],
#  ['frozen vegetables', 'yams', 'chicken', 'honey', 'light mayo'],
#  ['chocolate', 'champagne'],
#  ['herb & pepper', 'honey', 'cake', 'rice', 'protein bar'],
#  ['burgers',
#   'chocolate',
#   'frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'milk',
#   'light mayo',
#   'asparagus'],
#  ['chocolate', 'mineral water', 'corn', 'cottage cheese', 'green tea'],
#  ['muffins'],
#  ['ham', 'french wine', 'escalope'],
#  ['spaghetti', 'milk', 'whole wheat rice', 'mint green tea'],
#  ['chocolate', 'body spray'],
#  ['frozen vegetables', 'french fries', 'hot dogs'],
#  ['candy bars'],
#  ['burgers',
#   'shrimp',
#   'pasta',
#   'milk',
#   'green tea',
#   'french fries',
#   'cookies',
#   'white wine'],
#  ['parmesan cheese', 'ground beef'],
#  ['pancakes', 'whole wheat rice', 'candy bars'],
#  ['eggs', 'eggplant', 'cookies'],
#  ['frozen vegetables', 'mineral water'],
#  ['chocolate'],
#  ['turkey', 'spaghetti', 'milk', 'whole wheat rice', 'chocolate'],
#  ['whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'soup',
#   'meatballs',
#   'chicken',
#   'blueberries',
#   'cooking oil',
#   'champagne',
#   'yogurt cake',
#   'protein bar'],
#  ['cooking oil', 'tomato juice'],
#  ['frozen vegetables', 'milk', 'eggs', 'french fries', 'green tea'],
#  ['fresh tuna',
#   'spaghetti',
#   'olive oil',
#   'french wine',
#   'eggs',
#   'french fries',
#   'champagne',
#   'pancakes',
#   'light mayo'],
#  ['red wine', 'honey', 'hot dogs'],
#  ['milk', 'bacon', 'eggs', 'french fries', 'fresh bread'],
#  ['french fries', 'yogurt cake'],
#  ['milk'],
#  ['french fries'],
#  ['chocolate'],
#  ['burgers', 'ham', 'red wine'],
#  ['shrimp',
#   'pasta',
#   'tomatoes',
#   'energy bar',
#   'french wine',
#   'antioxydant juice',
#   'french fries',
#   'frozen smoothie',
#   'brownies'],
#  ['green tea'],
#  ['low fat yogurt'],
#  ['turkey',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'spinach',
#   'soda',
#   'energy drink',
#   'salt'],
#  ['turkey', 'eggs'],
#  ['bug spray', 'hot dogs'],
#  ['oil'],
#  ['soup',
#   'energy bar',
#   'chicken',
#   'eggs',
#   'cake',
#   'french fries',
#   'body spray',
#   'strawberries'],
#  ['spaghetti', 'chocolate', 'yogurt cake'],
#  ['turkey', 'mineral water', 'meatballs'],
#  ['ground beef',
#   'mineral water',
#   'chocolate',
#   'fromage blanc',
#   'bacon',
#   'hot dogs'],
#  ['frozen vegetables', 'mineral water', 'vegetables mix', 'escalope'],
#  ['herb & pepper', 'red wine', 'tomatoes'],
#  ['whole wheat pasta', 'olive oil', 'cereals', 'brownies', 'green tea'],
#  ['cookies'],
#  ['olive oil', 'cookies', 'mushroom cream sauce'],
#  ['ground beef', 'pancakes', 'cooking oil', 'gluten free bar', 'light mayo'],
#  ['mineral water', 'french fries'],
#  ['herb & pepper'],
#  ['salmon'],
#  ['eggs', 'escalope'],
#  ['mineral water', 'tomato juice'],
#  ['mineral water'],
#  ['shrimp', 'mineral water', 'soup', 'black tea'],
#  ['cake', 'frozen smoothie'],
#  ['turkey',
#   'burgers',
#   'grated cheese',
#   'tomatoes',
#   'chocolate',
#   'fromage blanc',
#   'honey',
#   'whole wheat rice'],
#  ['frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'olive oil',
#   'pancakes'],
#  ['turkey',
#   'burgers',
#   'ground beef',
#   'milk',
#   'olive oil',
#   'cake',
#   'fresh bread'],
#  ['whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'yams',
#   'mineral water',
#   'soup',
#   'chutney',
#   'cereals',
#   'energy drink',
#   'protein bar'],
#  ['eggs', 'whole wheat rice', 'cake', 'green tea', 'escalope'],
#  ['ground beef', 'yams', 'soup', 'avocado', 'salmon', 'green tea'],
#  ['milk'],
#  ['spaghetti', 'chocolate'],
#  ['whole wheat pasta', 'honey'],
#  ['whole wheat pasta', 'green tea'],
#  ['spaghetti', 'meatballs', 'vegetables mix', 'chocolate'],
#  ['eggs', 'low fat yogurt'],
#  ['fresh tuna',
#   'shrimp',
#   'pasta',
#   'mineral water',
#   'olive oil',
#   'eggs',
#   'cake',
#   'brownies',
#   'tomato juice'],
#  ['mineral water', 'green grapes', 'hot dogs', 'fresh bread'],
#  ['frozen vegetables', 'meatballs', 'eggs', 'chocolate'],
#  ['chocolate'],
#  ['meatballs', 'milk'],
#  ['low fat yogurt'],
#  ['green tea'],
#  ['escalope', 'pasta'],
#  ['pepper',
#   'chocolate',
#   'olive oil',
#   'french wine',
#   'salmon',
#   'rice',
#   'light mayo',
#   'fresh bread',
#   'magazines'],
#  ['red wine',
#   'french wine',
#   'vegetables mix',
#   'rice',
#   'clothes accessories',
#   'hot dogs',
#   'green tea'],
#  ['burgers',
#   'dessert wine',
#   'spaghetti',
#   'chicken',
#   'cake',
#   'protein bar',
#   'green tea'],
#  ['french wine', 'cake', 'fresh bread'],
#  ['burgers', 'frozen vegetables', 'flax seed', 'eggs'],
#  ['red wine'],
#  ['pepper', 'mineral water', 'energy bar', 'green grapes'],
#  ['milk', 'eggs', 'cake', 'chocolate', 'french fries', 'green tea'],
#  ['french fries'],
#  ['almonds'],
#  ['burgers', 'mineral water', 'green tea'],
#  ['milk', 'pancakes'],
#  ['pancakes', 'eggs', 'salt', 'tomato juice'],
#  ['mineral water'],
#  ['ham', 'spaghetti', 'mineral water', 'olive oil'],
#  ['salt', 'tomato juice', 'fresh bread'],
#  ['spaghetti', 'mushroom cream sauce'],
#  ['spaghetti', 'mineral water', 'eggs', 'pet food'],
#  ['frozen vegetables', 'spaghetti'],
#  ['energy drink'],
#  ['muffins'],
#  ['turkey', 'milk'],
#  ['cookies'],
#  ['chocolate'],
#  ['spaghetti',
#   'mineral water',
#   'eggs',
#   'cooking oil',
#   'chocolate',
#   'escalope'],
#  ['shrimp', 'frozen vegetables', 'pepper', 'spaghetti', 'green tea'],
#  ['burgers',
#   'fresh tuna',
#   'red wine',
#   'mineral water',
#   'french fries',
#   'hand protein bar',
#   'low fat yogurt'],
#  ['pancakes', 'eggs', 'energy drink', 'fresh bread'],
#  ['strong cheese',
#   'salmon',
#   'green tea',
#   'french fries',
#   'frozen smoothie',
#   'hot dogs'],
#  ['grated cheese',
#   'shrimp',
#   'pasta',
#   'tomatoes',
#   'milk',
#   'frozen smoothie',
#   'sandwich'],
#  ['herb & pepper', 'whole wheat pasta', 'olive oil', 'pancakes', 'eggs'],
#  ['spaghetti', 'antioxydant juice'],
#  ['chocolate', 'milk', 'almonds', 'eggs', 'strawberries', 'white wine'],
#  ['french fries', 'strawberries'],
#  ['mineral water'],
#  ['eggs'],
#  ['escalope'],
#  ['cake'],
#  ['whole wheat pasta', 'antioxydant juice', 'body spray', 'green tea'],
#  ['mineral water', 'oil', 'frozen smoothie'],
#  ['french fries', 'champagne'],
#  ['chocolate', 'french fries'],
#  ['frozen vegetables', 'spaghetti', 'eggs'],
#  ['hot dogs'],
#  ['chocolate', 'cookies'],
#  ['pancakes'],
#  ['shrimp', 'butter', 'chicken', 'salmon'],
#  ['chocolate', 'cookies', 'babies food'],
#  ['pepper', 'spaghetti', 'cake', 'chocolate', 'french fries', 'fresh bread'],
#  ['avocado', 'oil', 'cereals', 'french fries'],
#  ['herb & pepper',
#   'spaghetti',
#   'mineral water',
#   'spinach',
#   'eggs',
#   'oil',
#   'cooking oil',
#   'green tea',
#   'shampoo',
#   'tomato juice',
#   'low fat yogurt'],
#  ['herb & pepper',
#   'frozen vegetables',
#   'ground beef',
#   'pepper',
#   'spaghetti',
#   'mint green tea',
#   'french fries'],
#  ['french fries'],
#  ['green tea', 'tomato juice'],
#  ['eggs', 'whole wheat rice', 'chocolate'],
#  ['grated cheese',
#   'herb & pepper',
#   'red wine',
#   'spaghetti',
#   'mineral water',
#   'salmon',
#   'eggs',
#   'cooking oil',
#   'green tea'],
#  ['french fries',
#   'cookies',
#   'shallot',
#   'tomato juice',
#   'fresh bread',
#   'low fat yogurt'],
#  ['burgers', 'fresh tuna', 'spaghetti', 'muffins', 'honey'],
#  ['herb & pepper', 'ground beef', 'spaghetti', 'eggs', 'chicken'],
#  ['grated cheese', 'muffins', 'tomato juice', 'mayonnaise'],
#  ['whole wheat pasta',
#   'yams',
#   'mineral water',
#   'muffins',
#   'frozen smoothie',
#   'hot dogs',
#   'energy drink'],
#  ['burgers',
#   'spaghetti',
#   'soup',
#   'milk',
#   'olive oil',
#   'salmon',
#   'eggs',
#   'blueberries'],
#  ['chocolate', 'champagne', 'magazines'],
#  ['frozen vegetables',
#   'spaghetti',
#   'yams',
#   'mineral water',
#   'french wine',
#   'green grapes',
#   'rice',
#   'chocolate'],
#  ['tomato sauce', 'chocolate'],
#  ['milk', 'eggs'],
#  ['pet food'],
#  ['yogurt cake'],
#  ['green tea'],
#  ['escalope', 'pasta'],
#  ['herb & pepper', 'ground beef'],
#  ['mineral water', 'honey', 'brownies'],
#  ['turkey', 'eggs', 'cake', 'energy drink'],
#  ['turkey',
#   'burgers',
#   'dessert wine',
#   'ground beef',
#   'soup',
#   'salmon',
#   'eggs',
#   'gums',
#   'tomato juice',
#   'candy bars'],
#  ['spaghetti', 'mineral water', 'chicken'],
#  ['turkey', 'ground beef', 'carrots', 'french fries', 'melons'],
#  ['mineral water', 'eggs', 'low fat yogurt'],
#  ['turkey', 'cooking oil', 'shampoo'],
#  ['spaghetti', 'hot dogs'],
#  ['chocolate', 'green tea'],
#  ['grated cheese',
#   'pepper',
#   'mineral water',
#   'chocolate',
#   'eggs',
#   'cake',
#   'mashed potato',
#   'tomato juice'],
#  ['chocolate'],
#  ['spaghetti', 'olive oil', 'strong cheese', 'pancakes'],
#  ['red wine', 'mineral water', 'soup', 'rice', 'cookies'],
#  ['red wine', 'shrimp', 'spaghetti'],
#  ['green tea'],
#  ['mineral water', 'chicken', 'french fries', 'frozen smoothie'],
#  ['muffins'],
#  ['cake', 'chocolate'],
#  ['fresh tuna',
#   'tomatoes',
#   'mineral water',
#   'soup',
#   'avocado',
#   'meatballs',
#   'olive oil'],
#  ['turkey', 'french fries'],
#  ['burgers',
#   'turkey',
#   'herb & pepper',
#   'ground beef',
#   'pancakes',
#   'eggs',
#   'light cream',
#   'rice',
#   'champagne',
#   'fresh bread'],
#  ['escalope'],
#  ['chocolate', 'escalope', 'fresh bread'],
#  ['ham',
#   'spaghetti',
#   'french wine',
#   'vegetables mix',
#   'chocolate',
#   'french fries'],
#  ['avocado', 'light mayo'],
#  ['spaghetti', 'yams', 'butter', 'chocolate'],
#  ['energy bar', 'eggs', 'french fries'],
#  ['fresh tuna', 'barbecue sauce', 'eggplant'],
#  ['energy drink'],
#  ['whole wheat rice', 'french fries', 'hot dogs', 'green tea'],
#  ['mineral water', 'chicken', 'green tea'],
#  ['eggs', 'cake', 'mushroom cream sauce'],
#  ['escalope'],
#  ['antioxydant juice', 'escalope'],
#  ['shrimp', 'spaghetti', 'french fries'],
#  ['grated cheese', 'spaghetti', 'salmon', 'tomato juice'],
#  ['spaghetti', 'green tea'],
#  ['champagne', 'protein bar'],
#  ['mineral water', 'avocado', 'chocolate'],
#  ['tomatoes', 'champagne', 'green tea'],
#  ['chicken', 'french fries', 'escalope'],
#  ['frozen vegetables',
#   'tomatoes',
#   'eggs',
#   'green tea',
#   'frozen smoothie',
#   'light mayo'],
#  ['ground beef',
#   'chicken',
#   'cider',
#   'green grapes',
#   'honey',
#   'chocolate',
#   'french fries',
#   'champagne',
#   'frozen smoothie',
#   'escalope'],
#  ['french fries', 'champagne'],
#  ['mineral water', 'soup'],
#  ['frozen vegetables', 'spaghetti', 'milk', 'chocolate', 'babies food'],
#  ['honey', 'whole wheat rice'],
#  ['whole wheat rice', 'chicken', 'tomato juice'],
#  ['pancakes'],
#  ['green tea', 'protein bar', 'tomato juice', 'candy bars'],
#  ['french fries'],
#  ['mineral water'],
#  ['escalope'],
#  ['grated cheese',
#   'herb & pepper',
#   'whole wheat pasta',
#   'yams',
#   'mineral water',
#   'bacon',
#   'nonfat milk',
#   'spinach'],
#  ['spaghetti', 'milk'],
#  ['milk', 'chocolate', 'white wine'],
#  ['sandwich'],
#  ['chocolate', 'light mayo'],
#  ['shrimp',
#   'whole wheat pasta',
#   'spaghetti',
#   'meatballs',
#   'chicken',
#   'frozen smoothie',
#   'tomato juice'],
#  ['red wine', 'ground beef', 'spaghetti', 'mineral water', 'eggs'],
#  ['yams', 'melons'],
#  ['spaghetti', 'cooking oil'],
#  ['french fries'],
#  ['mineral water',
#   'milk',
#   'spinach',
#   'cooking oil',
#   'chocolate',
#   'frozen smoothie',
#   'hot dogs'],
#  ['tomato sauce', 'milk'],
#  ['shrimp', 'cider', 'eggs', 'french fries'],
#  ['champagne'],
#  ['salad'],
#  ['french fries'],
#  ['frozen vegetables',
#   'mineral water',
#   'energy bar',
#   'honey',
#   'rice',
#   'green tea'],
#  ['french fries', 'salad'],
#  ['honey', 'chocolate', 'french fries', 'brownies'],
#  ['green tea', 'strawberries', 'gluten free bar'],
#  ['frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'salmon',
#   'honey',
#   'extra dark chocolate',
#   'green tea',
#   'mushroom cream sauce',
#   'gluten free bar'],
#  ['grated cheese', 'tomatoes', 'mineral water', 'meatballs'],
#  ['shrimp', 'chocolate', 'water spray'],
#  ['turkey'],
#  ['turkey', 'eggs'],
#  ['turkey',
#   'frozen vegetables',
#   'tomatoes',
#   'soup',
#   'butter',
#   'french wine',
#   'pancakes',
#   'eggs',
#   'tomato juice',
#   'fresh bread',
#   'green tea'],
#  ['spaghetti'],
#  ['milk', 'frozen smoothie', 'low fat yogurt'],
#  ['burgers',
#   'mineral water',
#   'milk',
#   'whole wheat rice',
#   'cereals',
#   'chocolate',
#   'french fries'],
#  ['mineral water'],
#  ['tomatoes', 'mineral water', 'soup', 'cake', 'chocolate'],
#  ['mineral water'],
#  ['ground beef', 'spaghetti'],
#  ['pepper', 'frozen smoothie'],
#  ['yogurt cake'],
#  ['red wine', 'pancakes'],
#  ['candy bars'],
#  ['eggs', 'french fries', 'low fat yogurt'],
#  ['cookies'],
#  ['cookies'],
#  ['spaghetti',
#   'soup',
#   'vegetables mix',
#   'spinach',
#   'french fries',
#   'escalope',
#   'cauliflower',
#   'toothpaste'],
#  ['cookies'],
#  ['soup', 'olive oil', 'eggs', 'soda', 'corn'],
#  ['chocolate', 'frozen smoothie', 'low fat yogurt'],
#  ['spaghetti',
#   'mineral water',
#   'milk',
#   'pancakes',
#   'chocolate',
#   'french fries'],
#  ['mineral water'],
#  ['herb & pepper',
#   'frozen vegetables',
#   'tomato sauce',
#   'mineral water',
#   'soup',
#   'milk',
#   'olive oil',
#   'almonds'],
#  ['burgers', 'eggs'],
#  ['french fries'],
#  ['frozen smoothie', 'cottage cheese'],
#  ['tomatoes', 'mineral water', 'chocolate', 'light mayo'],
#  ['salmon',
#   'escalope',
#   'shallot',
#   'strawberries',
#   'fresh bread',
#   'low fat yogurt'],
#  ['energy bar'],
#  ['red wine',
#   'ground beef',
#   'spaghetti',
#   'pancakes',
#   'blueberries',
#   'oil',
#   'cooking oil',
#   'tomato juice'],
#  ['ground beef',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'frozen smoothie',
#   'champagne'],
#  ['cookies'],
#  ['salmon', 'escalope'],
#  ['cookies'],
#  ['low fat yogurt'],
#  ['eggs'],
#  ['red wine', 'butter', 'hot dogs'],
#  ['tomatoes', 'mineral water', 'soup', 'mashed potato'],
#  ['cookies'],
#  ['parmesan cheese', 'ground beef', 'salmon', 'pancakes', 'champagne'],
#  ['ground beef', 'yams', 'chocolate', 'olive oil', 'eggs'],
#  ['shrimp', 'salmon', 'eggs', 'cookies', 'hot dogs'],
#  ['magazines', 'mint'],
#  ['turkey',
#   'mineral water',
#   'eggs',
#   'cooking oil',
#   'extra dark chocolate',
#   'escalope'],
#  ['mineral water', 'mushroom cream sauce'],
#  ['grated cheese',
#   'frozen vegetables',
#   'mineral water',
#   'soup',
#   'milk',
#   'french wine'],
#  ['chocolate', 'cake'],
#  ['burgers', 'salt', 'white wine'],
#  ['energy drink'],
#  ['olive oil', 'cake', 'energy drink'],
#  ['ground beef', 'whole wheat rice'],
#  ['eggs', 'french fries'],
#  ['spaghetti', 'escalope', 'mushroom cream sauce'],
#  ['mineral water',
#   'fromage blanc',
#   'whole wheat rice',
#   'cake',
#   'french fries'],
#  ['turkey',
#   'burgers',
#   'frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'milk',
#   'eggs',
#   'cake',
#   'light mayo'],
#  ['green tea', 'cottage cheese'],
#  ['fresh tuna', 'eggs', 'champagne'],
#  ['cookies'],
#  ['cookies'],
#  ['cookies'],
#  ['tomatoes', 'mineral water', 'eggplant'],
#  ['grated cheese',
#   'tomatoes',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'honey',
#   'chicken',
#   'chocolate',
#   'french fries'],
#  ['protein bar'],
#  ['herb & pepper',
#   'red wine',
#   'shrimp',
#   'mineral water',
#   'barbecue sauce',
#   'protein bar'],
#  ['burgers',
#   'ham',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'eggs',
#   'french fries',
#   'escalope',
#   'pancakes',
#   'low fat yogurt'],
#  ['french fries'],
#  ['frozen vegetables',
#   'soup',
#   'milk',
#   'eggs',
#   'whole wheat rice',
#   'chocolate',
#   'escalope',
#   'melons'],
#  ['spaghetti'],
#  ['herb & pepper',
#   'shrimp',
#   'soup',
#   'eggs',
#   'oil',
#   'cooking oil',
#   'energy drink',
#   'protein bar',
#   'low fat yogurt'],
#  ['ham',
#   'grated cheese',
#   'herb & pepper',
#   'shrimp',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'carrots'],
#  ['ham',
#   'red wine',
#   'ground beef',
#   'yams',
#   'mineral water',
#   'chocolate',
#   'low fat yogurt'],
#  ['chocolate',
#   'french fries',
#   'mushroom cream sauce',
#   'cottage cheese',
#   'low fat yogurt'],
#  ['eggs'],
#  ['cake', 'cookies'],
#  ['grated cheese', 'mineral water', 'cake', 'chocolate bread'],
#  ['tomatoes', 'almonds', 'cake', 'champagne', 'low fat yogurt'],
#  ['herb & pepper',
#   'shrimp',
#   'frozen vegetables',
#   'milk',
#   'butter',
#   'salmon',
#   'eggs',
#   'chocolate'],
#  ['herb & pepper',
#   'shrimp',
#   'whole wheat pasta',
#   'whole wheat rice',
#   'chicken',
#   'green tea',
#   'cauliflower'],
#  ['eggs', 'corn'],
#  ['shrimp',
#   'frozen vegetables',
#   'tomato sauce',
#   'mineral water',
#   'chocolate',
#   'soup',
#   'olive oil',
#   'salmon',
#   'green beans',
#   'champagne'],
#  ['ham',
#   'herb & pepper',
#   'tomato sauce',
#   'mineral water',
#   'green grapes',
#   'eggs',
#   'gums',
#   'light cream',
#   'oil',
#   'green tea',
#   'mint'],
#  ['energy bar', 'cake', 'chocolate'],
#  ['herb & pepper', 'shrimp', 'spaghetti', 'eggs'],
#  ['fresh tuna', 'mineral water', 'honey', 'cooking oil'],
#  ['red wine',
#   'mineral water',
#   'oil',
#   'ketchup',
#   'chili',
#   'pet food',
#   'eggplant',
#   'green tea',
#   'escalope',
#   'tomato juice',
#   'low fat yogurt'],
#  ['herb & pepper',
#   'shrimp',
#   'mineral water',
#   'pancakes',
#   'eggs',
#   'cake',
#   'blueberries',
#   'tea',
#   'frozen smoothie'],
#  ['ground beef', 'mineral water', 'protein bar'],
#  ['shrimp',
#   'frozen vegetables',
#   'parmesan cheese',
#   'spaghetti',
#   'salmon',
#   'carrots',
#   'frozen smoothie',
#   'pasta',
#   'mashed potato',
#   'shallot',
#   'light mayo',
#   'magazines'],
#  ['milk', 'chocolate'],
#  ['frozen vegetables',
#   'ground beef',
#   'spaghetti',
#   'olive oil',
#   'whole wheat rice',
#   'eggplant',
#   'cottage cheese'],
#  ['turkey', 'ground beef', 'low fat yogurt'],
#  ['herb & pepper',
#   'spaghetti',
#   'mineral water',
#   'whole wheat rice',
#   'cake',
#   'hot dogs',
#   'green tea'],
#  ['green tea'],
#  ['cookies'],
#  ['eggs', 'cookies'],
#  ['spaghetti',
#   'eggs',
#   'ham',
#   'chocolate',
#   'french fries',
#   'champagne',
#   'brownies',
#   'pancakes',
#   'light mayo'],
#  ['red wine', 'spaghetti', 'milk', 'eggs', 'chocolate'],
#  ['turkey',
#   'burgers',
#   'pancakes',
#   'french fries',
#   'strawberries',
#   'green tea'],
#  ['escalope'],
#  ['frozen vegetables', 'pancakes', 'eggs', 'cake'],
#  ['french fries'],
#  ['turkey', 'ground beef', 'pepper', 'spaghetti', 'honey', 'cookies'],
#  ['chocolate',
#   'red wine',
#   'tomato sauce',
#   'olive oil',
#   'chili',
#   'french fries',
#   'cookies',
#   'salt',
#   'fresh bread',
#   'magazines'],
#  ['green tea', 'french fries'],
#  ['mineral water'],
#  ['cooking oil'],
#  ['frozen vegetables', 'spaghetti'],
#  ['ham', 'spaghetti'],
#  ['chicken', 'chocolate', 'cookies'],
#  ['low fat yogurt'],
#  ['eggs', 'cake', 'low fat yogurt'],
#  ['shrimp',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'milk',
#   'bramble',
#   'frozen smoothie',
#   'cottage cheese'],
#  ['mineral water', 'eggs', 'protein bar'],
#  ['turkey', 'shrimp', 'meatballs', 'butter', 'eggs', 'salad', 'green tea'],
#  ['fresh tuna',
#   'spaghetti',
#   'chocolate',
#   'olive oil',
#   'chicken',
#   'french fries'],
#  ['turkey', 'shrimp', 'escalope', 'hot dogs'],
#  ['burgers', 'pepper', 'soup', 'milk', 'pancakes', 'green tea'],
#  ['pancakes'],
#  ['mineral water', 'pancakes', 'eggs', 'french fries'],
#  ['eggs', 'escalope', 'low fat yogurt'],
#  ['mineral water', 'french wine', 'gluten free bar'],
#  ['burgers', 'ground beef', 'spaghetti', 'eggs', 'french fries'],
#  ['soup', 'meatballs', 'milk', 'energy bar'],
#  ['chocolate'],
#  ['herb & pepper'],
#  ['turkey', 'red wine', 'mineral water', 'eggs', 'bramble'],
#  ['burgers',
#   'ham',
#   'frozen vegetables',
#   'tomatoes',
#   'cake',
#   'chicken',
#   'green tea',
#   'toothpaste',
#   'mint'],
#  ['grated cheese', 'mineral water', 'olive oil', 'energy bar'],
#  ['milk', 'cake', 'green tea'],
#  ['mineral water',
#   'almonds',
#   'cooking oil',
#   'cereals',
#   'protein bar',
#   'white wine',
#   'green tea'],
#  ['turkey',
#   'fresh tuna',
#   'mineral water',
#   'milk',
#   'eggs',
#   'cake',
#   'burger sauce',
#   'chicken',
#   'french fries',
#   'frozen smoothie',
#   'fresh bread'],
#  ['herb & pepper',
#   'mineral water',
#   'whole wheat rice',
#   'yogurt cake',
#   'low fat yogurt'],
#  ['tomatoes', 'spaghetti', 'meatballs', 'chicken', 'eggs'],
#  ['burgers', 'mineral water', 'eggs', 'green tea', 'pancakes'],
#  ['cake', 'green tea'],
#  ['chocolate', 'herb & pepper', 'yogurt cake'],
#  ['ground beef',
#   'spaghetti',
#   'mineral water',
#   'almonds',
#   'salmon',
#   'nonfat milk',
#   'green grapes',
#   'pancakes'],
#  ['mineral water', 'vegetables mix', 'eggs'],
#  ['protein bar'],
#  ['eggs', 'eggplant'],
#  ['mayonnaise'],
#  ['milk', 'bug spray', 'oatmeal', 'sandwich', 'asparagus'],
#  ['frozen vegetables', 'soup', 'almonds', 'eggs', 'french fries'],
#  ['frozen vegetables'],
#  ['soup', 'butter', 'shampoo'],
#  ['herb & pepper', 'whole wheat pasta', 'pepper', 'eggs'],
#  ['mineral water',
#   'whole wheat rice',
#   'rice',
#   'cooking oil',
#   'chocolate',
#   'fresh bread',
#   'low fat yogurt'],
#  ['grated cheese', 'butter', 'chocolate', 'french fries', 'cookies'],
#  ['spaghetti',
#   'soup',
#   'milk',
#   'chutney',
#   'cooking oil',
#   'asparagus',
#   'tomato juice'],
#  ['eggs',
#   'french fries',
#   'frozen smoothie',
#   'cookies',
#   'champagne',
#   'cottage cheese',
#   'green tea'],
#  ['turkey', 'tomatoes', 'mineral water', 'eggs', 'blueberries'],
#  ['milk', 'tomato juice', 'low fat yogurt', 'green tea'],
#  ['mineral water', 'soup', 'almonds', 'cereals', 'green tea'],
#  ['chocolate', 'light mayo'],
#  ['turkey', 'herb & pepper', 'chocolate'],
#  ['eggs', 'french fries', 'green tea'],
#  ['mineral water', 'cake', 'chocolate', 'tomato juice'],
#  ['eggs'],
#  ['chocolate',
#   'pepper',
#   'spaghetti',
#   'mineral water',
#   'whole wheat rice',
#   'champagne',
#   'mushroom cream sauce'],
#  ['frozen vegetables', 'pepper', 'mineral water', 'chocolate', 'white wine'],
#  ['burgers',
#   'turkey',
#   'spaghetti',
#   'milk',
#   'whole wheat rice',
#   'oil',
#   'tomato juice',
#   'green tea'],
#  ['burgers',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'french wine',
#   'french fries',
#   'light mayo',
#   'low fat yogurt'],
#  ['butter', 'green grapes', 'frozen smoothie', 'low fat yogurt'],
#  ['eggs', 'low fat yogurt'],
#  ['cookies'],
#  ['milk', 'energy drink'],
#  ['olive oil', 'energy drink'],
#  ['eggs', 'cookies'],
#  ['eggs'],
#  ['energy bar', 'eggs'],
#  ['eggs'],
#  ['eggs', 'green tea'],
#  ['escalope'],
#  ['shrimp', 'soup', 'milk', 'almonds', 'eggs', 'oil', 'chocolate'],
#  ['chocolate', 'french fries'],
#  ['cake'],
#  ['pancakes', 'eggs', 'cake', 'green tea', 'toothpaste'],
#  ['herb & pepper', 'tomatoes', 'ground beef', 'eggs', 'cooking oil'],
#  ['cider', 'eggs', 'chocolate', 'low fat yogurt'],
#  ['frozen vegetables', 'cider', 'eggs', 'french fries'],
#  ['yams', 'cookies', 'toothpaste'],
#  ['mineral water', 'milk', 'escalope', 'champagne', 'hot dogs', 'fresh bread'],
#  ['ham',
#   'herb & pepper',
#   'spaghetti',
#   'mineral water',
#   'chocolate',
#   'pancakes',
#   'eggs'],
#  ['pepper',
#   'mineral water',
#   'escalope',
#   'shallot',
#   'protein bar',
#   'white wine'],
#  ['turkey', 'parmesan cheese', 'spaghetti', 'meatballs', 'butter'],
#  ['herb & pepper', 'eggs', 'escalope'],
#  ['herb & pepper'],
#  ['burgers', 'escalope', 'shallot'],
#  ['chocolate', 'pepper', 'tomato sauce', 'tomato juice'],
#  ['cookies'],
#  ['burgers',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'escalope',
#   'melons'],
#  ['frozen vegetables', 'mineral water', 'soup', 'milk', 'olive oil'],
#  ['turkey', 'eggs', 'french fries', 'asparagus', 'low fat yogurt', 'zucchini'],
#  ['burgers', 'frozen vegetables', 'gums'],
#  ['herb & pepper', 'frozen vegetables', 'ground beef', 'milk'],
#  ['frozen vegetables', 'cake', 'light cream', 'mashed potato'],
#  ['milk'],
#  ['turkey', 'eggs', 'barbecue sauce'],
#  ['escalope'],
#  ['parmesan cheese', 'french fries'],
#  ['energy bar', 'eggs'],
#  ['soup', 'escalope', 'mint'],
#  ['muffins', 'chicken', 'zucchini'],
#  ['burgers', 'eggs', 'french fries', 'cookies', 'green tea'],
#  ['spaghetti'],
#  ['avocado', 'energy bar', 'chocolate'],
#  ['cookies'],
#  ['green tea'],
#  ['whole wheat pasta', 'spaghetti', 'mineral water', 'olive oil'],
#  ['grated cheese',
#   'frozen vegetables',
#   'eggs',
#   'gums',
#   'escalope',
#   'low fat yogurt'],
#  ['grated cheese',
#   'herb & pepper',
#   'mineral water',
#   'pancakes',
#   'chocolate',
#   'escalope',
#   'tomato juice'],
#  ['chocolate', 'spaghetti', 'yams', 'flax seed', 'salmon', 'frozen smoothie'],
#  ['burger sauce', 'oil'],
#  ['eggs', 'french fries', 'energy drink'],
#  ['mineral water'],
#  ['grated cheese', 'ground beef', 'mineral water', 'olive oil'],
#  ['eggs', 'low fat yogurt'],
#  ['parmesan cheese', 'spaghetti', 'soda', 'pet food', 'white wine'],
#  ['turkey',
#   'shrimp',
#   'olive oil',
#   'chicken',
#   'eggs',
#   'extra dark chocolate',
#   'melons',
#   'fresh bread'],
#  ['pickles',
#   'ground beef',
#   'yams',
#   'milk',
#   'strong cheese',
#   'salmon',
#   'muffins',
#   'french fries',
#   'escalope'],
#  ['pepper', 'spaghetti', 'light cream'],
#  ['frozen vegetables', 'mineral water', 'eggs'],
#  ['spaghetti', 'chicken', 'tea', 'pancakes', 'gluten free bar'],
#  ['fresh tuna',
#   'turkey',
#   'herb & pepper',
#   'spaghetti',
#   'mineral water',
#   'mint'],
#  ['spaghetti', 'mineral water', 'cooking oil', 'escalope'],
#  ['soup'],
#  ['burgers', 'herb & pepper', 'spaghetti'],
#  ['cookies', 'shallot', 'strawberries'],
#  ['fresh tuna',
#   'chocolate',
#   'shrimp',
#   'whole wheat pasta',
#   'pepper',
#   'mineral water',
#   'soup',
#   'milk',
#   'salmon'],
#  ['yams',
#   'mineral water',
#   'avocado',
#   'milk',
#   'butter',
#   'cooking oil',
#   'chocolate',
#   'cottage cheese'],
#  ['ham', 'eggs', 'french fries', 'energy drink'],
#  ['mineral water', 'avocado'],
#  ['cookies'],
#  ['chocolate', 'butter', 'eggs', 'green tea', 'cottage cheese', 'mayonnaise'],
#  ['eggs', 'mushroom cream sauce', 'low fat yogurt'],
#  ['antioxydant juice', 'chocolate'],
#  ['ground beef', 'spaghetti', 'french fries', 'green tea'],
#  ['cake'],
#  ['turkey',
#   'red wine',
#   'mineral water',
#   'pancakes',
#   'eggs',
#   'whole wheat rice',
#   'cooking oil',
#   'chocolate',
#   'zucchini'],
#  ['chocolate', 'parmesan cheese', 'mineral water', 'olive oil', 'bacon'],
#  ['green grapes', 'gums'],
#  ['shrimp',
#   'frozen vegetables',
#   'parmesan cheese',
#   'milk',
#   'eggs',
#   'cooking oil',
#   'chocolate',
#   'french fries'],
#  ['ground beef', 'mineral water', 'milk', 'eggs'],
#  ['escalope'],
#  ['turkey', 'cookies'],
#  ['ground beef', 'mineral water', 'chocolate', 'green tea'],
#  ['whole wheat pasta',
#   'spaghetti',
#   'olive oil',
#   'butter',
#   'chocolate',
#   'french fries',
#   'tomato juice',
#   'low fat yogurt'],
#  ['red wine'],
#  ['frozen vegetables',
#   'mineral water',
#   'eggs',
#   'gums',
#   'cooking oil',
#   'frozen smoothie',
#   'cottage cheese',
#   'low fat yogurt'],
#  ['turkey', 'grated cheese', 'energy bar', 'vegetables mix', 'brownies'],
#  ['turkey', 'burgers', 'nonfat milk', 'cooking oil', 'energy drink'],
#  ['french fries', 'low fat yogurt'],
#  ['muffins'],
#  ['herb & pepper',
#   'mineral water',
#   'salmon',
#   'whole wheat rice',
#   'cake',
#   'green tea'],
#  ['mineral water', 'cake', 'chocolate', 'low fat yogurt', 'candy bars'],
#  ['grated cheese',
#   'mineral water',
#   'chocolate',
#   'soup',
#   'milk',
#   'olive oil',
#   'light cream',
#   'chicken'],
#  ['mineral water', 'strawberries'],
#  ['escalope'],
#  ['grated cheese',
#   'parmesan cheese',
#   'butter',
#   'whole wheat rice',
#   'cooking oil'],
#  ['ground beef', 'mint'],
#  ['cookies'],
#  ['ground beef', 'avocado', 'milk', 'chicken', 'rice'],
#  ['frozen vegetables', 'soup', 'eggs', 'low fat yogurt'],
#  ['herb & pepper',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'chocolate',
#   'black tea',
#   'french wine',
#   'pancakes',
#   'rice',
#   'green tea',
#   'toothpaste'],
#  ['shrimp',
#   'parmesan cheese',
#   'mineral water',
#   'eggs',
#   'cake',
#   'oil',
#   'cooking oil',
#   'toothpaste',
#   'low fat yogurt'],
#  ['ham',
#   'herb & pepper',
#   'frozen vegetables',
#   'tomatoes',
#   'spaghetti',
#   'olive oil',
#   'black tea',
#   'vegetables mix',
#   'cooking oil',
#   'green tea',
#   'frozen smoothie',
#   'mint'],
#  ['chicken', 'cider', 'eggs'],
#  ['shrimp', 'tomato sauce', 'mineral water', 'chocolate', 'escalope', 'mint'],
#  ['energy drink'],
#  ['ham',
#   'spaghetti',
#   'mineral water',
#   'energy bar',
#   'eggs',
#   'cooking oil',
#   'pancakes',
#   'fresh bread',
#   'low fat yogurt'],
#  ['shrimp', 'frozen vegetables', 'tomatoes'],
#  ['turkey',
#   'herb & pepper',
#   'frozen vegetables',
#   'ground beef',
#   'yams',
#   'mineral water',
#   'salmon'],
#  ['shrimp', 'mineral water'],
#  ['turkey', 'ground beef', 'spaghetti', 'soup', 'escalope', 'yogurt cake'],
#  ['shrimp',
#   'pepper',
#   'mineral water',
#   'soup',
#   'milk',
#   'eggs',
#   'rice',
#   'barbecue sauce',
#   'clothes accessories',
#   'cookies'],
#  ['burgers', 'pancakes'],
#  ['low fat yogurt'],
#  ['mineral water', 'milk'],
#  ['milk'],
#  ['chocolate'],
#  ['whole wheat pasta', 'mineral water', 'olive oil', 'pancakes'],
#  ['yams', 'mineral water', 'eggs', 'cake'],
#  ['turkey', 'french fries'],
#  ['shrimp',
#   'spaghetti',
#   'yams',
#   'mineral water',
#   'chocolate',
#   'olive oil',
#   'light cream',
#   'chicken',
#   'green tea',
#   'french fries',
#   'sandwich',
#   'white wine'],
#  ['mineral water', 'milk', 'salmon', 'green tea', 'cookies', 'fresh bread'],
#  ['spaghetti', 'olive oil'],
#  ['herb & pepper', 'spaghetti'],
#  ['spaghetti',
#   'mineral water',
#   'soup',
#   'salmon',
#   'pancakes',
#   'chicken',
#   'mint green tea',
#   'low fat yogurt'],
#  ['frozen vegetables',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'chocolate',
#   'milk',
#   'olive oil',
#   'almonds',
#   'french wine',
#   'yogurt cake',
#   'fresh bread'],
#  ['green tea'],
#  ['burgers',
#   'grated cheese',
#   'spaghetti',
#   'nonfat milk',
#   'eggs',
#   'gums',
#   'chocolate',
#   'tomato juice',
#   'low fat yogurt'],
#  ['ham',
#   'ground beef',
#   'olive oil',
#   'energy bar',
#   'chicken',
#   'brownies',
#   'white wine'],
#  ['whole wheat pasta',
#   'mineral water',
#   'olive oil',
#   'cooking oil',
#   'frozen smoothie',
#   'green tea'],
#  ['vegetables mix', 'champagne'],
#  ['olive oil'],
#  ['herb & pepper', 'ground beef', 'escalope', 'pancakes', 'green tea'],
#  ['herb & pepper',
#   'frozen vegetables',
#   'ground beef',
#   'tomato sauce',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'french wine',
#   'eggs',
#   'whole wheat rice',
#   'chocolate',
#   'escalope',
#   'hot dogs',
#   'green tea'],
#  ['yams', 'carrots'],
#  ['chicken'],
#  ['turkey',
#   'burgers',
#   'herb & pepper',
#   'ground beef',
#   'yams',
#   'mineral water',
#   'avocado',
#   'milk',
#   'almonds',
#   'muffins',
#   'eggs',
#   'french fries'],
#  ['whole wheat pasta', 'salmon', 'antioxydant juice', 'mint green tea'],
#  ['chocolate', 'french fries', 'strawberries', 'fresh bread'],
#  ['burgers',
#   'chocolate',
#   'shrimp',
#   'whole wheat pasta',
#   'ground beef',
#   'soup',
#   'energy bar',
#   ' asparagus'],
#  ['mineral water',
#   'butter',
#   'pancakes',
#   'french fries',
#   'frozen smoothie',
#   'white wine',
#   'low fat yogurt'],
#  ['muffins', 'eggs'],
#  ['turkey', 'shrimp', 'frozen vegetables', 'eggs'],
#  ['burgers', 'eggs', 'yogurt cake'],
#  ['burgers',
#   'fresh tuna',
#   'shrimp',
#   'frozen vegetables',
#   'whole wheat pasta',
#   'yams',
#   'mineral water',
#   'olive oil',
#   'almonds',
#   'cake',
#   'chicken',
#   'extra dark chocolate'],
#  ['herb & pepper', 'ground beef', 'mineral water', 'chicken'],
#  ['frozen smoothie'],
#  ['chicken', 'tomato juice'],
#  ['whole wheat pasta', 'olive oil'],
#  ['milk', 'energy bar', 'green tea'],
#  ['grated cheese', 'herb & pepper'],
#  ['escalope', 'green tea'],
#  ['soup', 'meatballs', 'milk', 'almonds', 'green tea'],
#  ['herb & pepper', 'pet food', 'cookies'],
#  ['grated cheese',
#   'whole wheat pasta',
#   'olive oil',
#   'energy bar',
#   'light cream',
#   'oil',
#   'french fries',
#   'pancakes',
#   'low fat yogurt'],
#  ['honey'],
#  ['parmesan cheese',
#   'mineral water',
#   'fromage blanc',
#   'eggs',
#   'honey',
#   'frozen smoothie'],
#  ['bramble', 'zucchini'],
#  ['ground beef',
#   'pepper',
#   'milk',
#   'eggs',
#   'green tea',
#   'chocolate',
#   'white wine'],
#  ['chocolate',
#   'red wine',
#   'butter',
#   'french fries',
#   'cookies',
#   'low fat yogurt'],
#  ['chocolate', 'spaghetti', 'bug spray'],
#  ['cookies'],
#  ['spaghetti',
#   'mineral water',
#   'vegetables mix',
#   'eggs',
#   'whole wheat rice',
#   'fresh bread'],
#  ['chocolate',
#   'grated cheese',
#   'mineral water',
#   'salmon',
#   'whole wheat rice',
#   'burger sauce',
#   'escalope',
#   'mushroom cream sauce',
#   'low fat yogurt'],
#  ['spaghetti', 'champagne'],
#  ['frozen vegetables', 'mineral water'],
#  ['mineral water', 'body spray', 'low fat yogurt'],
#  ['herb & pepper', 'red wine', 'whole wheat pasta', 'cake', 'tomato juice'],
#  ['burgers', 'parmesan cheese', 'eggs', 'french fries', 'hot dogs'],
#  ['mineral water', 'eggs', 'pancakes'],
#  ['eggs', 'french fries'],
#  ['shrimp', 'frozen vegetables', 'tomatoes', 'spaghetti'],
#  ['mineral water',
#   'almonds',
#   'pancakes',
#   'chocolate',
#   'french fries',
#   'green tea'],
#  ['cake', 'french fries', 'escalope'],
#  ['frozen vegetables',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'black tea',
#   'french wine',
#   'cider',
#   'chutney',
#   'salmon'],
#  ['almonds', 'cake', 'low fat yogurt'],
#  ['french fries'],
#  ['hot dogs'],
#  ['mineral water',
#   'soup',
#   'chicken',
#   'light cream',
#   'green tea',
#   'chocolate',
#   'champagne',
#   'low fat yogurt'],
#  ['ground beef', 'olive oil'],
#  ['french fries', 'cookies', 'green tea'],
#  ['soup',
#   'blueberries',
#   'cooking oil',
#   'chocolate',
#   'cookies',
#   'champagne',
#   'salt'],
#  ['chocolate', 'french fries', 'frozen smoothie', 'escalope', 'fresh bread'],
#  ['yams', 'mint'],
#  ['frozen vegetables',
#   'ground beef',
#   'salmon',
#   'muffins',
#   'chocolate',
#   'magazines'],
#  ['fresh tuna',
#   'herb & pepper',
#   'parmesan cheese',
#   'milk',
#   'olive oil',
#   'pancakes',
#   'honey',
#   'cake',
#   'chocolate'],
#  ['grated cheese',
#   'shrimp',
#   'butter',
#   'whole wheat rice',
#   'french fries',
#   'escalope',
#   'cookies',
#   'cottage cheese'],
#  ['energy bar', 'eggs', 'french fries', 'champagne', 'body spray'],
#  ['burgers', 'eggs', 'french fries'],
#  ['burgers',
#   'shrimp',
#   'mineral water',
#   'milk',
#   'eggs',
#   'chocolate',
#   'french fries',
#   'fresh bread'],
#  ['ground beef',
#   'mineral water',
#   'chocolate',
#   'milk',
#   'chicken',
#   'nonfat milk',
#   'green tea'],
#  ['mineral water', 'chicken'],
#  ['turkey', 'ground beef', 'spaghetti', 'milk', 'eggs', 'cake'],
#  ['french fries', 'green tea'],
#  ['french fries', 'escalope'],
#  ['turkey', 'sparkling water'],
#  ['whole wheat pasta',
#   'mineral water',
#   'olive oil',
#   'carrots',
#   'protein bar',
#   'low fat yogurt'],
#  ['cookies'],
#  ['turkey', 'grated cheese', 'honey', 'green beans', 'french fries'],
#  ['turkey',
#   'red wine',
#   'mineral water',
#   'chocolate',
#   'soup',
#   'light cream',
#   'rice',
#   'oil',
#   'chicken',
#   'barbecue sauce'],
#  ['turkey', 'eggs'],
#  ['low fat yogurt'],
#  ['nonfat milk', 'low fat yogurt'],
#  ['frozen vegetables', 'low fat yogurt'],
#  ['herb & pepper',
#   'parmesan cheese',
#   'whole wheat pasta',
#   'mineral water',
#   'milk',
#   'eggs',
#   'low fat yogurt',
#   'mint'],
#  ['yogurt cake', 'mint'],
#  ['sandwich', 'salt'],
#  ['shrimp', 'fresh bread', 'green tea'],
#  ['pepper', 'tomato sauce', 'escalope'],
#  ['mineral water', 'cake', 'protein bar', 'toothpaste'],
#  ['candy bars'],
#  ['red wine'],
#  ['spaghetti', 'mineral water', 'honey', 'strawberries'],
#  ['mineral water', 'eggs', 'green tea'],
#  ['grated cheese',
#   'frozen vegetables',
#   'parmesan cheese',
#   'french wine',
#   'french fries',
#   'fresh bread',
#   'green tea'],
#  ['frozen vegetables',
#   'parmesan cheese',
#   'whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'chocolate',
#   'avocado',
#   'milk',
#   'olive oil',
#   'muffins',
#   'cake'],
#  ['chocolate',
#   'grated cheese',
#   'shrimp',
#   'spaghetti',
#   'olive oil',
#   'honey',
#   'strawberries',
#   'mint'],
#  ['spaghetti', 'strawberries'],
#  ['burgers', 'chocolate', 'mushroom cream sauce'],
#  ['mineral water', 'olive oil', 'extra dark chocolate'],
#  ['eggs', 'green tea'],
#  ['tomato juice'],
#  ['muffins', 'low fat yogurt'],
#  ['soup',
#   'olive oil',
#   'pancakes',
#   'light cream',
#   'champagne',
#   'low fat yogurt'],
#  ['mineral water', 'vegetables mix', 'low fat yogurt'],
#  ['pepper',
#   'mineral water',
#   'avocado',
#   'pancakes',
#   'eggs',
#   'honey',
#   'green tea',
#   'chocolate'],
#  ['pickles', 'burgers', 'almonds', 'honey', 'frozen smoothie'],
#  ['bug spray', 'clothes accessories', 'cottage cheese'],
#  ['frozen vegetables',
#   'ground beef',
#   'spaghetti',
#   'pancakes',
#   'honey',
#   'whole wheat rice',
#   'green beans',
#   'french fries',
#   'frozen smoothie',
#   'mashed potato'],
#  ['spaghetti', 'mineral water', 'milk'],
#  ['pancakes'],
#  ['muffins'],
#  ['frozen vegetables', 'oil', 'cereals'],
#  ['turkey',
#   'shrimp',
#   'mineral water',
#   'milk',
#   'almonds',
#   'strong cheese',
#   'cake',
#   'frozen smoothie'],
#  ['chocolate', 'rice', 'eggplant', 'hand protein bar', 'zucchini'],
#  ['spaghetti', 'meatballs', 'nonfat milk', 'hot dogs'],
#  ['frozen vegetables', 'cake', 'cookies', 'pancakes'],
#  ['butter', 'bug spray', 'french fries', 'yogurt cake', 'green tea'],
#  ['herb & pepper'],
#  ['soup', 'milk', 'cider', 'chicken', 'green beans'],
#  ['shrimp',
#   'spaghetti',
#   'mineral water',
#   'avocado',
#   'milk',
#   'salmon',
#   'frozen smoothie',
#   'escalope',
#   'hot dogs'],
#  ['milk', 'whole wheat rice', 'escalope', 'champagne'],
#  ['escalope', 'pasta', 'mushroom cream sauce'],
#  ['parmesan cheese'],
#  ['grated cheese', 'spaghetti', 'french fries'],
#  ['burgers',
#   'shrimp',
#   'whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'olive oil',
#   'chicken',
#   'salmon',
#   'pancakes',
#   'cake'],
#  ['turkey',
#   'chocolate',
#   'grated cheese',
#   'frozen vegetables',
#   'ground beef',
#   'spaghetti',
#   'milk',
#   'butter',
#   'bacon',
#   'whole wheat rice'],
#  ['turkey',
#   'pepper',
#   'chocolate',
#   'fromage blanc',
#   'eggs',
#   'green tea',
#   'escalope'],
#  ['tomatoes', 'ground beef', 'avocado', 'milk', 'pancakes', 'green tea'],
#  ['turkey', 'mineral water', 'green tea', 'protein bar'],
#  ['mineral water', 'low fat yogurt'],
#  ['pancakes', 'tomato juice', 'candy bars'],
#  ['yams',
#   'avocado',
#   'bacon',
#   'oil',
#   'french fries',
#   'brownies',
#   'pancakes',
#   'zucchini',
#   'green tea'],
#  ['shrimp',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'milk',
#   'olive oil',
#   'chicken',
#   'cake',
#   'burger sauce',
#   'oil'],
#  ['chicken', 'cooking oil', 'tea'],
#  ['burgers',
#   'soup',
#   'vegetables mix',
#   'pancakes',
#   'body spray',
#   'melons',
#   'protein bar',
#   'asparagus',
#   'mayonnaise',
#   'mint',
#   'green tea'],
#  ['shrimp', 'pepper'],
#  ['spaghetti', 'olive oil', 'blueberries'],
#  ['muffins'],
#  ['grated cheese', 'herb & pepper', 'muffins', 'eggs', 'low fat yogurt'],
#  ['grated cheese',
#   'frozen vegetables',
#   'spaghetti',
#   'milk',
#   'gums',
#   'light cream',
#   'cooking oil',
#   'gluten free bar'],
#  ['pepper', 'pancakes', 'french fries', 'tomato juice'],
#  ['frozen vegetables',
#   'tomatoes',
#   'parmesan cheese',
#   'ground beef',
#   'tomato sauce',
#   'milk',
#   'extra dark chocolate',
#   'melons',
#   'mint',
#   'green tea'],
#  ['olive oil', 'chicken', 'chocolate', 'cookies', 'green tea'],
#  ['whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'chocolate',
#   'french wine',
#   'pancakes',
#   'eggs',
#   'frozen smoothie',
#   'sandwich',
#   'tomato juice'],
#  ['eggs', 'cottage cheese'],
#  ['muffins', 'cottage cheese'],
#  ['green tea', 'frozen smoothie', 'white wine'],
#  ['mineral water', 'chocolate', 'rice', 'champagne'],
#  ['mineral water'],
#  ['shrimp', 'whole wheat pasta', 'meatballs', 'milk'],
#  ['herb & pepper',
#   'parmesan cheese',
#   'ground beef',
#   'pepper',
#   'spaghetti',
#   'cream',
#   'black tea',
#   'almonds',
#   'french wine',
#   'pancakes',
#   'eggs'],
#  ['grated cheese',
#   'shrimp',
#   'parmesan cheese',
#   'ground beef',
#   'mineral water',
#   'mint'],
#  ['mineral water', 'rice'],
#  ['pancakes'],
#  ['mineral water', 'honey'],
#  ['burgers', 'ground beef', 'pancakes', 'salt'],
#  ['parmesan cheese', 'soda', 'french fries', 'brownies'],
#  ['whole wheat rice'],
#  ['ground beef',
#   'spaghetti',
#   'chicken',
#   'rice',
#   'oil',
#   'cooking oil',
#   'hot dogs',
#   'mint'],
#  ['butter', 'chocolate'],
#  ['pepper'],
#  ['herb & pepper', 'chocolate', 'champagne', 'yogurt cake', 'green tea'],
#  ['grated cheese', 'mineral water', 'eggs', 'escalope'],
#  ['cookies', 'yogurt cake', 'light mayo', 'green tea'],
#  ['milk', 'cooking oil'],
#  ['milk',
#   'olive oil',
#   'light cream',
#   'cooking oil',
#   'chicken',
#   'extra dark chocolate',
#   'cereals',
#   'french fries',
#   'frozen smoothie',
#   'pancakes',
#   'tomato juice',
#   'fresh bread',
#   'low fat yogurt'],
#  ['tomatoes',
#   'soup',
#   'avocado',
#   'milk',
#   'yogurt cake',
#   'energy drink',
#   'low fat yogurt',
#   'green tea'],
#  ['ham', 'chocolate', 'ground beef', 'mineral water', 'oil'],
#  ['green tea', 'champagne', 'escalope'],
#  ['chocolate'],
#  ['escalope', 'pasta'],
#  ['burgers',
#   'mineral water',
#   'olive oil',
#   'rice',
#   'antioxydant juice',
#   'frozen smoothie'],
#  ['green tea'],
#  ['grated cheese',
#   'tomato sauce',
#   'spaghetti',
#   'milk',
#   'pancakes',
#   'energy drink',
#   'white wine'],
#  ['turkey', 'spaghetti', 'strong cheese', 'strawberries'],
#  ['muffins'],
#  ['ground beef', 'spaghetti', 'cider', 'cooking oil', 'cookies'],
#  ['burgers',
#   'frozen vegetables',
#   'parmesan cheese',
#   'spaghetti',
#   'fromage blanc',
#   'vegetables mix',
#   'pancakes',
#   'honey',
#   'hot dogs',
#   'low fat yogurt'],
#  ['ground beef'],
#  ['green beans'],
#  ['frozen vegetables',
#   'mineral water',
#   'honey',
#   'whole wheat rice',
#   'champagne',
#   'escalope'],
#  ['parmesan cheese',
#   'milk',
#   'butter',
#   'black tea',
#   'eggs',
#   'frozen smoothie',
#   'light mayo',
#   'shampoo',
#   'low fat yogurt',
#   'green tea'],
#  ['mineral water', 'cake'],
#  ['turkey',
#   'mineral water',
#   'milk',
#   'pancakes',
#   'whole wheat rice',
#   'cooking oil',
#   'frozen smoothie',
#   'cookies',
#   'green tea'],
#  ['avocado', 'chocolate', 'french fries'],
#  ['green tea'],
#  ['chocolate', 'eggs', 'bug spray'],
#  ['grated cheese', 'muffins', 'french fries', 'body spray'],
#  ['mineral water', 'eggs', 'blueberries', 'soda', 'escalope'],
#  ['whole wheat rice'],
#  ['nonfat milk', 'cookies', 'mushroom cream sauce'],
#  ['french fries', 'champagne'],
#  ['mineral water', 'salmon'],
#  ['olive oil'],
#  ['turkey',
#   'tomatoes',
#   'ground beef',
#   'soup',
#   'milk',
#   'butter',
#   'honey',
#   'cake',
#   'mint green tea',
#   'brownies',
#   'salt'],
#  ['parmesan cheese',
#   'spaghetti',
#   'mineral water',
#   'chocolate',
#   'napkins',
#   'low fat yogurt'],
#  ['burgers',
#   'parmesan cheese',
#   'chocolate',
#   'soup',
#   'milk',
#   'olive oil',
#   'energy bar',
#   'butter',
#   'almonds',
#   'fromage blanc',
#   'eggs',
#   'cake',
#   'pancakes'],
#  ['shrimp', 'honey', 'pasta', 'energy drink', 'green tea'],
#  ['fresh tuna',
#   'chocolate',
#   'milk',
#   'french wine',
#   'muffins',
#   'pancakes',
#   'champagne',
#   'frozen smoothie'],
#  ['strawberries'],
#  ['herb & pepper'],
#  ['herb & pepper',
#   'frozen vegetables',
#   'tomatoes',
#   'parmesan cheese',
#   'ground beef',
#   'fromage blanc',
#   'eggs',
#   'honey',
#   'cake',
#   'rice',
#   'cereals',
#   'french fries',
#   'champagne'],
#  ['spaghetti',
#   'mineral water',
#   'milk',
#   'strong cheese',
#   'cereals',
#   'escalope',
#   'cottage cheese'],
#  ['turkey',
#   'burgers',
#   'fresh tuna',
#   'spaghetti',
#   'pancakes',
#   'eggs',
#   'cake',
#   'cottage cheese',
#   'energy drink',
#   'gluten free bar'],
#  ['eggplant'],
#  ['burgers',
#   'spaghetti',
#   'mineral water',
#   'almonds',
#   'honey',
#   'extra dark chocolate',
#   'carrots',
#   'mashed potato'],
#  ['chocolate',
#   'french fries',
#   'frozen smoothie',
#   'cottage cheese',
#   'strawberries',
#   'light mayo'],
#  ['strong cheese'],
#  ['chocolate', 'french fries'],
#  ['chocolate', 'french fries', 'strawberries'],
#  ['turkey',
#   'frozen vegetables',
#   'avocado',
#   'cake',
#   'light cream',
#   'cooking oil',
#   'chicken',
#   'chocolate bread',
#   'mashed potato'],
#  ['olive oil', 'energy bar', 'shallot'],
#  ['turkey', 'shrimp'],
#  ['chocolate', 'spaghetti', 'champagne', 'yogurt cake'],
#  ['shrimp',
#   'mineral water',
#   'chocolate',
#   'avocado',
#   'butter',
#   'zucchini',
#   'green tea'],
#  ['muffins', 'green tea', 'brownies'],
#  ['yogurt cake'],
#  ['turkey',
#   'tomato sauce',
#   'milk',
#   'butter',
#   'bacon',
#   'salmon',
#   'cooking oil',
#   'chocolate',
#   'french fries',
#   'hot dogs',
#   'melons',
#   'protein bar',
#   'mint'],
#  ['grated cheese'],
#  ['butter', 'burger sauce', 'brownies', 'pancakes'],
#  ['butter',
#   'pancakes',
#   'whole wheat rice',
#   'green tea',
#   'french fries',
#   'cookies',
#   'shallot',
#   'low fat yogurt'],
#  ['shrimp', 'chocolate', 'butter', 'cooking oil', 'escalope'],
#  ['burgers',
#   'red wine',
#   'frozen vegetables',
#   'pepper',
#   'spaghetti',
#   'chocolate',
#   'milk',
#   'honey',
#   'whole wheat rice',
#   'cooking oil',
#   'cereals'],
#  ['turkey',
#   'ground beef',
#   'spaghetti',
#   'pancakes',
#   'eggs',
#   'cake',
#   'chili',
#   'pet food',
#   'chocolate'],
#  ['shrimp', 'milk', 'butter', 'chicken', 'salt', 'mayonnaise', 'green tea'],
#  ['fresh tuna',
#   'mineral water',
#   'fromage blanc',
#   'honey',
#   'gums',
#   'chocolate',
#   'french fries',
#   'frozen smoothie',
#   'sparkling water',
#   'strawberries',
#   'green tea'],
#  ['chocolate', 'cookies'],
#  ['sparkling water', 'light mayo'],
#  ['frozen vegetables',
#   'tomatoes',
#   'spaghetti',
#   'chicken',
#   'french fries',
#   'escalope'],
#  ['turkey',
#   'burgers',
#   'butter',
#   'vegetables mix',
#   'green grapes',
#   'pancakes',
#   'eggs',
#   'cake',
#   'barbecue sauce',
#   'green tea'],
#  ['red wine', 'shrimp', 'yams', 'eggs', 'burger sauce', 'yogurt cake'],
#  ['french fries', 'light mayo'],
#  ['burgers', 'ground beef', 'eggs', 'chocolate', 'champagne', 'zucchini'],
#  ['mushroom cream sauce'],
#  ['butter', 'mint green tea'],
#  ['whole wheat rice'],
#  ['gums'],
#  ['mineral water', 'french fries', 'champagne', 'green tea'],
#  ['cereals', 'salt', 'green tea'],
#  ['shrimp',
#   'spaghetti',
#   'chocolate',
#   'french fries',
#   'escalope',
#   'cookies',
#   'brownies',
#   'pancakes',
#   'melons'],
#  ['ham',
#   'spaghetti',
#   'yams',
#   'chicken',
#   'cooking oil',
#   'chocolate',
#   'hot dogs'],
#  ['eggs'],
#  ['ground beef', 'olive oil', 'bug spray', 'frozen smoothie', 'hot dogs'],
#  ['frozen vegetables',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'olive oil',
#   'escalope'],
#  ['whole wheat rice', 'oil', 'chicken', 'french fries', 'escalope'],
#  ['green tea'],
#  ['parmesan cheese', 'whole wheat rice', 'escalope', 'champagne'],
#  ['fresh tuna',
#   'frozen vegetables',
#   'chicken',
#   'fromage blanc',
#   'honey',
#   'light mayo'],
#  ['ground beef'],
#  ['muffins', 'champagne', 'cookies', 'fresh bread', 'green tea'],
#  ['frozen vegetables', 'spaghetti', 'chocolate', 'escalope', 'fresh bread'],
#  ['pickles', 'spaghetti', 'french fries', 'frozen smoothie'],
#  ['avocado'],
#  ['sandwich'],
#  ['spaghetti', 'milk', 'oil', 'shampoo'],
#  ['champagne'],
#  ['spaghetti'],
#  ['champagne'],
#  ['avocado', 'milk', 'butter', 'french fries', 'cookies'],
#  ['turkey',
#   'frozen vegetables',
#   'chicken',
#   'eggs',
#   'frozen smoothie',
#   'cauliflower',
#   'low fat yogurt'],
#  ['burgers',
#   'shrimp',
#   'tomatoes',
#   'milk',
#   'energy bar',
#   'almonds',
#   'chicken',
#   'chocolate',
#   'french fries',
#   'body spray'],
#  ['burgers',
#   'milk',
#   'cake',
#   'cooking oil',
#   'french fries',
#   'escalope',
#   'zucchini'],
#  ['tomatoes',
#   'spaghetti',
#   'chocolate',
#   'milk',
#   'olive oil',
#   'whole wheat rice',
#   'cake',
#   'frozen smoothie',
#   'protein bar'],
#  ['fresh tuna',
#   'red wine',
#   'pepper',
#   'spaghetti',
#   'fromage blanc',
#   'salmon',
#   'pancakes',
#   'eggs',
#   'honey',
#   'green tea'],
#  ['milk', 'low fat yogurt'],
#  ['shrimp', 'parmesan cheese', 'soup', 'chocolate', 'brownies'],
#  ['spaghetti', 'chicken'],
#  ['grated cheese', 'vegetables mix', 'nonfat milk', 'green tea'],
#  ['fresh tuna',
#   'parmesan cheese',
#   'cider',
#   'muffins',
#   'spinach',
#   'honey',
#   'oil'],
#  ['cake'],
#  ['shrimp', 'chocolate', 'mushroom cream sauce', 'candy bars'],
#  ['candy bars'],
#  ['avocado', 'honey'],
#  ['shrimp', 'frozen vegetables', 'tomatoes', 'cottage cheese'],
#  ['french fries'],
#  ['strawberries'],
#  ['ground beef', 'almonds', 'french fries', 'escalope'],
#  ['grated cheese', 'spaghetti'],
#  ['turkey', 'mineral water', 'butter', 'frozen smoothie'],
#  ['frozen vegetables', 'spaghetti', 'french fries', 'light mayo', 'green tea'],
#  ['burgers',
#   'ham',
#   'spaghetti',
#   'whole wheat rice',
#   'eggplant',
#   'chocolate',
#   'cookies',
#   'shallot',
#   'green tea'],
#  ['grated cheese',
#   'frozen vegetables',
#   'spaghetti',
#   'avocado',
#   'milk',
#   'blueberries',
#   'light cream',
#   'rice',
#   'green tea',
#   'chocolate',
#   'french fries',
#   'frozen smoothie',
#   'cookies',
#   'hot dogs'],
#  ['burgers', 'shrimp', 'tomatoes', 'bacon', 'whole wheat rice', 'green tea'],
#  ['parmesan cheese', 'pancakes'],
#  ['parmesan cheese', 'cake', 'hot dogs', 'green tea'],
#  ['spaghetti', 'milk', 'fromage blanc', 'ketchup', 'chocolate', 'babies food'],
#  ['mint'],
#  ['chocolate', 'mint'],
#  ['butter', 'french fries', 'salt', 'fresh bread'],
#  ['chocolate', 'french fries', 'strawberries', 'yogurt cake', 'light mayo'],
#  ['eggs', 'eggplant', 'cookies'],
#  ['yogurt cake'],
#  ['herb & pepper',
#   'spaghetti',
#   'meatballs',
#   'milk',
#   'olive oil',
#   'chicken',
#   'honey',
#   'frozen smoothie',
#   'escalope',
#   'pancakes'],
#  ['frozen vegetables', 'rice', 'chocolate'],
#  ['herb & pepper',
#   'ground beef',
#   'spaghetti',
#   'chocolate',
#   'milk',
#   'eggs',
#   'light cream'],
#  ['eggs', 'champagne'],
#  ['whole wheat pasta', 'ground beef', 'olive oil', 'blueberries', 'escalope'],
#  ['burgers',
#   'red wine',
#   'mineral water',
#   'eggs',
#   'oil',
#   'carrots',
#   'hand protein bar',
#   'tomato juice'],
#  ['chocolate',
#   'grated cheese',
#   'herb & pepper',
#   'mineral water',
#   'soup',
#   'olive oil'],
#  ['burgers',
#   'shrimp',
#   'mineral water',
#   'chicken',
#   'fromage blanc',
#   'salmon',
#   'eggs',
#   'cake',
#   'frozen smoothie',
#   'strawberries'],
#  ['green tea'],
#  ['cookies'],
#  ['french fries', 'cookies'],
#  ['milk', 'butter', 'eggs'],
#  ['eggs', 'mushroom cream sauce', 'low fat yogurt'],
#  ['eggs', 'green tea'],
#  ['mineral water', 'whole wheat rice'],
#  ['shrimp',
#   'frozen vegetables',
#   'parmesan cheese',
#   'mineral water',
#   'whole wheat rice',
#   'cake'],
#  ['whole wheat rice', 'pancakes'],
#  ['frozen vegetables',
#   'spaghetti',
#   'olive oil',
#   'butter',
#   'salmon',
#   'oil',
#   'cooking oil',
#   'frozen smoothie',
#   'cauliflower'],
#  ['green tea'],
#  ['fresh tuna', 'eggs', 'escalope', 'strawberries'],
#  ['spaghetti', 'soup', 'milk', 'carrots', 'chocolate'],
#  ['burgers', 'mineral water', 'soup', 'meatballs', 'olive oil'],
#  ['grated cheese',
#   'mineral water',
#   'cooking oil',
#   'french fries',
#   'cookies',
#   'low fat yogurt'],
#  ['shrimp', 'milk', 'olive oil', 'french fries'],
#  ['frozen vegetables', 'mineral water', 'pancakes', 'cake', 'tomato juice'],
#  ['spaghetti', 'milk', 'chicken'],
#  ['grated cheese',
#   'mineral water',
#   'chicken',
#   'french fries',
#   'cottage cheese',
#   'pancakes'],
#  ['ground beef', 'mineral water', 'milk', 'eggs', 'mint'],
#  ['shrimp', 'body spray', 'green tea'],
#  ['frozen smoothie'],
#  ['herb & pepper', 'frozen vegetables', 'mineral water', 'muffins', 'cereals'],
#  ['turkey',
#   'tomatoes',
#   'spaghetti',
#   'milk',
#   'cider',
#   'eggs',
#   'honey',
#   'cake',
#   'green tea',
#   'french fries',
#   'brownies',
#   'tomato juice'],
#  ...]

# %%
rules = apriori(T, min_support=0.003, min_confidence=0.35,min_lift=3, min_length=2)

# %%
list(rules)
# Out:
# [RelationRecord(items=frozenset({'pasta', 'escalope'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'escalope'}), confidence=0.3728813559322034, lift=4.700811850163794)]),
#  RelationRecord(items=frozenset({'tomato sauce', 'ground beef'}), support=0.005332622317024397, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tomato sauce'}), items_add=frozenset({'ground beef'}), confidence=0.3773584905660377, lift=3.840659481324083)]),
#  RelationRecord(items=frozenset({'spaghetti', 'milk', 'avocado'}), support=0.003332888948140248, ordered_statistics=[OrderedStatistic(items_base=frozenset({'spaghetti', 'avocado'}), items_add=frozenset({'milk'}), confidence=0.41666666666666663, lift=3.215449245541838)]),
#  RelationRecord(items=frozenset({'tomatoes', 'cake', 'frozen vegetables'}), support=0.0030662578322890282, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tomatoes', 'cake'}), items_add=frozenset({'frozen vegetables'}), confidence=0.36507936507936506, lift=3.8300144300144296)]),
#  RelationRecord(items=frozenset({'spaghetti', 'cereals', 'ground beef'}), support=0.0030662578322890282, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals', 'ground beef'}), items_add=frozenset({'spaghetti'}), confidence=0.6764705882352942, lift=3.8853031258445188), OrderedStatistic(items_base=frozenset({'spaghetti', 'cereals'}), items_add=frozenset({'ground beef'}), confidence=0.45999999999999996, lift=4.681763907734057)]),
#  RelationRecord(items=frozenset({'milk', 'chicken', 'ground beef'}), support=0.0038661511798426876, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chicken', 'ground beef'}), items_add=frozenset({'milk'}), confidence=0.40845070422535207, lift=3.152046020981858)]),
#  RelationRecord(items=frozenset({'milk', 'olive oil', 'chicken'}), support=0.0035995200639914677, ordered_statistics=[OrderedStatistic(items_base=frozenset({'olive oil', 'chicken'}), items_add=frozenset({'milk'}), confidence=0.5, lift=3.858539094650206)]),
#  RelationRecord(items=frozenset({'chocolate', 'herb & pepper', 'ground beef'}), support=0.003999466737768298, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chocolate', 'herb & pepper'}), items_add=frozenset({'ground beef'}), confidence=0.4411764705882354, lift=4.4901827759597746)]),
#  RelationRecord(items=frozenset({'soup', 'milk', 'chocolate'}), support=0.003999466737768298, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soup', 'chocolate'}), items_add=frozenset({'milk'}), confidence=0.3947368421052632, lift=3.0462150747238472)]),
#  RelationRecord(items=frozenset({'spaghetti', 'cooking oil', 'ground beef'}), support=0.004799360085321957, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cooking oil', 'ground beef'}), items_add=frozenset({'spaghetti'}), confidence=0.5714285714285714, lift=3.2819951870487856)]),
#  RelationRecord(items=frozenset({'eggs', 'red wine', 'spaghetti'}), support=0.0037328356219170776, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'red wine'}), items_add=frozenset({'spaghetti'}), confidence=0.5283018867924528, lift=3.0342974370828397)]),
#  RelationRecord(items=frozenset({'herb & pepper', 'french fries', 'ground beef'}), support=0.003199573390214638, ordered_statistics=[OrderedStatistic(items_base=frozenset({'herb & pepper', 'french fries'}), items_add=frozenset({'ground beef'}), confidence=0.46153846153846156, lift=4.697421981004071)]),
#  RelationRecord(items=frozenset({'milk', 'olive oil', 'frozen vegetables'}), support=0.004799360085321957, ordered_statistics=[OrderedStatistic(items_base=frozenset({'olive oil', 'frozen vegetables'}), items_add=frozenset({'milk'}), confidence=0.4235294117647058, lift=3.2684095860566447)]),
#  RelationRecord(items=frozenset({'soup', 'milk', 'frozen vegetables'}), support=0.003999466737768298, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soup', 'frozen vegetables'}), items_add=frozenset({'milk'}), confidence=0.5, lift=3.858539094650206)]),
#  RelationRecord(items=frozenset({'tomatoes', 'shrimp', 'frozen vegetables'}), support=0.003999466737768298, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tomatoes', 'shrimp'}), items_add=frozenset({'frozen vegetables'}), confidence=0.35714285714285715, lift=3.7467532467532467)]),
#  RelationRecord(items=frozenset({'milk', 'herb & pepper', 'ground beef'}), support=0.0035995200639914677, ordered_statistics=[OrderedStatistic(items_base=frozenset({'milk', 'herb & pepper'}), items_add=frozenset({'ground beef'}), confidence=0.3913043478260869, lift=3.9825968969382335)]),
#  RelationRecord(items=frozenset({'mineral water', 'herb & pepper', 'ground beef'}), support=0.006665777896280496, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mineral water', 'herb & pepper'}), items_add=frozenset({'ground beef'}), confidence=0.39062500000000006, lift=3.975682666214383)]),
#  RelationRecord(items=frozenset({'spaghetti', 'herb & pepper', 'ground beef'}), support=0.006399146780429276, ordered_statistics=[OrderedStatistic(items_base=frozenset({'spaghetti', 'herb & pepper'}), items_add=frozenset({'ground beef'}), confidence=0.3934426229508197, lift=4.004359721511667)]),
#  RelationRecord(items=frozenset({'soup', 'milk', 'ground beef'}), support=0.003999466737768298, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soup', 'ground beef'}), items_add=frozenset({'milk'}), confidence=0.4109589041095891, lift=3.1714019956029094)]),
#  RelationRecord(items=frozenset({'spaghetti', 'shrimp', 'ground beef'}), support=0.005999200106652446, ordered_statistics=[OrderedStatistic(items_base=frozenset({'shrimp', 'ground beef'}), items_add=frozenset({'spaghetti'}), confidence=0.5232558139534884, lift=3.005315360233627)]),
#  RelationRecord(items=frozenset({'spaghetti', 'tomato sauce', 'ground beef'}), support=0.0030662578322890282, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tomato sauce', 'ground beef'}), items_add=frozenset({'spaghetti'}), confidence=0.5750000000000001, lift=3.3025076569678413), OrderedStatistic(items_base=frozenset({'spaghetti', 'tomato sauce'}), items_add=frozenset({'ground beef'}), confidence=0.4893617021276596, lift=4.980599901844742)]),
#  RelationRecord(items=frozenset({'milk', 'shrimp', 'olive oil'}), support=0.003199573390214638, ordered_statistics=[OrderedStatistic(items_base=frozenset({'shrimp', 'olive oil'}), items_add=frozenset({'milk'}), confidence=0.3934426229508197, lift=3.0362274843149164)]),
#  RelationRecord(items=frozenset({'soup', 'milk', 'olive oil'}), support=0.0035995200639914677, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soup', 'olive oil'}), items_add=frozenset({'milk'}), confidence=0.4029850746268656, lift=3.1098673300165833)]),
#  RelationRecord(items=frozenset({'soup', 'milk', 'tomatoes'}), support=0.0030662578322890282, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soup', 'tomatoes'}), items_add=frozenset({'milk'}), confidence=0.44230769230769235, lift=3.4133230452674903)]),
#  RelationRecord(items=frozenset({'spaghetti', 'milk', 'whole wheat pasta'}), support=0.003999466737768298, ordered_statistics=[OrderedStatistic(items_base=frozenset({'spaghetti', 'whole wheat pasta'}), items_add=frozenset({'milk'}), confidence=0.4545454545454546, lift=3.5077628133183696)]),
#  RelationRecord(items=frozenset({'whole wheat pasta', 'mineral water', 'olive oil'}), support=0.0038661511798426876, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole wheat pasta', 'mineral water'}), items_add=frozenset({'olive oil'}), confidence=0.4027777777777778, lift=6.115862573099416)]),
#  RelationRecord(items=frozenset({'spaghetti', 'tomatoes', 'olive oil'}), support=0.004399413411545127, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tomatoes', 'olive oil'}), items_add=frozenset({'spaghetti'}), confidence=0.6111111111111112, lift=3.5099115194827295)]),
#  RelationRecord(items=frozenset({'ground beef', 'chocolate', 'spaghetti', 'frozen vegetables'}), support=0.0030662578322890282, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ground beef', 'chocolate', 'frozen vegetables'}), items_add=frozenset({'spaghetti'}), confidence=0.5348837209302326, lift=3.0721001460165964), OrderedStatistic(items_base=frozenset({'spaghetti', 'chocolate', 'frozen vegetables'}), items_add=frozenset({'ground beef'}), confidence=0.3898305084745763, lift=3.967596531978015)]),
#  RelationRecord(items=frozenset({'milk', 'chocolate', 'mineral water', 'frozen vegetables'}), support=0.003999466737768298, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mineral water', 'chocolate', 'frozen vegetables'}), items_add=frozenset({'milk'}), confidence=0.4109589041095891, lift=3.1714019956029094)]),
#  RelationRecord(items=frozenset({'spaghetti', 'milk', 'chocolate', 'frozen vegetables'}), support=0.0034662045060658577, ordered_statistics=[OrderedStatistic(items_base=frozenset({'spaghetti', 'chocolate', 'frozen vegetables'}), items_add=frozenset({'milk'}), confidence=0.44067796610169485, lift=3.4007463207086555)]),
#  RelationRecord(items=frozenset({'mineral water', 'chocolate', 'shrimp', 'frozen vegetables'}), support=0.003199573390214638, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mineral water', 'chocolate', 'shrimp'}), items_add=frozenset({'frozen vegetables'}), confidence=0.4210526315789474, lift=4.417224880382776)]),
#  RelationRecord(items=frozenset({'eggs', 'milk', 'mineral water', 'frozen vegetables'}), support=0.0037328356219170776, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'mineral water', 'frozen vegetables'}), items_add=frozenset({'milk'}), confidence=0.411764705882353, lift=3.177620430888405)]),
#  RelationRecord(items=frozenset({'spaghetti', 'milk', 'mineral water', 'frozen smoothie'}), support=0.003199573390214638, ordered_statistics=[OrderedStatistic(items_base=frozenset({'spaghetti', 'mineral water', 'frozen smoothie'}), items_add=frozenset({'milk'}), confidence=0.4705882352941177, lift=3.631566206729606)]),
#  RelationRecord(items=frozenset({'ground beef', 'milk', 'mineral water', 'frozen vegetables'}), support=0.0037328356219170776, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ground beef', 'mineral water', 'frozen vegetables'}), items_add=frozenset({'milk'}), confidence=0.40579710144927533, lift=3.1315679608755294)]),
#  RelationRecord(items=frozenset({'ground beef', 'milk', 'spaghetti', 'frozen vegetables'}), support=0.0030662578322890282, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ground beef', 'milk', 'frozen vegetables'}), items_add=frozenset({'spaghetti'}), confidence=0.5348837209302326, lift=3.0721001460165964), OrderedStatistic(items_base=frozenset({'spaghetti', 'milk', 'frozen vegetables'}), items_add=frozenset({'ground beef'}), confidence=0.3709677419354839, lift=3.7756160546242397)]),
#  RelationRecord(items=frozenset({'ground beef', 'mineral water', 'spaghetti', 'frozen vegetables'}), support=0.004399413411545127, ordered_statistics=[OrderedStatistic(items_base=frozenset({'spaghetti', 'mineral water', 'frozen vegetables'}), items_add=frozenset({'ground beef'}), confidence=0.3666666666666667, lift=3.7318407960199007)]),
#  RelationRecord(items=frozenset({'milk', 'mineral water', 'olive oil', 'frozen vegetables'}), support=0.003332888948140248, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mineral water', 'olive oil', 'frozen vegetables'}), items_add=frozenset({'milk'}), confidence=0.5102040816326531, lift=3.937284790459394), OrderedStatistic(items_base=frozenset({'milk', 'mineral water', 'olive oil'}), items_add=frozenset({'frozen vegetables'}), confidence=0.39062500000000006, lift=4.098011363636364)]),
#  RelationRecord(items=frozenset({'soup', 'milk', 'mineral water', 'frozen vegetables'}), support=0.0030662578322890282, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soup', 'frozen vegetables'}), items_add=frozenset({'milk', 'mineral water'}), confidence=0.3833333333333333, lift=7.987175925925926), OrderedStatistic(items_base=frozenset({'soup', 'milk', 'frozen vegetables'}), items_add=frozenset({'mineral water'}), confidence=0.7666666666666666, lift=3.21631245339299), OrderedStatistic(items_base=frozenset({'soup', 'mineral water', 'frozen vegetables'}), items_add=frozenset({'milk'}), confidence=0.6052631578947368, lift=4.670863114576565), OrderedStatistic(items_base=frozenset({'soup', 'milk', 'mineral water'}), items_add=frozenset({'frozen vegetables'}), confidence=0.35937500000000006, lift=3.7701704545454553)]),
#  RelationRecord(items=frozenset({'spaghetti', 'mineral water', 'shrimp', 'frozen vegetables'}), support=0.003332888948140248, ordered_statistics=[OrderedStatistic(items_base=frozenset({'spaghetti', 'mineral water', 'shrimp'}), items_add=frozenset({'frozen vegetables'}), confidence=0.39062500000000006, lift=4.098011363636364)]),
#  RelationRecord(items=frozenset({'spaghetti', 'tomatoes', 'mineral water', 'frozen vegetables'}), support=0.0030662578322890282, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tomatoes', 'mineral water', 'frozen vegetables'}), items_add=frozenset({'spaghetti'}), confidence=0.5227272727272727, lift=3.0022796881525826)]),
#  RelationRecord(items=frozenset({'spaghetti', 'tomatoes', 'mineral water', 'ground beef'}), support=0.0030662578322890282, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tomatoes', 'mineral water', 'ground beef'}), items_add=frozenset({'spaghetti'}), confidence=0.5609756097560976, lift=3.221958689724723)])]

# %% [markdown]
# ## Check Max Sold Items

# %%
D = df.values.ravel()
D
# Out:
# array(['shrimp', 'almonds', 'avocado', ..., nan, nan, nan], dtype=object)

# %%
import collections
val = collections.Counter(D)
val
# Out:
# Counter({'shrimp': 536,
#          'almonds': 153,
#          'avocado': 250,
#          'vegetables mix': 193,
#          'green grapes': 68,
#          'whole weat flour': 70,
#          'yams': 86,
#          'cottage cheese': 239,
#          'energy drink': 200,
#          'tomato juice': 228,
#          'low fat yogurt': 574,
#          'green tea': 991,
#          'honey': 356,
#          'salad': 37,
#          'mineral water': 1788,
#          'salmon': 319,
#          'antioxydant juice': 67,
#          'frozen smoothie': 475,
#          'spinach': 53,
#          'olive oil': 494,
#          'burgers': 654,
#          'meatballs': 157,
#          'eggs': 1348,
#          nan: 120657,
#          'chutney': 31,
#          'turkey': 469,
#          'milk': 972,
#          'energy bar': 203,
#          'whole wheat rice': 439,
#          'whole wheat pasta': 221,
#          'french fries': 1282,
#          'soup': 379,
#          'light cream': 117,
#          'shallot': 58,
#          'frozen vegetables': 715,
#          'spaghetti': 1306,
#          'pet food': 49,
#          'cookies': 603,
#          'cooking oil': 383,
#          'champagne': 351,
#          'chocolate': 1230,
#          'chicken': 450,
#          'oil': 173,
#          'fresh tuna': 167,
#          'tomatoes': 513,
#          'black tea': 107,
#          'extra dark chocolate': 90,
#          'protein bar': 139,
#          'red wine': 211,
#          'pasta': 118,
#          'pepper': 199,
#          'shampoo': 37,
#          'rice': 141,
#          'sparkling water': 47,
#          'ham': 203,
#          'body spray': 86,
#          'pancakes': 713,
#          'grated cheese': 393,
#          'white wine': 124,
#          'toothpaste': 61,
#          'parmesan cheese': 149,
#          'fresh bread': 323,
#          'ground beef': 737,
#          'escalope': 595,
#          'herb & pepper': 371,
#          'tomato sauce': 106,
#          'magazines': 82,
#          'strawberries': 160,
#          'strong cheese': 58,
#          'pickles': 45,
#          'cake': 608,
#          'hot dogs': 243,
#          'brownies': 253,
#          'cereals': 193,
#          'clothes accessories': 63,
#          'bug spray': 65,
#          'muffins': 181,
#          'light mayo': 204,
#          'gums': 101,
#          'soda': 47,
#          'cider': 79,
#          'corn': 36,
#          'yogurt cake': 205,
#          'mint': 131,
#          'butter': 226,
#          'asparagus': 35,
#          'french wine': 169,
#          'salt': 69,
#          'tea': 29,
#          'barbecue sauce': 81,
#          'mayonnaise': 46,
#          'zucchini': 71,
#          'carrots': 115,
#          'mushroom cream sauce': 143,
#          'candy bars': 73,
#          'chili': 46,
#          'mashed potato': 31,
#          'nonfat milk': 78,
#          'water spray': 3,
#          'chocolate bread': 32,
#          'mint green tea': 42,
#          'eggplant': 99,
#          'blueberries': 69,
#          'bacon': 65,
#          'fromage blanc': 102,
#          'gluten free bar': 52,
#          'dessert wine': 33,
#          'flax seed': 68,
#          'hand protein bar': 39,
#          'sandwich': 34,
#          'babies food': 34,
#          'melons': 90,
#          'cauliflower': 36,
#          'green beans': 65,
#          'ketchup': 33,
#          'bramble': 14,
#          'burger sauce': 44,
#          'oatmeal': 33,
#          ' asparagus': 1,
#          'cream': 7,
#          'napkins': 5})

# %%
val.items()
# Out:
# dict_items([('shrimp', 536), ('almonds', 153), ('avocado', 250), ('vegetables mix', 193), ('green grapes', 68), ('whole weat flour', 70), ('yams', 86), ('cottage cheese', 239), ('energy drink', 200), ('tomato juice', 228), ('low fat yogurt', 574), ('green tea', 991), ('honey', 356), ('salad', 37), ('mineral water', 1788), ('salmon', 319), ('antioxydant juice', 67), ('frozen smoothie', 475), ('spinach', 53), ('olive oil', 494), ('burgers', 654), ('meatballs', 157), ('eggs', 1348), (nan, 120657), ('chutney', 31), ('turkey', 469), ('milk', 972), ('energy bar', 203), ('whole wheat rice', 439), ('whole wheat pasta', 221), ('french fries', 1282), ('soup', 379), ('light cream', 117), ('shallot', 58), ('frozen vegetables', 715), ('spaghetti', 1306), ('pet food', 49), ('cookies', 603), ('cooking oil', 383), ('champagne', 351), ('chocolate', 1230), ('chicken', 450), ('oil', 173), ('fresh tuna', 167), ('tomatoes', 513), ('black tea', 107), ('extra dark chocolate', 90), ('protein bar', 139), ('red wine', 211), ('pasta', 118), ('pepper', 199), ('shampoo', 37), ('rice', 141), ('sparkling water', 47), ('ham', 203), ('body spray', 86), ('pancakes', 713), ('grated cheese', 393), ('white wine', 124), ('toothpaste', 61), ('parmesan cheese', 149), ('fresh bread', 323), ('ground beef', 737), ('escalope', 595), ('herb & pepper', 371), ('tomato sauce', 106), ('magazines', 82), ('strawberries', 160), ('strong cheese', 58), ('pickles', 45), ('cake', 608), ('hot dogs', 243), ('brownies', 253), ('cereals', 193), ('clothes accessories', 63), ('bug spray', 65), ('muffins', 181), ('light mayo', 204), ('gums', 101), ('soda', 47), ('cider', 79), ('corn', 36), ('yogurt cake', 205), ('mint', 131), ('butter', 226), ('asparagus', 35), ('french wine', 169), ('salt', 69), ('tea', 29), ('barbecue sauce', 81), ('mayonnaise', 46), ('zucchini', 71), ('carrots', 115), ('mushroom cream sauce', 143), ('candy bars', 73), ('chili', 46), ('mashed potato', 31), ('nonfat milk', 78), ('water spray', 3), ('chocolate bread', 32), ('mint green tea', 42), ('eggplant', 99), ('blueberries', 69), ('bacon', 65), ('fromage blanc', 102), ('gluten free bar', 52), ('dessert wine', 33), ('flax seed', 68), ('hand protein bar', 39), ('sandwich', 34), ('babies food', 34), ('melons', 90), ('cauliflower', 36), ('green beans', 65), ('ketchup', 33), ('bramble', 14), ('burger sauce', 44), ('oatmeal', 33), (' asparagus', 1), ('cream', 7), ('napkins', 5)])

# %%
df1 = pd.DataFrame(val.items())
df1
# Out:
#                   0    1
# 0            shrimp  536
# 1           almonds  153
# 2           avocado  250
# 3    vegetables mix  193
# 4      green grapes   68
# ..              ...  ...
# 116    burger sauce   44
# 117         oatmeal   33
# 118       asparagus    1
# 119           cream    7
# 120         napkins    5
#
# [121 rows x 2 columns]

# %%
df2 = df1.rename(columns = {0:'items', 1:'Total'})         
df2
# Out:
#               items  Total
# 0            shrimp    536
# 1           almonds    153
# 2           avocado    250
# 3    vegetables mix    193
# 4      green grapes     68
# ..              ...    ...
# 116    burger sauce     44
# 117         oatmeal     33
# 118       asparagus      1
# 119           cream      7
# 120         napkins      5
#
# [121 rows x 2 columns]

# %% [markdown]
# ## Check Total items sold

# %%
df2.sort_values(by='Total',ascending=False)
# Out:
#              items   Total
# 23             NaN  120657
# 14   mineral water    1788
# 22            eggs    1348
# 35       spaghetti    1306
# 30    french fries    1282
# ..             ...     ...
# 115        bramble      14
# 119          cream       7
# 120        napkins       5
# 98     water spray       3
# 118      asparagus       1
#
# [121 rows x 2 columns]

# %%
df2.sort_values(by='Total',ascending=False)[1:]
# Out:
#              items  Total
# 14   mineral water   1788
# 22            eggs   1348
# 35       spaghetti   1306
# 30    french fries   1282
# 40       chocolate   1230
# ..             ...    ...
# 115        bramble     14
# 119          cream      7
# 120        napkins      5
# 98     water spray      3
# 118      asparagus      1
#
# [120 rows x 2 columns]
