# %% [markdown]
# # Basic Language Processing

# %% [markdown]
# # Basic NLP Tasks with NLTK

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\user\anaconda3.1\lib\site-packages (3.6.5)
# Requirement already satisfied: click in c:\users\user\anaconda3.1\lib\site-packages (from nltk) (8.0.3)
# Requirement already satisfied: joblib in c:\users\user\anaconda3.1\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\anaconda3.1\lib\site-packages (from nltk) (2021.8.3)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3.1\lib\site-packages (from nltk) (4.62.3)
# Requirement already satisfied: colorama in c:\users\user\anaconda3.1\lib\site-packages (from click->nltk) (0.4.4)

# %%
import nltk
from nltk.book import*

# %% [markdown]
# # Counting vocabulary of words

# %%
text7
