# %% [markdown]
# ## IBM Time Series and Survival Analysis Capstone Project
# ### Introduction
# Litecoin is a peer-to-peer Internet currency that enables instant, near-zero cost payments to anyone in the world. Litecoin is an open source, global payment network that is fully decentralized without any central authorities. Mathematics secures the network and empowers individuals to control their own finances. Litecoin features faster transaction confirmation times and improved storage efficiency than the leading math-based currency. With substantial industry support, trade volume and liquidity, Litecoin is a proven medium of commerce complementary to Bitcoin.
#
# This notebook demonstrates the prediction of the litecoin price by the neural network model. We are using both long short term memory (LSTM) and recurrent neural network (RNN) algorithms, to find the one that suits the problem better.
#
# ### Dataset
# Litecoin cryptocurrency data were retrieved from Yahoo Finance
#
#     Date: date of observation
#     Open: Opening price on the given day
#     High: Highest price on the given day
#     Close: Closing price on the given day
#     Adjusted Close: Is the closing price after adjustments for all applicable splits and dividend distributions
#     Volume: Volume of transactions on the given date

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from sklearn.preprocessing import MinMaxScaler

# %matplotlib inline

# %%
Litecoin = pd.read_csv('LTC-USD.csv')
Litecoin.head()
# Out:
#          Date     Open     High      Low    Close  Adj Close   Volume
# 0  2014-09-17  5.08589  5.17077  4.96595  5.05855    5.05855  3071840
# 1  2014-09-18  5.06543  5.06543  4.57996  4.68523    4.68523  4569260
# 2  2014-09-19  4.68729  4.75582  4.25435  4.32777    4.32777  3917450
# 3  2014-09-20  4.32920  4.61608  4.20219  4.28644    4.28644  5490660
# 4  2014-09-21  4.26307  4.30013  4.15499  4.24592    4.24592  2931220

# %%
Litecoin.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 2694  2022-02-01  109.589439  116.365822  108.664413  115.402000  115.402000
# 2695  2022-02-02  115.404503  115.882263  108.436996  108.556023  108.556023
# 2696  2022-02-03  108.534653  110.287003  106.417969  110.287003  110.287003
# 2697  2022-02-04  110.291100  120.922211  109.004990  120.918037  120.918037
# 2698  2022-02-05  120.735291  123.357422  119.287521  123.357422  123.357422
#
#          Volume
# 2694  824048434
# 2695  743395485
# 2696  683428425
# 2697  953726676
# 2698  858523456

# %%
Litecoin.isnull().values.any()
# Out:
# False

# %%
Litecoin.isnull().sum().sum()
# Out:
# 0

# %%
Litecoin[Litecoin.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
Litecoin['Open'] = Litecoin['Open'].interpolate()
Litecoin['High'] = Litecoin['High'].interpolate()
Litecoin['Low'] = Litecoin['Low'].interpolate()
Litecoin['Close'] = Litecoin['Close'].interpolate()
Litecoin['Adj Close'] = Litecoin['Adj Close'].interpolate()
Litecoin['Volume'] = Litecoin['Volume'].interpolate()

# %%
Litecoin.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Dividing the dataset into training and testing splits

# %%
lite_train = Litecoin[Litecoin['Date']< '2021-01-01'].copy()
lite_train
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2014-09-17    5.085890    5.170770    4.965950    5.058550    5.058550
# 1     2014-09-18    5.065430    5.065430    4.579960    4.685230    4.685230
# 2     2014-09-19    4.687290    4.755820    4.254350    4.327770    4.327770
# 3     2014-09-20    4.329200    4.616080    4.202190    4.286440    4.286440
# 4     2014-09-21    4.263070    4.300130    4.154990    4.245920    4.245920
# ...          ...         ...         ...         ...         ...         ...
# 2293  2020-12-27  129.456619  138.319717  123.097404  127.516968  127.516968
# 2294  2020-12-28  127.588303  136.185074  127.071342  130.050339  130.050339
# 2295  2020-12-29  130.033264  130.608582  121.187202  129.040802  129.040802
# 2296  2020-12-30  129.061859  132.450119  123.444344  129.466080  129.466080
# 2297  2020-12-31  129.480286  130.166245  123.036484  124.690323  124.690323
#
#            Volume
# 0         3071840
# 1         4569260
# 2         3917450
# 3         5490660
# 4         2931220
# ...           ...
# 2293  14103307412
# 2294  10248729547
# 2295   9160551332
# 2296   8127317345
# 2297   6274573135
#
# [2298 rows x 7 columns]

# %%
lite_test = Litecoin[Litecoin['Date'] > '2021-01-01'].copy()
lite_test
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 2299  2021-01-02  126.272964  140.372574  123.693619  136.944885  136.944885
# 2300  2021-01-03  136.949402  163.898636  135.739914  160.190582  160.190582
# 2301  2021-01-04  160.271164  173.027817  143.623962  154.807327  154.807327
# 2302  2021-01-05  154.897552  162.850189  147.400070  158.594772  158.594772
# 2303  2021-01-06  158.665970  169.657455  155.452866  169.016922  169.016922
# ...          ...         ...         ...         ...         ...         ...
# 2694  2022-02-01  109.589439  116.365822  108.664413  115.402000  115.402000
# 2695  2022-02-02  115.404503  115.882263  108.436996  108.556023  108.556023
# 2696  2022-02-03  108.534653  110.287003  106.417969  110.287003  110.287003
# 2697  2022-02-04  110.291100  120.922211  109.004990  120.918037  120.918037
# 2698  2022-02-05  120.735291  123.357422  119.287521  123.357422  123.357422
#
#            Volume
# 2299  10532067985
# 2300  15385661271
# 2301  13659785704
# 2302  10192818976
# 2303  10743884477
# ...           ...
# 2694    824048434
# 2695    743395485
# 2696    683428425
# 2697    953726676
# 2698    858523456
#
# [400 rows x 7 columns]

# %%
train_lt = lite_train.drop(['Date', 'Adj Close'], axis = 1)
train_lt.head()
# Out:
#       Open     High      Low    Close   Volume
# 0  5.08589  5.17077  4.96595  5.05855  3071840
# 1  5.06543  5.06543  4.57996  4.68523  4569260
# 2  4.68729  4.75582  4.25435  4.32777  3917450
# 3  4.32920  4.61608  4.20219  4.28644  5490660
# 4  4.26307  4.30013  4.15499  4.24592  2931220

# %%
scaler = MinMaxScaler(feature_range= (0,1))
train_lt = scaler.fit_transform(train_lt)
train_lt
# Out:
# array([[1.09859225e-02, 1.02314481e-02, 1.15142146e-02, 1.09232069e-02,
#         1.83660073e-04],
#        [1.09287671e-02, 9.94974608e-03, 1.03604946e-02, 9.87801665e-03,
#         2.89838795e-04],
#        [9.87242681e-03, 9.12178169e-03, 9.38724977e-03, 8.87722990e-03,
#         2.43620397e-04],
#        ...,
#        [3.60028467e-01, 3.45679405e-01, 3.58898297e-01, 3.58038395e-01,
#         6.49520161e-01],
#        [3.57314831e-01, 3.50604075e-01, 3.65644870e-01, 3.59229053e-01,
#         5.76255837e-01],
#        [3.58483714e-01, 3.44496500e-01, 3.64425781e-01, 3.45858286e-01,
#         4.44881867e-01]])

# %%
X_train = []
y_train = []

train_lt.shape
# Out:
# (2298, 5)

# %%
for i in range(60, train_lt.shape[0]):
    X_train.append(train_lt[i-60:i])
    y_train.append(train_lt[i,0])

# %%
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train.shape
# Out:
# (2238, 60, 5)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %% [markdown]
# ## LSTM model

# %%
regressor = Sequential()
regressor.add(LSTM(units = 50, activation = 'relu', return_sequences = True, input_shape = (X_train.shape[1], 5)))
regressor.add(Dropout(0.2))

# %%
regressor.add(LSTM(units = 60, activation = 'relu', return_sequences = True))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
regressor.add(Dropout(0.4))

regressor.add(LSTM(units = 120, activation = 'relu'))
regressor.add(Dropout(0.5))

regressor.add(Dense(units =1))

# %%
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 50)            11200
#
#  dropout (Dropout)           (None, 60, 50)            0
#
#  lstm_1 (LSTM)               (None, 60, 60)            26640
#
#  dropout_1 (Dropout)         (None, 60, 60)            0
#
#  lstm_2 (LSTM)               (None, 60, 80)            45120
#
#  dropout_2 (Dropout)         (None, 60, 80)            0
#
#  lstm_3 (LSTM)               (None, 120)               96480
#
#  dropout_3 (Dropout)         (None, 120)               0
#
#  dense (Dense)               (None, 1)                 121
#
# =================================================================
# Total params: 179,561
# Trainable params: 179,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf
from keras import optimizers

optimizer = tf.keras.optimizers.Adam(clipvalue=0.5)

regressor.compile(optimizer = optimizer, loss = 'mean_squared_error')

# %%
regressor.fit(X_train, y_train, epochs = 20, batch_size =32)
# Out:
# Epoch 1/20
# 70/70 [==============================] - 8s 74ms/step - loss: 0.0080
# Epoch 2/20
# 70/70 [==============================] - 5s 77ms/step - loss: 0.0043
# Epoch 3/20
# 70/70 [==============================] - 5s 78ms/step - loss: 0.0031
# Epoch 4/20
# 70/70 [==============================] - 5s 77ms/step - loss: 0.0027
# Epoch 5/20
# 70/70 [==============================] - 5s 75ms/step - loss: 0.0023
# Epoch 6/20
# 70/70 [==============================] - 5s 75ms/step - loss: 0.0019
# Epoch 7/20
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0023
# Epoch 8/20
# 70/70 [==============================] - 5s 73ms/step - loss: 0.0020
# Epoch 9/20
# 70/70 [==============================] - 5s 74ms/step - loss: 0.0017
# Epoch 10/20
# 70/70 [==============================] - 5s 73ms/step - loss: 0.0015
# Epoch 11/20
# 70/70 [==============================] - 5s 73ms/step - loss: 0.0017
# Epoch 12/20
# 70/70 [==============================] - 6s 83ms/step - loss: 0.0013
# Epoch 13/20
# 70/70 [==============================] - 6s 88ms/step - loss: 0.0016
# Epoch 14/20
# 70/70 [==============================] - 6s 82ms/step - loss: 0.0015
# Epoch 15/20
# 70/70 [==============================] - 5s 74ms/step - loss: 0.0013
# Epoch 16/20
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0017: 0s - loss: 0.00
# Epoch 17/20
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0014
# Epoch 18/20
# 70/70 [==============================] - 5s 73ms/step - loss: 0.0014
# Epoch 19/20
# 70/70 [==============================] - 5s 74ms/step - loss: 0.0014: 0s - loss: 0.001
# Epoch 20/20
# 70/70 [==============================] - 5s 78ms/step - loss: 0.0013

# %%
past_60_days = lite_train.tail(60)
lt= past_60_days.append(lite_test, ignore_index = True)
lt = lt.drop(['Date', 'Adj Close'], axis = 1)
lt.head()
# Out:
#         Open       High        Low      Close      Volume
# 0  55.587322  56.710835  53.205944  53.817482  3019889902
# 1  53.817410  54.272400  51.648445  53.819622  2580300879
# 2  53.819469  55.007088  51.606560  54.499104  3050534139
# 3  54.501873  59.223793  54.501873  58.678497  3250514599
# 4  58.676193  63.280354  58.465351  63.131111  4083503373

# %%
inputs = scaler.transform(lt)
inputs
# Out:
# array([[0.1520625 , 0.14806078, 0.15570304, 0.14743441, 0.21409952],
#        [0.14711823, 0.14153987, 0.15104769, 0.1474404 , 0.18292924],
#        [0.14712398, 0.14350459, 0.1509225 , 0.14934275, 0.21627243],
#        ...,
#        [0.29997174, 0.29133509, 0.31475322, 0.30553307, 0.04842623],
#        [0.30487841, 0.31977595, 0.32248579, 0.33529695, 0.06759248],
#        [0.33405443, 0.32628823, 0.35322017, 0.34212654, 0.06084183]])

# %%
X_test = []
y_test = []
for i in range (60, inputs.shape[0]):
    X_test.append(inputs[i-60:i])
    y_test.append(inputs[i, 0])

# %%
X_test, y_test = np.array(X_test), np.array(y_test)
X_test.shape, y_test.shape
# Out:
# ((400, 60, 5), (400,))

# %%
y_pred = regressor.predict(X_test)
y_pred, y_test
# Out:
# (array([[0.3168092 ],
#         [0.31415835],
#         [0.32210445],
#         [0.34301388],
#         [0.36736587],
#         [0.3897167 ],
#         [0.41012198],
#         [0.4284494 ],
#         [0.4406207 ],
#         [0.44710544],
#         [0.4484684 ],
#         [0.44058028],
#         [0.42443743],
#         [0.40438697],
#         [0.3841776 ],
#         [0.3661491 ],
#         [0.3513057 ],
#         [0.3418875 ],
#         [0.34211692],
#         [0.35060903],
#         [0.36136022],
#         [0.36914536],
#         [0.3708793 ],
#         [0.36746454],
#         [0.36208123],
#         [0.35617626],
#         [0.3499651 ],
#         [0.34398505],
#         [0.34170607],
#         [0.34169602],
#         [0.3412616 ],
#         [0.34017888],
#         [0.3412281 ],
#         [0.3483275 ],
#         [0.3605443 ],
#         [0.3743988 ],
#         [0.38830507],
#         [0.39828244],
#         [0.40605593],
#         [0.4167907 ],
#         [0.4351728 ],
#         [0.45409104],
#         [0.47115865],
#         [0.49652725],
#         [0.52328014],
#         [0.54143524],
#         [0.5473233 ],
#         [0.5472655 ],
#         [0.54184514],
#         [0.53451055],
#         [0.5294426 ],
#         [0.5265849 ],
#         [0.5250118 ],
#         [0.52087116],
#         [0.5103292 ],
#         [0.49583066],
#         [0.47921953],
#         [0.4614935 ],
#         [0.44428852],
#         [0.42951766],
#         [0.42071226],
#         [0.42218107],
#         [0.43302557],
#         [0.44652972],
#         [0.45762682],
#         [0.4656052 ],
#         [0.4721905 ],
#         [0.48110363],
#         [0.49343932],
#         [0.50448424],
#         [0.5181536 ],
#         [0.5336325 ],
#         [0.544655  ],
#         [0.548127  ],
#         [0.5423531 ],
#         [0.5302687 ],
#         [0.5154875 ],
#         [0.5005295 ],
#         [0.4879511 ],
#         [0.4793603 ],
#         [0.47451216],
#         [0.4719331 ],
#         [0.47131142],
#         [0.46963888],
#         [0.46688575],
#         [0.46409094],
#         [0.46233723],
#         [0.4647584 ],
#         [0.4727231 ],
#         [0.48405167],
#         [0.49712178],
#         [0.51138663],
#         [0.5234515 ],
#         [0.5287197 ],
#         [0.5321771 ],
#         [0.54558665],
#         [0.5652024 ],
#         [0.57664394],
#         [0.57570785],
#         [0.5732544 ],
#         [0.5779889 ],
#         [0.58609796],
#         [0.5987138 ],
#         [0.61817646],
#         [0.6393759 ],
#         [0.6696167 ],
#         [0.70721954],
#         [0.7269617 ],
#         [0.7192825 ],
#         [0.6947035 ],
#         [0.66400504],
#         [0.6359237 ],
#         [0.6117682 ],
#         [0.5889929 ],
#         [0.56710464],
#         [0.5504202 ],
#         [0.5464469 ],
#         [0.55820453],
#         [0.5804705 ],
#         [0.60761696],
#         [0.6340389 ],
#         [0.65280956],
#         [0.6687638 ],
#         [0.6970763 ],
#         [0.74696535],
#         [0.79349244],
#         [0.8172737 ],
#         [0.8097182 ],
#         [0.7941417 ],
#         [0.7865711 ],
#         [0.7812764 ],
#         [0.77238685],
#         [0.7582329 ],
#         [0.7408775 ],
#         [0.7225228 ],
#         [0.70509845],
#         [0.68918574],
#         [0.68066216],
#         [0.67292255],
#         [0.656735  ],
#         [0.63151664],
#         [0.5990513 ],
#         [0.56238467],
#         [0.526091  ],
#         [0.49445084],
#         [0.4723579 ],
#         [0.46431586],
#         [0.4682208 ],
#         [0.4754813 ],
#         [0.4786857 ],
#         [0.47842303],
#         [0.47712013],
#         [0.47634965],
#         [0.47781754],
#         [0.48009518],
#         [0.47982007],
#         [0.47572452],
#         [0.46810597],
#         [0.45757946],
#         [0.4467769 ],
#         [0.43787056],
#         [0.43147755],
#         [0.42647028],
#         [0.4233614 ],
#         [0.42364833],
#         [0.42871276],
#         [0.43577775],
#         [0.44149908],
#         [0.44304842],
#         [0.4392193 ],
#         [0.43109885],
#         [0.41971704],
#         [0.4051251 ],
#         [0.38858756],
#         [0.372111  ],
#         [0.35738525],
#         [0.34527397],
#         [0.33681056],
#         [0.33337888],
#         [0.33671412],
#         [0.3458635 ],
#         [0.3571235 ],
#         [0.3662785 ],
#         [0.37178543],
#         [0.3747752 ],
#         [0.37574083],
#         [0.37513533],
#         [0.37350485],
#         [0.37053037],
#         [0.3662642 ],
#         [0.36131358],
#         [0.35646674],
#         [0.35280976],
#         [0.35008976],
#         [0.34785664],
#         [0.3456118 ],
#         [0.34254968],
#         [0.33816263],
#         [0.33277315],
#         [0.32652232],
#         [0.3193049 ],
#         [0.3122171 ],
#         [0.3068312 ],
#         [0.30446282],
#         [0.30606562],
#         [0.311281  ],
#         [0.3207158 ],
#         [0.33264786],
#         [0.34585753],
#         [0.35864985],
#         [0.36984417],
#         [0.3784    ],
#         [0.38371143],
#         [0.3855742 ],
#         [0.3840343 ],
#         [0.38027886],
#         [0.37598386],
#         [0.37324104],
#         [0.374247  ],
#         [0.37868536],
#         [0.38774082],
#         [0.4006897 ],
#         [0.4159978 ],
#         [0.4305051 ],
#         [0.44356057],
#         [0.4548654 ],
#         [0.46385518],
#         [0.46978876],
#         [0.4706629 ],
#         [0.46566686],
#         [0.45700765],
#         [0.44887117],
#         [0.44386882],
#         [0.44395652],
#         [0.44913223],
#         [0.45584777],
#         [0.46037266],
#         [0.46111056],
#         [0.45913848],
#         [0.45583788],
#         [0.4529593 ],
#         [0.45019564],
#         [0.44738516],
#         [0.44655302],
#         [0.44928333],
#         [0.4633736 ],
#         [0.48982584],
#         [0.5230886 ],
#         [0.55315775],
#         [0.56686604],
#         [0.56126624],
#         [0.5420603 ],
#         [0.5159482 ],
#         [0.4885999 ],
#         [0.46471938],
#         [0.45496476],
#         [0.45498416],
#         [0.45989814],
#         [0.46699908],
#         [0.47272667],
#         [0.47426364],
#         [0.47123823],
#         [0.463896  ],
#         [0.45225397],
#         [0.43831363],
#         [0.42499965],
#         [0.4144991 ],
#         [0.40699187],
#         [0.4021089 ],
#         [0.3987284 ],
#         [0.39526054],
#         [0.39137813],
#         [0.38837764],
#         [0.38977313],
#         [0.39777532],
#         [0.41146693],
#         [0.42621687],
#         [0.43889388],
#         [0.44936916],
#         [0.458251  ],
#         [0.46423998],
#         [0.46689   ],
#         [0.46613213],
#         [0.46329483],
#         [0.45872432],
#         [0.4532257 ],
#         [0.44891962],
#         [0.44880486],
#         [0.453016  ],
#         [0.45884088],
#         [0.4643155 ],
#         [0.46882358],
#         [0.47562775],
#         [0.48570612],
#         [0.4945759 ],
#         [0.49927032],
#         [0.49939975],
#         [0.49663755],
#         [0.49327192],
#         [0.49049774],
#         [0.48765373],
#         [0.48567858],
#         [0.48460808],
#         [0.48403463],
#         [0.4848833 ],
#         [0.4880909 ],
#         [0.49453652],
#         [0.50250095],
#         [0.50850755],
#         [0.5104482 ],
#         [0.5090841 ],
#         [0.51208067],
#         [0.53783405],
#         [0.59252983],
#         [0.64406013],
#         [0.67219776],
#         [0.67348564],
#         [0.66077954],
#         [0.6439641 ],
#         [0.6255093 ],
#         [0.60449004],
#         [0.58154964],
#         [0.55864143],
#         [0.53964543],
#         [0.5280352 ],
#         [0.52331156],
#         [0.5237706 ],
#         [0.5272894 ],
#         [0.53340477],
#         [0.53934634],
#         [0.53956956],
#         [0.53396857],
#         [0.52642536],
#         [0.52140045],
#         [0.520477  ],
#         [0.52164656],
#         [0.521288  ],
#         [0.5153889 ],
#         [0.5017752 ],
#         [0.48271877],
#         [0.46178165],
#         [0.44254473],
#         [0.42667574],
#         [0.41428998],
#         [0.40563816],
#         [0.40122828],
#         [0.39968145],
#         [0.39891112],
#         [0.39872733],
#         [0.39894322],
#         [0.3983936 ],
#         [0.39676479],
#         [0.3961108 ],
#         [0.39709842],
#         [0.39914092],
#         [0.40192404],
#         [0.40596816],
#         [0.41108888],
#         [0.41566357],
#         [0.41817123],
#         [0.41819406],
#         [0.4152903 ],
#         [0.40940365],
#         [0.40155298],
#         [0.39355692],
#         [0.38679168],
#         [0.3824279 ],
#         [0.38058928],
#         [0.38064325],
#         [0.38099808],
#         [0.37973654],
#         [0.37619403],
#         [0.37037843],
#         [0.3630547 ],
#         [0.35527554],
#         [0.3482547 ],
#         [0.34419504],
#         [0.34414062],
#         [0.34860367],
#         [0.3572288 ],
#         [0.36776167],
#         [0.37920862],
#         [0.38880926],
#         [0.39326262],
#         [0.39159644],
#         [0.38387385],
#         [0.3709514 ],
#         [0.3545745 ],
#         [0.33696458],
#         [0.3197832 ],
#         [0.3045508 ],
#         [0.29205164],
#         [0.28289795],
#         [0.27742177],
#         [0.27537835],
#         [0.27613193],
#         [0.2796316 ],
#         [0.2848265 ],
#         [0.28994885],
#         [0.2954959 ]], dtype=float32),
#  array([0.34952401, 0.37934881, 0.44449854, 0.42948726, 0.4400144 ,
#         0.46907326, 0.4706748 , 0.48076562, 0.49256385, 0.47473464,
# %%
y_pred
# Out:
# array([[112.66875 ],
#        [111.726006],
#        [114.551926],
#        [121.98807 ],
#        [130.64851 ],
#        [138.59727 ],
#        [145.85413 ],
#        [152.37201 ],
#        [156.70056 ],
#        [159.00677 ],
#        [159.49149 ],
#        [156.68619 ],
#        [150.9452  ],
#        [143.81454 ],
#        [136.62737 ],
#        [130.21579 ],
#        [124.936935],
#        [121.58749 ],
#        [121.669075],
#        [124.68918 ],
#        [128.5127  ],
#        [131.28136 ],
#        [131.89801 ],
#        [130.68361 ],
#        [128.7691  ],
#        [126.66908 ],
#        [124.460175],
#        [122.33345 ],
#        [121.522964],
#        [121.519394],
#        [121.36489 ],
#        [120.97984 ],
#        [121.35298 ],
#        [123.87778 ],
#        [128.22252 ],
#        [133.14967 ],
#        [138.09525 ],
#        [141.64355 ],
#        [144.40808 ],
#        [148.22575 ],
#        [154.76309 ],
#        [161.4911  ],
#        [167.56096 ],
#        [176.58295 ],
#        [186.09723 ],
#        [192.55383 ],
#        [194.64784 ],
#        [194.6273  ],
#        [192.69962 ],
#        [190.09117 ],
#        [188.28883 ],
#        [187.27254 ],
#        [186.71306 ],
#        [185.24051 ],
#        [181.49141 ],
#        [176.3352  ],
#        [170.42769 ],
#        [164.12367 ],
#        [158.00497 ],
#        [152.75192 ],
#        [149.6204  ],
#        [150.14276 ],
#        [153.99947 ],
#        [158.80202 ],
#        [162.74855 ],
#        [165.58595 ],
#        [167.92792 ],
#        [171.09775 ],
#        [175.48476 ],
#        [179.41273 ],
#        [184.27405 ],
#        [189.77892 ],
#        [193.69891 ],
#        [194.93367 ],
#        [192.88026 ],
#        [188.58263 ],
#        [183.32588 ],
#        [178.0063  ],
#        [173.53296 ],
#        [170.47777 ],
#        [168.75359 ],
#        [167.83638 ],
#        [167.61528 ],
#        [167.02048 ],
#        [166.04135 ],
#        [165.04742 ],
#        [164.42374 ],
#        [165.28479 ],
#        [168.11732 ],
#        [172.14618 ],
#        [176.79437 ],
#        [181.86748 ],
#        [186.15817 ],
#        [188.03174 ],
#        [189.2613  ],
#        [194.03023 ],
#        [201.0063  ],
#        [205.07532 ],
#        [204.74242 ],
#        [203.86987 ],
#        [205.55365 ],
#        [208.4375  ],
#        [212.92416 ],
#        [219.84578 ],
#        [227.38507 ],
#        [238.13977 ],
#        [251.5127  ],
#        [258.53372 ],
#        [255.80272 ],
#        [247.06155 ],
#        [236.14407 ],
#        [226.15733 ],
#        [217.56676 ],
#        [209.46706 ],
#        [201.6828  ],
#        [195.74922 ],
#        [194.33617 ],
#        [198.51761 ],
#        [206.43619 ],
#        [216.09044 ],
#        [225.48705 ],
#        [232.16255 ],
#        [237.83646 ],
#        [247.90541 ],
#        [265.64774 ],
#        [282.19443 ],
#        [290.65192 ],
#        [287.9649  ],
#        [282.42535 ],
#        [279.73297 ],
#        [277.84998 ],
#        [274.68854 ],
#        [269.65488 ],
#        [263.48267 ],
#        [256.95508 ],
#        [250.75836 ],
#        [245.09923 ],
#        [242.06793 ],
#        [239.31546 ],
#        [233.55858 ],
#        [224.59003 ],
#        [213.04417 ],
#        [200.00421 ],
#        [187.09686 ],
#        [175.8445  ],
#        [167.98746 ],
#        [165.12741 ],
#        [166.51616 ],
#        [169.09825 ],
#        [170.23785 ],
#        [170.14442 ],
#        [169.68108 ],
#        [169.40706 ],
#        [169.9291  ],
#        [170.7391  ],
#        [170.64127 ],
#        [169.18474 ],
#        [166.47531 ],
#        [162.7317  ],
#        [158.88992 ],
#        [155.72252 ],
#        [153.44893 ],
#        [151.66817 ],
#        [150.56253 ],
#        [150.66458 ],
#        [152.46567 ],
#        [154.97824 ],
#        [157.01295 ],
#        [157.56395 ],
#        [156.20218 ],
#        [153.31425 ],
#        [149.26648 ],
#        [144.07706 ],
#        [138.19571 ],
#        [132.33604 ],
#        [127.099045],
#        [122.79184 ],
#        [119.781944],
#        [118.561516],
#        [119.74765 ],
#        [123.001495],
#        [127.00596 ],
#        [130.26181 ],
#        [132.22026 ],
#        [133.28354 ],
#        [133.62695 ],
#        [133.4116  ],
#        [132.83176 ],
#        [131.77393 ],
#        [130.25671 ],
#        [128.4961  ],
#        [126.77239 ],
#        [125.47183 ],
#        [124.50451 ],
#        [123.71033 ],
#        [122.91199 ],
#        [121.82298 ],
#        [120.26279 ],
#        [118.3461  ],
#        [116.12308 ],
#        [113.556305],
#        [111.03562 ],
#        [109.12021 ],
#        [108.27792 ],
#        [108.84794 ],
#        [110.70271 ],
#        [114.058075],
#        [118.30154 ],
#        [122.999374],
#        [127.54878 ],
#        [131.52989 ],
#        [134.57265 ],
#        [136.46158 ],
#        [137.12404 ],
#        [136.5764  ],
#        [135.24083 ],
#        [133.71338 ],
#        [132.73793 ],
#        [133.09569 ],
#        [134.67413 ],
#        [137.89458 ],
#        [142.49966 ],
#        [147.94377 ],
#        [153.10309 ],
#        [157.7461  ],
#        [161.7665  ],
#        [164.96358 ],
#        [167.07378 ],
#        [167.38464 ],
#        [165.60788 ],
#        [162.52835 ],
#        [159.63472 ],
#        [157.85571 ],
#        [157.8869  ],
#        [159.72757 ],
#        [162.11586 ],
#        [163.72507 ],
#        [163.9875  ],
#        [163.28615 ],
#        [162.11234 ],
#        [161.08861 ],
#        [160.10576 ],
#        [159.10625 ],
#        [158.81032 ],
#        [159.78131 ],
#        [164.79231 ],
#        [174.19968 ],
#        [186.0291  ],
#        [196.72278 ],
#        [201.59795 ],
#        [199.60646 ],
#        [192.77614 ],
#        [183.48972 ],
#        [173.76369 ],
#        [165.27092 ],
#        [161.80182 ],
#        [161.80873 ],
#        [163.55632 ],
#        [166.08167 ],
#        [168.1186  ],
#        [168.6652  ],
#        [167.58926 ],
#        [164.9781  ],
#        [160.83777 ],
#        [155.88008 ],
#        [151.14516 ],
#        [147.41078 ],
#        [144.74094 ],
#        [143.00438 ],
#        [141.80215 ],
#        [140.56886 ],
#        [139.18814 ],
#        [138.12105 ],
#        [138.61734 ],
#        [141.46321 ],
#        [146.33243 ],
#        [151.57805 ],
#        [156.08644 ],
#        [159.81183 ],
#        [162.97054 ],
#        [165.10043 ],
#        [166.04288 ],
#        [165.77335 ],
#        [164.7643  ],
#        [163.13885 ],
#        [161.18335 ],
#        [159.65196 ],
#        [159.61115 ],
#        [161.10878 ],
#        [163.18031 ],
#        [165.12729 ],
#        [166.73053 ],
#        [169.15033 ],
#        [172.73456 ],
#        [175.88896 ],
#        [177.55847 ],
#        [177.6045  ],
#        [176.62218 ],
#        [175.42523 ],
#        [174.43863 ],
#        [173.4272  ],
#        [172.72476 ],
#        [172.34406 ],
#        [172.14012 ],
#        [172.44194 ],
#        [173.58267 ],
#        [175.87497 ],
#        [178.70741 ],
#        [180.84357 ],
#        [181.53374 ],
#        [181.04861 ],
#        [182.1143  ],
#        [191.27313 ],
#        [210.72491 ],
#        [229.05095 ],
#        [239.0577  ],
#        [239.5157  ],
#        [234.99696 ],
#        [229.0168  ],
#        [222.4536  ],
#        [214.9784  ],
#        [206.81996 ],
#        [198.67297 ],
#        [191.91731 ],
#        [187.78831 ],
#        [186.1084  ],
#        [186.27165 ],
#        [187.52307 ],
#        [189.69792 ],
#        [191.81094 ],
#        [191.89034 ],
#        [189.89842 ],
#        [187.21579 ],
#        [185.42874 ],
#        [185.10034 ],
#        [185.51627 ],
#        [185.38875 ],
#        [183.29083 ],
#        [178.44931 ],
#        [171.67215 ],
#        [164.22617 ],
#        [157.38481 ],
#        [151.74123 ],
#        [147.33641 ],
#        [144.25952 ],
#        [142.69121 ],
#        [142.1411  ],
#        [141.86714 ],
#        [141.80177 ],
#        [141.87856 ],
#        [141.68309 ],
#        [141.10382 ],
#        [140.87125 ],
#        [141.22247 ],
#        [141.94887 ],
#        [142.93864 ],
#        [144.37688 ],
#        [146.19798 ],
#        [147.8249  ],
#        [148.71672 ],
#        [148.72484 ],
#        [147.69215 ],
#        [145.59866 ],
#        [142.80667 ],
#        [139.963   ],
#        [137.55702 ],
#        [136.00511 ],
#        [135.35123 ],
#        [135.37042 ],
#        [135.49661 ],
#        [135.04797 ],
#        [133.78812 ],
#        [131.7199  ],
#        [129.1153  ],
#        [126.348755],
#        [123.8519  ],
#        [122.408134],
#        [122.38878 ],
#        [123.976   ],
#        [127.0434  ],
#        [130.78928 ],
#        [134.86021 ],
#        [138.27455 ],
#        [139.85832 ],
#        [139.26578 ],
#        [136.51935 ],
#        [131.92366 ],
#        [126.09944 ],
#        [119.83672 ],
#        [113.72641 ],
#        [108.30921 ],
#        [103.86407 ],
#        [100.60868 ],
#        [ 98.661156],
#        [ 97.93444 ],
#        [ 98.20244 ],
#        [ 99.44706 ],
#        [101.29454 ],
#        [103.116234],
#        [105.08897 ]], dtype=float32)

# %%
y_test
# Out:
# array([124.30330238, 134.91007531, 158.07965993, 152.74111141,
#        156.48494002, 166.81931605, 167.38887817, 170.97753693,
#        175.17341251, 168.83270316, 137.02675798, 130.64760512,
#        145.27235903, 149.97326458, 142.10162634, 142.13803819,
#        140.35952841, 150.05873322, 151.20971162, 147.81997335,
#        128.07937421, 135.15674618, 135.69423099, 139.36966084,
#        135.39044028, 132.72646521, 120.9933322 , 136.17091315,
#        166.42710111, 164.8080659 , 173.14206138, 181.30739563,
#        177.58777701, 183.77213328, 184.93684746, 171.43053962,
#        175.58422728, 165.74599758, 173.83385271, 173.23613948,
#        172.34561145, 165.26588992, 169.20063261, 178.62991228,
#        181.09222486, 210.42950718, 209.44465765, 229.44125043,
#        216.94645698, 175.76826056, 175.60314603, 178.12518631,
#        172.02523567, 176.37296189, 180.90105248, 177.23609783,
#        180.7060741 , 186.65017238, 183.04306578, 177.51343628,
#        178.91965128, 173.4600866 , 155.04114484, 146.12811246,
#        159.29357993, 161.67615522, 150.08862688, 149.05340321,
#        148.73313473, 143.12696593, 138.60839482, 142.7628564 ,
#        151.14768004, 163.98197962, 166.91870029, 168.34348533,
#        165.3002254 , 171.61436029, 176.37143095, 176.30278978,
#        173.54606986, 177.46025755, 172.82120178, 177.13065041,
#        170.38277929, 175.24028032, 178.67345033, 187.11609123,
#        183.67038456, 181.45610689, 183.2669672 , 186.48915195,
#        204.82988638, 194.51420159, 188.59689037, 194.03415453,
#        188.18143607, 192.94384267, 195.11702327, 177.01277263,
#        187.52437463, 193.99662005, 188.05546345, 189.64619655,
#        195.19042417, 198.26350226, 204.78483328, 200.48184224,
#        196.85184499, 195.460244  , 199.83659025, 226.2375145 ,
#        259.30208605, 258.04368818, 259.74582657, 248.4086072 ,
#        255.15967631, 276.27313951, 260.4412411 , 227.99313462,
#        227.10815416, 201.67411542, 215.54986775, 224.31431007,
#        219.12592925, 206.801935  , 213.80502683, 209.70289455,
#        220.31013739, 193.13610689, 192.9937777 , 197.14291724,
#        203.24489854, 205.13604255, 206.38636048, 201.0943354 ,
#        185.97384448, 160.74821392, 154.34438216, 159.58237811,
#        159.83916057, 162.73717944, 149.61850861, 146.62568442,
#        155.74914173, 157.16890873, 142.5326633 , 148.48282575,
#        151.36345682, 146.86254671, 142.17772552, 146.59441082,
#        151.11472449, 150.3647821 , 152.8766502 , 153.37831428,
#        161.33955998, 159.29136647, 155.59850412, 153.72211123,
#        153.81855379, 143.83884234, 143.49002934, 146.09673356,
#        144.43497893, 148.55634786, 149.13066972, 146.35328751,
#        144.70761824, 134.04367977, 134.45552578, 129.49110798,
#        128.14246682, 129.30139004, 124.85277942, 129.55056248,
#        139.66629654, 134.60957399, 142.6302126 , 145.82127476,
#        144.43296317, 149.51862464, 139.81670665, 134.85779071,
#        128.39574728, 112.53090028, 106.60875184, 110.2236284 ,
#        107.73165662, 106.21146719, 105.41575144, 105.08405303,
#        107.57143098, 108.96113046, 106.94352803, 107.72863944,
#        113.50575943, 106.68073604, 108.42572201, 118.80176338])

# %%
plt.figure(figsize=(14,5))
plt.plot(y_test, color = 'red', label = 'Real Litecoin Price')
plt.plot(y_pred, color = 'green', label = 'Predicted Litecoin Price')
plt.title('Litecoin Price Prediction using RNN-LSTM')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ## RNN model

# %%
regressor_2 = Sequential()
regressor_2.add(keras.layers.SimpleRNN(units = 50, activation = 'relu', return_sequences = True, input_shape = (X_train.shape[1], 5)))
regressor_2.add(Dropout(0.2))

# %%
regressor_2.add(keras.layers.SimpleRNN(units = 60, activation = 'relu', return_sequences = True))
regressor_2.add(Dropout(0.3))

regressor_2.add(keras.layers.SimpleRNN(units = 80, activation = 'relu', return_sequences = True))
regressor_2.add(Dropout(0.4))

regressor_2.add(keras.layers.SimpleRNN(units = 120, activation = 'relu'))
regressor_2.add(Dropout(0.5))

regressor_2.add(Dense(units =1))

# %%
regressor_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 60, 50)            2800
#
#  dropout_4 (Dropout)         (None, 60, 50)            0
#
#  simple_rnn_1 (SimpleRNN)    (None, 60, 60)            6660
#
#  dropout_5 (Dropout)         (None, 60, 60)            0
#
#  simple_rnn_2 (SimpleRNN)    (None, 60, 80)            11280
#
#  dropout_6 (Dropout)         (None, 60, 80)            0
#
#  simple_rnn_3 (SimpleRNN)    (None, 120)               24120
#
#  dropout_7 (Dropout)         (None, 120)               0
#
#  dense_1 (Dense)             (None, 1)                 121
#
# =================================================================
# Total params: 44,981
# Trainable params: 44,981
# Non-trainable params: 0
# _________________________________________________________________

# %%
regressor_2.compile(optimizer = optimizer, loss = 'mean_squared_error')

# %%
regressor_2.fit(X_train, y_train, epochs = 20, batch_size =32)
# Out:
# Epoch 1/20
# 70/70 [==============================] - 4s 27ms/step - loss: 0.0068
# Epoch 2/20
# 70/70 [==============================] - 2s 26ms/step - loss: 0.0033: 0s - loss:
# Epoch 3/20
# 70/70 [==============================] - 2s 26ms/step - loss: 0.0032
# Epoch 4/20
# 70/70 [==============================] - 2s 28ms/step - loss: 0.0029
# Epoch 5/20
# 70/70 [==============================] - 2s 28ms/step - loss: 0.0024
# Epoch 6/20
# 70/70 [==============================] - 2s 28ms/step - loss: 0.0024
# Epoch 7/20
# 70/70 [==============================] - 2s 30ms/step - loss: 0.0023
# Epoch 8/20
# 70/70 [==============================] - 2s 28ms/step - loss: 0.0023
# Epoch 9/20
# 70/70 [==============================] - 2s 27ms/step - loss: 0.0029
# Epoch 10/20
# 70/70 [==============================] - 2s 28ms/step - loss: 0.0021
# Epoch 11/20
# 70/70 [==============================] - 2s 27ms/step - loss: 0.0019
# Epoch 12/20
# 70/70 [==============================] - 2s 27ms/step - loss: 0.0024
# Epoch 13/20
# 70/70 [==============================] - 2s 27ms/step - loss: 0.0020
# Epoch 14/20
# 70/70 [==============================] - 2s 26ms/step - loss: 0.0022
# Epoch 15/20
# 70/70 [==============================] - 2s 28ms/step - loss: 0.0017
# Epoch 16/20
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0016
# Epoch 17/20
# 70/70 [==============================] - 2s 28ms/step - loss: 0.0018
# Epoch 18/20
# 70/70 [==============================] - 2s 27ms/step - loss: 0.0015
# Epoch 19/20
# 70/70 [==============================] - 2s 26ms/step - loss: 0.0017
# Epoch 20/20
# 70/70 [==============================] - 2s 26ms/step - loss: 0.0019

# %%
y_pred = regressor_2.predict(X_test)

# %%
y_pred = y_pred*scale

# %%
plt.figure(figsize=(14,5))
plt.plot(y_test, color = 'red', label = 'Real Litecoin Price')
plt.plot(y_pred, color = 'green', label = 'Predicted Litecoin Price')
plt.title('Litecoin Price Prediction using RNN-LSTM')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusion
# In this report, two models were created for forecasting the litecoin cryptocurrency price; a Recurent neural network model and a Long Short-Term Memory model. For comparison reasons, the algorithms used the same hyperparameters and both were trained on 20 epochs.
#
# ### Results
# By comparing the model summary for Simple RNN with the model summary for LSTM, it is evident that there are more trainable parameters for the LSTM (approximately 1:4 ratio for the LSTM), which explains why it took a longer time to train this model.
#
# Overall the plots show that the LSTM model performs a lot better, compared to the RNN, as it clearly captures the upward trend of the price.
#
# ### Next Steps
# To improve the quality of forecasts over many time steps, we'd need to use more data and more sophisticated LSTM model structures. We could try training with more data and running more training epochs. An additional recommendation would be to change the hyperparameters to achieve even smaller losses. However, the loss of this simple LSTM model was only 0.019.
